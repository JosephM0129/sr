# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
import tensorflow as tf
import sqlite3
import pandas as pd 
from keras.models import load_model
import numpy as np
import pickle

# %% [markdown]
# # Datos

# %%
conn = sqlite3.connect('sr_gaming/datos/metacritics.db')

df_scores = pd.read_sql("""SELECT
    l.id_juego,
    l.rating,
    l.genero,
    l.distribuidor,
    l.desarrollador,
    l.fecha_lanzamiento,
    u.id_usuario,
    u.cant_reviews,
    u.score_promedio,
    u.ratio_positivo,
    u.ratio_negativo,
    u.ratio_mixto,          

    i.score
    FROM interacciones AS i
        JOIN juegos as l ON l.id_juego = i.id_juego
        JOIN usuarios as u ON u.id_usuario = i.id_usuario
    WHERE score > 0
""", conn)

df_scores.head()
# Out:
#          id_juego rating       genero          distribuidor  \
# 0  baldurs-gate-3      M  Western RPG  Larian Studios Games
# 1  baldurs-gate-3      M  Western RPG  Larian Studios Games
# 2  baldurs-gate-3      M  Western RPG  Larian Studios Games
# 3  baldurs-gate-3      M  Western RPG  Larian Studios Games
# 4  baldurs-gate-3      M  Western RPG  Larian Studios Games
#
#           desarrollador fecha_lanzamiento            id_usuario  cant_reviews  \
# 0  Larian Studios Games        2023-08-03  attack-of-the-fanboy          1204
# 1  Larian Studios Games        2023-08-03            gamesradar          3857
# 2  Larian Studios Games        2023-08-03           gamingtrend          5123
# 3  Larian Studios Games        2023-08-03               ggrecon           225
# 4  Larian Studios Games        2023-08-03               gfinity           324
#
#    score_promedio  ratio_positivo  ratio_negativo  ratio_mixto  score
# 0              78              66               1           33    100
# 1              70              45               9           46    100
# 2              78              71               5           25    100
# 3              77              63               5           32    100
# 4              76              61               5           34    100

# %% [markdown]
# Generación de mapping, categorización y normalización de datos

# %%
## user_id
unique_user_id = df_scores["id_usuario"].unique().tolist()
user_id_2_id_mapping = {t: i for i, t in enumerate(unique_user_id)}
id_2_user_id_mapping = {user_id_2_id_mapping[k]: k for k in user_id_2_id_mapping}
df_scores["id_usuario"] = df_scores["id_usuario"].apply(lambda x: user_id_2_id_mapping[x])

## item_id
unique_item_id = df_scores["id_juego"].unique().tolist()
item_id_2_id_mapping = {t: i for i, t in enumerate(unique_item_id)}
id_2_item_id_mapping = {item_id_2_id_mapping[k]: k for k in item_id_2_id_mapping}
df_scores["id_juego"] = df_scores["id_juego"].apply(lambda x: item_id_2_id_mapping[x])

categorical_cols = ["distribuidor", "desarrollador", "genero", "rating"]

mappings = {}

for col in categorical_cols:

    # 1) imputar NaN con categoría fija
    df_scores[col] = df_scores[col].fillna("__UNKNOWN__")
    
    df_scores[col] = df_scores[col].astype("category")
    
    # Diccionarios
    categories = df_scores[col].cat.categories

    col_map = {
        "value_2_id": {cat: i for i, cat in enumerate(categories)},
        "id_2_value": {i: cat for i, cat in enumerate(categories)},
    }

    mappings[col] = col_map
    
    # Aplicar los códigos
    df_scores[col] = df_scores[col].cat.codes

# ---- fecha_lanzamiento: pasar a número tipo AAAAMM ----
df_scores["fecha_lanzamiento"] = pd.to_datetime(
    df_scores["fecha_lanzamiento"], 
    format="%Y-%m-%d", 
    errors="coerce"
)

df_scores["fecha_lanzamiento"] = (
    df_scores["fecha_lanzamiento"]
        .dt.strftime("%Y%m")
        .astype(float)
)

# ---- columnas numéricas a normalizar (incluyendo fecha_lanzamiento) ----
numeric_cols = [
    "cant_reviews",
    "score_promedio",
    "ratio_positivo",
    "ratio_mixto",
    "ratio_negativo",
    "fecha_lanzamiento",
]

# en cuáles querés hacer fillna(0.0) antes de normalizar
fillna_zero_cols = [
    "score_promedio",
    "ratio_positivo",
    "ratio_mixto",
    "ratio_negativo",
    "fecha_lanzamiento",  # si también querés imputar 0 acá
]

# mantenemos norm_params si lo querés seguir usando internamente
mappings.setdefault("norm_params", {})

# NUEVO: definimos variables para los min/max que van en el mapping final
fecha_min = fecha_max = None
cant_reviews_min = cant_reviews_max = None
score_prom_min = score_prom_max = None
ratio_pos_min = ratio_pos_max = None
ratio_mix_min = ratio_mix_max = None
ratio_neg_min = ratio_neg_max = None

for col in numeric_cols:
    # 1) imputación opcional
    if col in fillna_zero_cols:
        df_scores[col] = df_scores[col].fillna(0.0)
    
    # 2) min y max (sobre los datos ya imputados)
    col_min = df_scores[col].min()
    col_max = df_scores[col].max()

    # 3) guardar en mappings[norm_params] (por compatibilidad)
    mappings["norm_params"][col] = {
        "min": float(col_min),
        "max": float(col_max),
    }

    # 3bis) NUEVO: asignar a las variables con los nombres que querés
    if col == "fecha_lanzamiento":
        fecha_min = float(col_min)
        fecha_max = float(col_max)
    elif col == "cant_reviews":
        cant_reviews_min = float(col_min)
        cant_reviews_max = float(col_max)
    elif col == "score_promedio":
        score_prom_min = float(col_min)
        score_prom_max = float(col_max)
    elif col == "ratio_positivo":
        ratio_pos_min = float(col_min)
        ratio_pos_max = float(col_max)
    elif col == "ratio_mixto":
        ratio_mix_min = float(col_min)
        ratio_mix_max = float(col_max)
    elif col == "ratio_negativo":
        ratio_neg_min = float(col_min)
        ratio_neg_max = float(col_max)

    # 4) normalización min-max
    if col_max > col_min:
        df_scores[col] = (df_scores[col] - col_min) / (col_max - col_min)
    else:
        # caso degenerado: toda la columna es constante
        df_scores[col] = 0.0

# NUEVO: construir los diccionarios de categóricas con los nombres pedidos
desarrollador_2_id_mapping = mappings["desarrollador"]["value_2_id"]
id_2_desarrollador_mapping = mappings["desarrollador"]["id_2_value"]

distribuidor_2_id_mapping = mappings["distribuidor"]["value_2_id"]
id_2_distribuidor_mapping = mappings["distribuidor"]["id_2_value"]

genero_2_id_mapping = mappings["genero"]["value_2_id"]
id_2_genero_mapping = mappings["genero"]["id_2_value"]

rating_2_id_mapping = mappings["rating"]["value_2_id"]
id_2_rating_mapping = mappings["rating"]["id_2_value"]

# NUEVO: mapping final con los nombres EXACTOS que querés
mappings = {
    "user_id_2_id": user_id_2_id_mapping,
    "item_id_2_id": item_id_2_id_mapping,
    "desarrollador_2_id": desarrollador_2_id_mapping,
    "distribuidor_2_id": distribuidor_2_id_mapping,
    "rating_2_id": rating_2_id_mapping,
    "genero_2_id": genero_2_id_mapping,
    "id_2_user_id": id_2_user_id_mapping,
    "id_2_item_id": id_2_item_id_mapping,
    "id_2_desarrollador": id_2_desarrollador_mapping,
    "id_2_distribuidor": id_2_distribuidor_mapping,
    "id_2_rating": id_2_rating_mapping,
    "id_2_genero": id_2_genero_mapping,
    "fecha_min": fecha_min,
    "fecha_max": fecha_max,
    "cant_reviews_min": cant_reviews_min,
    "cant_reviews_max": cant_reviews_max,
    "score_prom_min": score_prom_min, 
    "score_prom_max": score_prom_max,
    "ratio_pos_min": ratio_pos_min,
    "ratio_pos_max": ratio_pos_max,
    "ratio_mix_min": ratio_mix_min,
    "ratio_mix_max": ratio_mix_max,
    "ratio_neg_min": ratio_neg_min,
    "ratio_neg_max": ratio_neg_max,
}

with open("sr_gaming/datos/mappings.pkl", "wb") as f:
    pickle.dump(mappings, f)

# scores
df_scores["score"] = df_scores["score"] / 100.0

df_scores.head()
# Out:
#    id_juego  rating  genero  distribuidor  desarrollador  fecha_lanzamiento  \
# 0         0       4     117          1009           2160           0.999012
# 1         0       4     117          1009           2160           0.999012
# 2         0       4     117          1009           2160           0.999012
# 3         0       4     117          1009           2160           0.999012
# 4         0       4     117          1009           2160           0.999012
#
#    id_usuario  cant_reviews  score_promedio  ratio_positivo  ratio_negativo  \
# 0           0      0.059511        0.677419        0.632911        0.030303
# 1           1      0.193082        0.419355        0.367089        0.272727
# 2           2      0.256822        0.677419        0.696203        0.151515
# 3           3      0.010221        0.645161        0.594937        0.151515
# 4           4      0.015205        0.612903        0.569620        0.151515
#
#    ratio_mixto  score
# 0     0.475410    1.0
# 1     0.688525    1.0
# 2     0.344262    1.0
# 3     0.459016    1.0
# 4     0.491803    1.0

# %%
df_scores.distribuidor.unique()
# Out:
# array([1009,   19, 1232, ...,  689, 1399,  172],
#       shape=(2096,), dtype=int16)

# %%
dataset_inputs = {
    "user_id": df_scores["id_usuario"].to_numpy(dtype="float32"),
    "item_id": df_scores["id_juego"].to_numpy(dtype="float32"),
    "desarrollador_id": df_scores["desarrollador"].to_numpy(dtype="float32"),
    "distribuidor_id": df_scores["distribuidor"].to_numpy(dtype="float32"),
    "rating_id": df_scores["rating"].to_numpy(dtype="float32"),
    "genero_id": df_scores["genero"].to_numpy(dtype="float32"),
    "fecha_lanzamiento": df_scores["fecha_lanzamiento"].to_numpy(dtype="float32"),
    "cant_reviews": df_scores["cant_reviews"].to_numpy(dtype="float32"),
    "score_promedio": df_scores["score_promedio"].to_numpy(dtype="float32"),
    "ratio_positivo": df_scores["ratio_positivo"].to_numpy(dtype="float32"),
    "ratio_mixto": df_scores["ratio_mixto"].to_numpy(dtype="float32"),
    "ratio_negativo": df_scores["ratio_negativo"].to_numpy(dtype="float32"),
    
}

dataset_outputs = df_scores['score']

dataset = tf.data.Dataset.from_tensor_slices((dataset_inputs, dataset_outputs))
dataset = dataset.shuffle(100_000, seed=42, reshuffle_each_iteration=False)

cut = int(df_scores.shape[0] * 0.8)
train_dataset = dataset.take(cut).batch(1024).cache()
test_dataset = dataset.skip(df_scores.shape[0] - cut).batch(1024).cache()

# %% [markdown]
# ## Una torre (versión funcional)

# %%
# usuarios
num_users = df_scores["id_usuario"].nunique() + 1
user_input = keras.layers.Input(shape=[1], name="user_id")
user_embedding = keras.layers.Embedding(num_users, min(num_users//2+1, 50))(user_input)
user_vec = keras.layers.Flatten()(user_embedding)

# items
num_items = df_scores["id_juego"].nunique() + 1
item_input = keras.layers.Input(shape=[1], name="item_id")
item_embedding = keras.layers.Embedding(num_items, min(num_items//2+1, 50))(item_input)
item_vec = keras.layers.Flatten()(item_embedding)

# desarrollador
num_desarrolladores = df_scores["desarrollador"].nunique() + 1
desarrollador_input = keras.layers.Input(shape=[1], name="desarrollador_id")
desarrollador_embedding = keras.layers.Embedding(num_desarrolladores, min(num_desarrolladores//2+1, 50))(desarrollador_input)
desarrollador_vec = keras.layers.Flatten()(desarrollador_embedding)

# distribuidor
num_distribuidores = df_scores["distribuidor"].nunique() + 1
distribuidor_input = keras.layers.Input(shape=[1], name="distribuidor_id")
distribuidor_embedding = keras.layers.Embedding(num_distribuidores, min(num_distribuidores//2+1, 50))(distribuidor_input)
distribuidor_vec = keras.layers.Flatten()(distribuidor_embedding)

# ratinges
num_ratinges = df_scores["rating"].nunique() + 1
rating_input = keras.layers.Input(shape=[1], name="rating_id")
rating_embedding = keras.layers.Embedding(num_ratinges, min(num_ratinges//2+1, 50))(rating_input)
rating_vec = keras.layers.Flatten()(rating_embedding)

# genero
num_generos = df_scores["genero"].nunique() + 1
genero_input = keras.layers.Input(shape=[1], name="genero_id")
genero_embedding = keras.layers.Embedding(num_generos, min(num_generos//2+1, 50))(genero_input)
genero_vec = keras.layers.Flatten()(genero_embedding)

# fecha_lanzamiento
fecha_lanzamiento_input = keras.layers.Input(shape=[1], name="fecha_lanzamiento")

# cant_reviews
cant_reviews_input = keras.layers.Input(shape=[1], name="cant_reviews")

# score_promedio
score_promedio_input = keras.layers.Input(shape=[1], name="score_promedio")

# ratio_positivo
ratio_positivo_input = keras.layers.Input(shape=[1], name="ratio_positivo")

# ratio_mixto
ratio_mixto_input = keras.layers.Input(shape=[1], name="ratio_mixto")

# ratio_negativo
ratio_negativo_input = keras.layers.Input(shape=[1], name="ratio_negativo")

conc = keras.layers.Concatenate()([
    user_vec, item_vec, desarrollador_vec, distribuidor_vec, rating_vec, genero_vec, fecha_lanzamiento_input, cant_reviews_input,
    score_promedio_input, ratio_positivo_input, ratio_mixto_input, ratio_negativo_input,
    ])

scores = keras.Sequential([
    keras.layers.Dense(256, activation="relu"),
    keras.layers.Dense(64, activation="relu"),

    keras.layers.Dense(1, activation='linear'),
])(conc)

# %%
model = keras.Model(inputs=[
    user_input, item_input, desarrollador_input, distribuidor_input, rating_input, genero_input, fecha_lanzamiento_input, cant_reviews_input,
    score_promedio_input, ratio_positivo_input, ratio_mixto_input, ratio_negativo_input
    ], outputs=scores)

model.compile(
    loss=keras.losses.MeanSquaredError(),
    metrics=[keras.metrics.RootMeanSquaredError()],
    optimizer=keras.optimizers.Adagrad(learning_rate=0.1) #hiperparámetro
)

# Detiene el entrenamiento cuando no hay mejora en loss en tres épocas consecutivas
es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# Graba el modelo cuando cambia val_root_mean_squared_error
#mc_callback = keras.callbacks.ModelCheckpoint(filepath="checkpoint.{val_root_mean_squared_error:.2f}.weights.h5", monitor="val_root_mean_squared_error", mode="min",  save_weights_only=True, save_best_only=True)
mc_callback = keras.callbacks.ModelCheckpoint(filepath="checkpoint.{val_root_mean_squared_error:.2f}.keras", monitor="val_root_mean_squared_error", mode="min",  save_weights_only=False, save_best_only=True)

history = model.fit(train_dataset,
                    validation_data=test_dataset,
                    validation_freq=1,
                    epochs=100,
                    batch_size=1024,
                    callbacks=[es_callback, mc_callback]
                    )
# Out:
# Epoch 1/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 13s 36ms/step - loss: 0.0192 - root_mean_squared_error: 0.1387 - val_loss: 0.0270 - val_root_mean_squared_error: 0.1642
# Epoch 2/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0144 - root_mean_squared_error: 0.1201 - val_loss: 0.0263 - val_root_mean_squared_error: 0.1621
# Epoch 3/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1608
# Epoch 4/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0140 - root_mean_squared_error: 0.1183 - val_loss: 0.0256 - val_root_mean_squared_error: 0.1599
# Epoch 5/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0139 - root_mean_squared_error: 0.1178 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1593
# Epoch 6/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0138 - root_mean_squared_error: 0.1174 - val_loss: 0.0252 - val_root_mean_squared_error: 0.1586
# Epoch 7/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0137 - root_mean_squared_error: 0.1171 - val_loss: 0.0250 - val_root_mean_squared_error: 0.1580
# Epoch 8/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0136 - root_mean_squared_error: 0.1167 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1575
# Epoch 9/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0136 - root_mean_squared_error: 0.1164 - val_loss: 0.0246 - val_root_mean_squared_error: 0.1569
# Epoch 10/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0135 - root_mean_squared_error: 0.1161 - val_loss: 0.0245 - val_root_mean_squared_error: 0.1564
# Epoch 11/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1558
# Epoch 12/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0134 - root_mean_squared_error: 0.1156 - val_loss: 0.0241 - val_root_mean_squared_error: 0.1554
# Epoch 13/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0133 - root_mean_squared_error: 0.1153 - val_loss: 0.0240 - val_root_mean_squared_error: 0.1548
# Epoch 14/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0132 - root_mean_squared_error: 0.1151 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1544
# Epoch 15/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0132 - root_mean_squared_error: 0.1148 - val_loss: 0.0237 - val_root_mean_squared_error: 0.1540
# Epoch 16/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0236 - val_root_mean_squared_error: 0.1535
# Epoch 17/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0131 - root_mean_squared_error: 0.1143 - val_loss: 0.0235 - val_root_mean_squared_error: 0.1532
# Epoch 18/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0130 - root_mean_squared_error: 0.1141 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1528
# Epoch 19/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0130 - root_mean_squared_error: 0.1139 - val_loss: 0.0232 - val_root_mean_squared_error: 0.1525
# Epoch 20/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0129 - root_mean_squared_error: 0.1136 - val_loss: 0.0231 - val_root_mean_squared_error: 0.1521
# Epoch 21/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0129 - root_mean_squared_error: 0.1134 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1518
# Epoch 22/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0229 - val_root_mean_squared_error: 0.1514
# Epoch 23/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0128 - root_mean_squared_error: 0.1129 - val_loss: 0.0228 - val_root_mean_squared_error: 0.1510
# Epoch 24/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0227 - val_root_mean_squared_error: 0.1506
# Epoch 25/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0126 - root_mean_squared_error: 0.1125 - val_loss: 0.0226 - val_root_mean_squared_error: 0.1502
# Epoch 26/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0126 - root_mean_squared_error: 0.1122 - val_loss: 0.0225 - val_root_mean_squared_error: 0.1499
# Epoch 27/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0224 - val_root_mean_squared_error: 0.1495
# Epoch 28/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0125 - root_mean_squared_error: 0.1118 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1491
# Epoch 29/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0124 - root_mean_squared_error: 0.1115 - val_loss: 0.0221 - val_root_mean_squared_error: 0.1488
# Epoch 30/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1483
# Epoch 31/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0123 - root_mean_squared_error: 0.1111 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1479
# Epoch 32/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1475
# Epoch 33/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0122 - root_mean_squared_error: 0.1106 - val_loss: 0.0216 - val_root_mean_squared_error: 0.1470
# Epoch 34/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0122 - root_mean_squared_error: 0.1104 - val_loss: 0.0215 - val_root_mean_squared_error: 0.1465
# Epoch 35/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1459
# Epoch 36/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0121 - root_mean_squared_error: 0.1099 - val_loss: 0.0212 - val_root_mean_squared_error: 0.1455
# Epoch 37/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0120 - root_mean_squared_error: 0.1097 - val_loss: 0.0210 - val_root_mean_squared_error: 0.1448
# Epoch 38/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0208 - val_root_mean_squared_error: 0.1442
# Epoch 39/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1436
# Epoch 40/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0119 - root_mean_squared_error: 0.1090 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1428
# Epoch 41/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0118 - root_mean_squared_error: 0.1087 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1415
# Epoch 42/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0118 - root_mean_squared_error: 0.1084 - val_loss: 0.0195 - val_root_mean_squared_error: 0.1398
# Epoch 43/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0189 - val_root_mean_squared_error: 0.1375
# Epoch 44/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0116 - root_mean_squared_error: 0.1079 - val_loss: 0.0181 - val_root_mean_squared_error: 0.1347
# Epoch 45/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0116 - root_mean_squared_error: 0.1077 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1319
# Epoch 46/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0115 - root_mean_squared_error: 0.1074 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1309
# Epoch 47/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0115 - root_mean_squared_error: 0.1072 - val_loss: 0.0171 - val_root_mean_squared_error: 0.1307
# Epoch 48/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0114 - root_mean_squared_error: 0.1070 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1303
# Epoch 49/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0114 - root_mean_squared_error: 0.1067 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1302
# Epoch 50/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0113 - root_mean_squared_error: 0.1065 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1299
# Epoch 51/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1296
# Epoch 52/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0112 - root_mean_squared_error: 0.1060 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1294
# Epoch 53/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1290
# Epoch 54/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0111 - root_mean_squared_error: 0.1055 - val_loss: 0.0165 - val_root_mean_squared_error: 0.1284
# Epoch 55/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - loss: 0.0111 - root_mean_squared_error: 0.1052 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1278
# Epoch 56/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1271
# Epoch 57/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0109 - root_mean_squared_error: 0.1046 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1266
# Epoch 58/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1262
# Epoch 59/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1255
# Epoch 60/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0107 - root_mean_squared_error: 0.1036 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1249
# Epoch 61/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 0.0107 - root_mean_squared_error: 0.1033 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1244
# Epoch 62/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0106 - root_mean_squared_error: 0.1030 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1238
# Epoch 63/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0105 - root_mean_squared_error: 0.1027 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1233
# Epoch 64/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1227
# Epoch 65/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0104 - root_mean_squared_error: 0.1020 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 66/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0104 - root_mean_squared_error: 0.1017 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1217
# Epoch 67/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0103 - root_mean_squared_error: 0.1014 - val_loss: 0.0147 - val_root_mean_squared_error: 0.1212
# Epoch 68/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0102 - root_mean_squared_error: 0.1011 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1202
# Epoch 69/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0102 - root_mean_squared_error: 0.1008 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1197
# Epoch 70/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0101 - root_mean_squared_error: 0.1004 - val_loss: 0.0143 - val_root_mean_squared_error: 0.1194
# Epoch 71/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0100 - root_mean_squared_error: 0.1001 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1187
# Epoch 72/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0100 - root_mean_squared_error: 0.0998 - val_loss: 0.0138 - val_root_mean_squared_error: 0.1175
# Epoch 73/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0099 - root_mean_squared_error: 0.0994 - val_loss: 0.0137 - val_root_mean_squared_error: 0.1170
# Epoch 74/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1164
# Epoch 75/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1279
# Epoch 76/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1265
# Epoch 77/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1258
# Epoch 78/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0097 - root_mean_squared_error: 0.0983 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1274
# Epoch 79/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - loss: 0.0096 - root_mean_squared_error: 0.0978 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 80/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
# Epoch 81/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.0095 - root_mean_squared_error: 0.0973 - val_loss: 0.0156 - val_root_mean_squared_error: 0.1250
# Epoch 82/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0095 - root_mean_squared_error: 0.0973 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1221
# Epoch 83/100
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.0094 - root_mean_squared_error: 0.0969 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1216

# %% [markdown]
# Predicción Ejemplo

# %%
modelo = load_model("sr_gaming/datos/checkpoint.0.16.keras")


test_loss, test_rmse = modelo.evaluate(test_dataset, batch_size=1024)
print("Test RMSE en escala 0–100:", test_rmse * 100)
# Out:
# 270/270 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0245 - root_mean_squared_error: 0.1564
# Test RMSE en escala 0–100: 15.636640787124634

# %%
# Cargar mappings
import pickle
with open("sr_gaming/datos/mappings.pkl", "rb") as f:
    mappings = pickle.load(f)

user_id_2_id          = mappings["user_id_2_id"]
item_id_2_id          = mappings["item_id_2_id"]
desarrollador_2_id    = mappings["desarrollador_2_id"]
distribuidor_2_id     = mappings["distribuidor_2_id"]
rating_2_id           = mappings["rating_2_id"]
genero_2_id           = mappings["genero_2_id"]
cant_reviews_min = mappings["cant_reviews_min"]
cant_reviews_max = mappings["cant_reviews_max"]
score_prom_min = mappings["score_prom_min"]
score_prom_max = mappings["score_prom_max"]
ratio_pos_min = mappings["ratio_pos_min"]
ratio_pos_max = mappings["ratio_pos_max"]
ratio_mix_min = mappings["ratio_mix_min"]
ratio_mix_max = mappings["ratio_mix_max"]
ratio_neg_min = mappings["ratio_neg_min"]
ratio_neg_max = mappings["ratio_neg_max"]

# para fecha
fecha_min = mappings["fecha_min"]
fecha_max = mappings["fecha_max"]

#Ejemplo
id_usuario_real = '1up'

id_usuario_int = user_id_2_id_mapping[id_usuario_real]

print(f'ID de usuario: {id_usuario_int}') #id_usuario_int
# Out:
# ID de usuario: 113

# %%
conn = sqlite3.connect('sr_gaming/datos/metacritics.db')

# Obtiene los juegos que el usuario no ha puntuado, es decir, desconocidos
df_cand = pd.read_sql("""
    SELECT
        j.id_juego,
        j.desarrollador,
        j.distribuidor,
        j.rating,
        j.genero,
        j.fecha_lanzamiento,
        u.cant_reviews,
        u.score_promedio,
        u.ratio_positivo,
        u.ratio_mixto,
        u.ratio_negativo
    FROM juegos j
    JOIN usuarios u ON u.id_usuario = ?
    WHERE j.id_juego NOT IN (
        SELECT id_juego
        FROM interacciones
        WHERE id_usuario = ?
    )
""", conn, params=[id_usuario_real, id_usuario_real])

df_cand
# Out:
#                        id_juego           desarrollador  \
# 0                baldurs-gate-3    Larian Studios Games
# 1                 goldeneye-007               Rare Ltd.
# 2          grand-theft-auto-iii              DMA Design
# 3            grand-theft-auto-v          Rockstar North
# 4                   half-life-2          Valve Software
# ...                         ...                     ...
# 11363  ride-to-hell-retribution               Eutechnyx
# 11364              spogs-racing            Pronto Games
# 11365                 stormgate     Frost Giant Studios
# 11366    vroom-in-the-night-sky                 Poisoft
# 11367                     yaris  Backbone Entertainment
#
#                  distribuidor rating             genero fecha_lanzamiento  \
# 0        Larian Studios Games      M        Western RPG        2023-08-03
# 1                    Nintendo      T                FPS        1997-08-25
# 2              Rockstar Games      M  Open-World Action        2001-10-22
# 3              Rockstar Games      M  Open-World Action        2014-11-18
# 4                    VU Games      M                FPS        2004-11-16
# ...                       ...    ...                ...               ...
# 11363             Deep Silver      M   Action Adventure        2013-06-25
# 11364               D2C Games      E        Auto Racing        2008-07-07
# 11365     Frost Giant Studios   None        Command RTS        2025-08-05
# 11366                 Poisoft      E             Biking        2017-04-05
# 11367  Backbone Entertainment   E10+        Auto Racing        2007-10-10
#
#        cant_reviews  score_promedio  ratio_positivo  ratio_mixto  \
# 0              3527              69              51           35
# 1              3527              69              51           35
# 2              3527              69              51           35
# 3              3527              69              51           35
# 4              3527              69              51           35
# ...             ...             ...             ...          ...
# 11363          3527              69              51           35
# 11364          3527              69              51           35
# 11365          3527              69              51           35
# 11366          3527              69              51           35
# 11367          3527              69              51           35
#
#        ratio_negativo
# 0                  14
# 1                  14
# 2                  14
# 3                  14
# 4                  14
# ...               ...
# 11363              14
# 11364              14
# 11365              14
# 11366              14
# 11367              14
#
# [11368 rows x 11 columns]

# %%
## Mapping cada variable categórica
# user_id interno (el mismo para todas las filas)
id_usuario_int = user_id_2_id[id_usuario_real]
df_cand["user_id_int"] = id_usuario_int

# item_id interno
df_cand["item_id_int"] = df_cand["id_juego"].map(item_id_2_id)

# desarrollador_id interno
df_cand["desarrollador_id_int"] = df_cand["desarrollador"].fillna( '__UNKNOWN__')
df_cand["desarrollador_id_int"] = df_cand["desarrollador_id_int"].map(desarrollador_2_id)

# distribuidor_id interno
df_cand["distribuidor_id_int"] = df_cand["distribuidor"].fillna( '__UNKNOWN__')
df_cand["distribuidor_id_int"] = df_cand["distribuidor_id_int"].map(distribuidor_2_id)

# rating_id interno
df_cand["rating_id_int"] = df_cand["rating"].fillna( '__UNKNOWN__')
df_cand["rating_id_int"] = df_cand["rating_id_int"].map(rating_2_id)

# genero_id interno
df_cand["genero_id_int"] = df_cand["genero"].fillna( '__UNKNOWN__')
df_cand["genero_id_int"] = df_cand["genero"].map(genero_2_id)


## Normalizar fecha y numéricas igual que en train
df_cand["fecha_lanzamiento"] = pd.to_datetime(
    df_cand["fecha_lanzamiento"], errors="coerce"
)
df_cand["fecha_aaaamm"] = df_cand["fecha_lanzamiento"].dt.strftime("%Y%m").astype(float)

df_cand["fecha_lanzamiento_norm"] = (
    (df_cand["fecha_aaaamm"] - fecha_min) / (fecha_max - fecha_min)
)

## Normalizar variables numéricas igual que en train


df_cand["cant_reviews_norm"] = (
    (df_cand["cant_reviews"] - cant_reviews_min)
    / (cant_reviews_max - cant_reviews_min)
)

df_cand["score_promedio_norm"] = (
    (df_cand["score_promedio"] - score_prom_min)
    / (score_prom_max - score_prom_min)
)

df_cand["ratio_positivo_norm"] = (
    (df_cand["ratio_positivo"] - ratio_pos_min)
    / (ratio_pos_max - ratio_pos_min)
)

df_cand["ratio_mixto_norm"] = (
    (df_cand["ratio_mixto"] - ratio_mix_min)
    / (ratio_mix_max - ratio_mix_min)
)

df_cand["ratio_negativo_norm"] = (
    (df_cand["ratio_negativo"] - ratio_neg_min)
    / (ratio_neg_max - ratio_neg_min)
)

df_cand.head()
# Out:
#                id_juego         desarrollador          distribuidor rating  \
# 0        baldurs-gate-3  Larian Studios Games  Larian Studios Games      M
# 1         goldeneye-007             Rare Ltd.              Nintendo      T
# 2  grand-theft-auto-iii            DMA Design        Rockstar Games      M
# 3    grand-theft-auto-v        Rockstar North        Rockstar Games      M
# 4           half-life-2        Valve Software              VU Games      M
#
#               genero fecha_lanzamiento  cant_reviews  score_promedio  \
# 0        Western RPG        2023-08-03          3527              69
# 1                FPS        1997-08-25          3527              69
# 2  Open-World Action        2001-10-22          3527              69
# 3  Open-World Action        2014-11-18          3527              69
# 4                FPS        2004-11-16          3527              69
#
#    ratio_positivo  ratio_mixto  ...  distribuidor_id_int  rating_id_int  \
# 0              51           35  ...                 1009              4
# 1              51           35  ...                 1232              6
# 2              51           35  ...                 1518              4
# 3              51           35  ...                 1518              4
# 4              51           35  ...                 1911              4
#
#    genero_id_int  fecha_aaaamm  fecha_lanzamiento_norm  cant_reviews_norm  \
# 0            117      202308.0                0.999012           0.176468
# 1             38      199708.0                0.986173           0.176468
# 2             67      200110.0                0.988158           0.176468
# 3             67      201411.0                0.994583           0.176468
# 4             38      200411.0                0.989645           0.176468
#
#    score_promedio_norm  ratio_positivo_norm  ratio_mixto_norm  \
# 0             0.387097             0.443038          0.508197
# 1             0.387097             0.443038          0.508197
# 2             0.387097             0.443038          0.508197
# 3             0.387097             0.443038          0.508197
# 4             0.387097             0.443038          0.508197
#
#    ratio_negativo_norm
# 0             0.424242
# 1             0.424242
# 2             0.424242
# 3             0.424242
# 4             0.424242
#
# [5 rows x 24 columns]

# %%
    # --- 5) Armar input_dict AL ESTILO "lista de items" -------------

input_dict = {
        "user_id":        df_cand["user_id_int"].to_numpy(dtype="float32"),
        "item_id":        df_cand["item_id_int"].to_numpy(dtype="float32"),
        "desarrollador_id": df_cand["desarrollador_id_int"].to_numpy(dtype="float32"),
        "distribuidor_id":  df_cand["distribuidor_id_int"].to_numpy(dtype="float32"),
        "rating_id":        df_cand["rating_id_int"].to_numpy(dtype="float32"),
        "genero_id":        df_cand["genero_id_int"].to_numpy(dtype="float32"),
        "fecha_lanzamiento": df_cand["fecha_lanzamiento_norm"].to_numpy(dtype="float32"),
        "cant_reviews":      df_cand["cant_reviews_norm"].to_numpy(dtype="float32"),
        "score_promedio":    df_cand["score_promedio_norm"].to_numpy(dtype="float32"),
        "ratio_positivo":    df_cand["ratio_positivo_norm"].to_numpy(dtype="float32"),
        "ratio_mixto":       df_cand["ratio_mixto_norm"].to_numpy(dtype="float32"),
        "ratio_negativo":    df_cand["ratio_negativo_norm"].to_numpy(dtype="float32"),
    }

    # --- 6) Predecir para TODOS los juegos candidatos ---------------

preds = modelo.predict(input_dict, batch_size=1024).squeeze()
df_cand["pred_score"] = preds

# Top N recomendaciones
N = 9
df_top = df_cand.sort_values("pred_score", ascending=False).head(N)

# Mostrar id_juego real + score predicho
print(df_top[["id_juego", "pred_score"]])
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#                                                id_juego  pred_score
# 13               the-legend-of-zelda-breath-of-the-wild    0.717273
# 31             the-legend-of-zelda-tears-of-the-kingdom    0.717007
# 27    the-legend-of-zelda-a-link-to-the-past-four-sw...    0.715471
# 9                                 red-dead-redemption-2    0.713944
# 3317  the-legend-of-zelda-breath-of-the-wild-the-master    0.712717
# 32    the-legend-of-zelda-tears-of-the-kingdom-nintendo    0.712250
# 3                                    grand-theft-auto-v    0.712141
# 144                                      metroid-fusion    0.711019
# 33                   the-legend-of-zelda-the-wind-waker    0.710333

# %%
preds_train = model.predict(dataset_inputs, batch_size=1024).squeeze()

print("train min:", preds_train.min(), "max:", preds_train.max(), "std:", preds_train.std())
# Out:
# 337/337 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# train min: 0.13033879 max: 1.0110232 std: 0.10904927

# %%
df_juegos = df_cand.sort_values("pred_score", ascending=False)  

id_juegos = [i for i in df_juegos["id_juego"]]

id_juegos
# Out:
# ['the-legend-of-zelda-breath-of-the-wild',
#  'the-legend-of-zelda-tears-of-the-kingdom',
#  'the-legend-of-zelda-a-link-to-the-past-four-swords',
#  'red-dead-redemption-2',
#  'the-legend-of-zelda-breath-of-the-wild-the-master',
#  'the-legend-of-zelda-tears-of-the-kingdom-nintendo',
#  'grand-theft-auto-v',
#  'metroid-fusion',
#  'the-legend-of-zelda-the-wind-waker',
#  'new-super-mario-bros-u-deluxe',
#  'pikmin-1-plus-2',
#  'la-noire-the-vr-case-files',
#  'the-legend-of-zelda-ocarina-of-time-master-quest-2002',
#  'super-mario-maker-2',
#  'the-legend-of-zelda-ocarina-of-time',
#  'the-legend-of-zelda-breath-of-the-wild-the',
#  'new-super-luigi-u',
#  'super-mario-bros-wonder',
#  'the-legend-of-zelda-breath-of-the-wild-nintendo',
#  'mass-effect-2-lair-of-the-shadow-broker',
#  'yoshis-story',
#  'the-legend-of-zelda-a-link-between-worlds',
#  'the-legend-of-zelda-triforce-heroes',
#  'new-super-mario-bros-2',
#  'star-fox-64',
#  'the-legend-of-zelda-collectors-edition',
#  'l-a-noire-reefer-madness',
#  'grand-theft-auto-vice-city',
#  'f-zero-99',
#  'nintendogs-cats-toy-poodle-and-new-friends',
#  'pikmin-3',
#  'l-a-noire-nicholson-electroplating-disaster',
#  'emio-the-smiling-man-famicom-detective-club',
#  'new-super-mario-bros-u',
#  'nintendogs-cats-french-bulldog-and-new-friend',
#  'marvels-spider-man',
#  'rhythm-heaven-megamix',
#  'super-mario-world-super-mario-advance-2',
#  'super-mario-odyssey',
#  'super-mario-maker',
#  'diablo-iii-ultimate-evil-edition',
#  'pilotwings-64',
#  'the-legend-of-zelda-majoras-mask',
#  'super-mario-3d-world',
#  'donkey-kong-bananza',
#  'super-mario-bros-35',
#  'super-mario-sunshine',
#  'art-style-pictobits',
#  'nintendogs-cats-golden-retriever-and-new-frie',
#  'wario-land-4',
#  'diablo-iii',
#  'diablo-iii-rise-of-the-necromancer',
#  'grand-theft-auto-online',
#  'mario-kart-8-deluxe-booster-course-pass-wave-4',
#  'super-mario-3d-world-plus-bowsers-fury',
#  'mass-effect-2-kasumi-stolen-memory',
#  'nintendogs-dalmatian-and-friends',
#  'marvels-spider-man-2',
#  'red-dead-redemption-featuring-undead-nightmare',
#  'mario-kart-8-deluxe-booster-course-pass-wave-1',
#  'yoshis-island-super-mario-advance-3',
#  'f-zero-x',
#  'arms',
#  'red-dead-redemption-undead-nightmare-pack',
#  'mario-kart-8',
#  'wii-fit-u',
#  'mario-kart-8-dlc-pack-2',
#  'mario-kart-64',
#  'grand-theft-auto-the-trilogy-the-definitive',
#  'l-a-noire-the-complete-edition',
#  '1080-teneighty-snowboarding',
#  'dragon-age-inquisition',
#  'diablo-iv',
#  'diablo-iv-vessel-of-hatred',
#  'baldurs-gate-ii-throne-of-bhaal',
#  'red-dead-redemption-liars-and-cheats',
#  'pikmin-4',
#  'bloodborne',
#  'bloodborne-the-old-hunters',
#  'animal-crossing-new-horizons',
#  'mario-kart-8-dlc-pack-1',
#  'art-style-cubello',
#  'advance-wars',
#  'diablo-iii-reaper-of-souls',
#  'super-mario-advance',
#  'xcom-enemy-within',
#  'god-of-war',
#  'baldurs-gate-3',
#  'metroid-samus-returns',
#  'halo-4',
#  'ring-fit-adventure',
#  'marvels-spider-man-silver-lining',
#  'pikmin',
#  'grand-theft-auto-iii',
#  'animal-crossing-new-horizons-happy-home-paradise',
#  'steel-diver-sub-wars',
#  'baldurs-gate',
#  'mario-and-donkey-kong-minis-on-the-move',
#  'art-style-orbient',
#  'dr-mario-miracle-cure',
#  'super-mario-3d-all-stars',
#  'lbx-little-battlers-experience',
#  'dragon-age-the-veilguard',
#  'dragon-age-origins-return-to-ostagar',
#  'xenoblade-chronicles-2',
#  'dragon-age-origins-witch-hunt',
#  'red-dead-redemption-and-undead-nightmare',
#  'baldurs-gate-ii-shadows-of-amn',
#  'xcom-enemy-within-expansion',
#  'warcraft-iii-reign-of-chaos',
#  'tank-troopers',
#  'the-last-of-us-part-i',
#  'marvels-spider-man-turf-wars',
#  'the-legend-of-zelda-skyward-sword-hd',
#  'glory-of-heracles',
#  'fallout-3-mothership-zeta',
#  'monster-hunter-stories-2017',
#  'halo-combat-evolved',
#  'animal-crossing-new-leaf',
#  'god-of-war-ascension',
#  'the-last-of-us-remastered',
#  'days-gone',
#  'dc-super-hero-girls-teen-power',
#  'animal-crossing-happy-home-designer',
#  'fire-emblem-if',
#  'hearthstone-heroes-of-warcraft-blackrock-mountain',
#  'xenoblade-chronicles-2-torna-the-golden-country',
#  'hearthstone-heroes-of-warcraft',
#  'starcraft-remastered',
#  'metroid-prime',
#  'marvels-spider-man-the-heist',
#  'divinity-original-sin-ii-definitive-edition',
#  'fire-emblem-echoes-shadows-of-valentia',
#  'warcraft-iii-the-frozen-throne',
#  'diablo',
#  'mario-vs-donkey-kong-2024',
#  'art-style-rotohex',
#  'bird-and-beans',
#  'dr-kawashimas-brain-training-for-nintendo-switch',
#  'resistance-3',
#  'uncharted-the-lost-legacy',
#  'world-of-warcraft-legion',
#  'xcom-2-collection',
#  'xenoblade-chronicles-3',
#  'fire-emblem-shadow-dragon-and-the-blade-of-light',
#  'live-a-live',
#  'overwatch-2',
#  'grand-theft-auto-2',
#  'super-smash-bros-for-nintendo-3ds-wii-u',
#  'mass-effect-2-overlord',
#  'mass-effect-3',
#  'fallout',
#  'paper-mario-the-thousand-year-door',
#  'tokyo-mirage-sessions-fe',
#  'the-last-of-us',
#  'alienation',
#  'xenoblade-chronicles',
#  'fire-emblem-engage',
#  'uncharted-4-a-thiefs-end',
#  'fire-emblem-three-houses',
#  'dragon-quest-xi-s-echoes-of-an-elusive-age',
#  'tomodachi-life',
#  'divinity-original-sin',
#  'lionheart-legacy-of-the-crusader',
#  'mass-effect-2-arrival',
#  'fire-emblem-fates-revelation',
#  '1080-avalanche',
#  'xenoblade-chronicles-x',
#  'nex-machina-death-machine',
#  'marvels-midnight-suns',
#  'fable-ii-knothole-island',
#  'infamous-second-son',
#  'mario-kart-8-deluxe-booster-course-pass-wave-2',
#  'warcraft-iii-reforged',
#  'the-elder-scrolls-iv-knights-of-the-nine',
#  'hearthstone-heroes-of-warcraft-curse-of-naxxramas',
#  'flipnote-studio',
#  'sid-meiers-alpha-centauri',
#  'dragon-age-origins-lelianas-song',
#  'mario-kart-8-deluxe-booster-course-pass-wave-3',
#  'another-code-recollection',
#  'sid-meiers-gettysburg',
#  'xenoblade-chronicles-x-definitive-edition',
#  'death-stranding-directors-cut',
#  'fire-emblem-fates-birthright',
#  'tokyo-mirage-sessions-fe-encore',
#  'starcraft-ii-legacy-of-the-void',
#  'mario-kart-8-deluxe',
#  'photo-dojo',
#  'crackdown-2',
#  'xcom-2-war-of-the-chosen',
#  'world-of-warcraft-classic',
#  'kinetica',
#  'golden-sun',
#  'planescape-torment',
#  'metroid-dread',
#  'paper-mario-sticker-star',
#  'bayonetta-3',
#  'animal-crossing',
#  'ghost-of-tsushima',
#  'rallisport-challenge-2',
#  'forza-motorsport-6',
#  'mario-and-luigi-brothership',
#  'f-zero-gx',
#  'harmoknight',
#  'days-gone-remastered',
#  'starfield',
#  'dragon-age-inquisition-jaws-of-hakkon',
#  'xenoblade-chronicles-definitive-edition',
#  'alan-wakes-american-nightmare',
#  'fire-emblem-awakening',
#  'world-of-warcraft-the-war-within',
#  'the-master-chief-collection',
#  'starcraft-ii-nova-covert-ops-mission-pack-1',
#  'spyro-year-of-the-dragon',
#  'dead-rising-3',
#  'icewind-dale',
#  'dead-rising-3-chaos-rising',
#  'mario-and-luigi-dream-team',
#  'fallout-3-broken-steel',
#  'horizon-zero-dawn-the-frozen-wilds',
#  'icewind-dale-heart-of-winter',
#  'code-name-steam',
#  'fire-emblem',
#  'the-last-of-us-left-behind',
#  'starcraft',
#  'golden-sun-the-lost-age',
#  'midnight-club-ii',
#  'eco-shooter-plant-530',
#  'xenoblade-chronicles-3-expansion-pass-wave-4',
#  'world-of-warcraft-battle-for-azeroth',
#  'ratchet-and-clank-ps4',
#  '2002-fifa-world-cup',
#  'xcom-enemy-unknown',
#  'octopath-traveler',
#  'dead-rising-3-fallen-angel',
#  'donkey-kong-country-3-dixie-kongs-double-trouble',
#  'diablo-ii-lord-of-destruction',
#  'deracine',
#  'horizon-zero-dawn',
#  'mass-effect-pinnacle-station',
#  'pokemon-quest',
#  'the-wonderful-101',
#  'starcraft-ii-heart-of-the-swarm',
#  'brain-age-concentration-training',
#  'horizon-zero-dawn-remastered',
#  'the-legend-of-zelda-the-minish-cap',
#  'demons-souls',
#  'hearthstone-heroes-of-warcraft-the-grand',
#  'bayonetta-2',
#  'dragon-quest-vii-fragments-of-the-forgotten-past',
#  'dead-rising-3-the-last-agent',
#  'etrian-odyssey-untold-the-millenium-girl',
#  'wild-arms-3',
#  'world-of-warcraft-mists-of-pandaria',
#  'sid-meiers-simgolf',
#  'shenmue-ii',
#  'advance-wars-2-black-hole-rising',
#  'pillars-of-eternity-complete-edition',
#  'the-elder-scrolls-v-skyrim-dawnguard',
#  'heavy-rain-and-beyond-two-souls-collection',
#  'playstation-all-stars-battle-royale',
#  'fallout-2',
#  'rallisport-challenge',
#  'resident-evil-revelations-collection',
#  'bravely-second',
#  'donkey-kong-country-tropical-freeze',
#  'icewind-dale-ii',
#  'the-elder-scrolls-iii-morrowind',
#  'nascar-thunder-2003',
#  'the-legend-of-zelda-links-awakening',
#  'fire-emblem-three-houses-side-story-cindered',
#  'the-elder-scrolls-v-skyrim-dragonborn',
#  'dungeon-travelers-2-the-royal-library-and-the',
#  'game-builder-garage',
#  'super-mario-rpg',
#  'wargroove',
#  'fire-emblem-fates-special-edition',
#  'disneys-magical-mirror-starring-mickey-mouse',
#  'the-elder-scrolls-v-skyrim-anniversary-edition',
#  'dead-nation-road-of-devastation',
#  'the-elder-scrolls-v-skyrim-vr',
#  'carrion',
#  'mario-vs-donkey-kong-2004',
#  'madden-nfl-2003',
#  'divinity-original-sin-ii',
#  'nascar-2001',
#  'ac-dc-live-rock-band-track-pack',
#  'midnight-club-street-racing',
#  'halo-2-multiplayer-map-pack',
#  'madden-nfl-16',
#  'f1-24',
#  'death-stranding',
#  'fallout-4-far-harbor',
#  'fuser',
#  'killzone-mercenary',
#  'the-legend-of-zelda-echoes-of-wisdom',
#  'ncaa-football-2002',
#  'f1-2002',
#  'drag-x-drive',
#  'banner-of-the-maid',
#  'steamworld-dig-2',
#  'mario-and-luigi-bowsers-inside-story-plus-bowser',
#  'madden-nfl-2001',
#  'splatoon-2-octo-expansion',
#  'star-wars-knights-of-the-old-republic',
#  'mario-vs-donkey-kong-mini-land-mayhem',
#  'super-stardust-delta',
#  'f-zero-maximum-velocity',
#  'gravity-rush-2',
#  'blade-and-soul',
#  'mortal-kombat-1-khaos-reigns',
#  'fallout-4',
#  'death-stranding-2-on-the-beach',
#  'xcom-2',
#  'bayonetta-plus-bayonetta-2',
#  'gears-tactics',
#  'forza-horizon-2-storm-island',
#  'wario-world',
#  'god-of-war-iii-remastered',
#  'mortal-kombat-x',
#  'forza-motorsport-7',
#  'starship-defense',
#  'heroes-of-the-storm',
#  'capcom-vs-snk',
#  'the-legend-of-zelda-majoras-mask-3d',
#  'xcom-chimera-squad',
#  'neverwinter-nights-enhanced-edition',
#  'the-elder-scrolls-v-skyrim-special-edition',
#  'pokemon-white-version',
#  'pillars-of-eternity-ii-deadfire',
#  'splatoon-2',
#  'splatoon',
#  'left-4-dead-2-the-passing',
#  'avadon-the-black-fortress',
#  'etrian-odyssey-iv-legends-of-the-titan',
#  'the-legend-of-zelda-twilight-princess-hd',
#  'chibi-robo-zip-lash',
#  'sine-mora',
#  'persona-4-golden',
#  'killer-instinct-season-3',
#  'marvel-ultimate-alliance-3-the-black-order',
#  'mario-and-luigi-paper-jam',
#  'pokemon-x',
#  'halo-reach-remastered',
#  'sacrifice-2000',
#  'pillars-of-eternity-the-white-march-part-2',
#  'ratchet-and-clank',
#  'dead-space-3',
#  'littlebigplanet-ps-vita',
#  'jak-and-daxter-the-precursor-legacy',
#  'nioh-bloodsheds-end',
#  'jak-ii',
#  'splatoon-3-expansion-pass-wave-2-side-order',
#  'super-smash-bros-ultimate',
#  'mass-effect-3-omega',
#  'fable-the-lost-chapters',
#  'avernum-2-crystal-souls',
#  'horizon-forbidden-west-burning-shores',
#  'the-nioh-collection',
#  'sid-meiers-civilization-v-brave-new-world',
#  'entwined',
#  'ratchet-and-clank-into-the-nexus',
#  'pokemon-scarlet',
#  'etrian-odyssey-2-untold-the-fafnir-knight',
#  'howl',
#  'deadlight',
#  'mario-tennis-power-tour',
#  'silence-of-the-sleep',
#  'mark-of-the-ninja',
#  'etrian-odyssey-nexus',
#  'sid-meiers-civilization-beyond-earth-rising-tide',
#  'forza-horizon-3-hot-wheels',
#  'bravely-default-where-the-fairy-flies',
#  'f1-career-challenge',
#  'madden-nfl-2002',
#  'below',
#  'etrian-odyssey-v-beyond-the-myth',
#  'jagged-alliance-2-unfinished-business',
#  'wave-race-64',
#  'shin-megami-tensei-strange-journey-redux',
#  'mario-tennis-ultra-smash',
#  'valkyria-chronicles-4',
#  'pokemon-conquest',
#  'dark-devotion',
#  'left-4-dead-crash-course',
#  'project-gotham-racing',
#  'forza-motorsport',
#  'paper-mario-color-splash',
#  'forza-horizon-3',
#  'fifa-16',
#  'mass-effect-andromeda',
#  'the-beatles-rock-band',
#  'new-pokemon-snap',
#  'wii-karaoke-u',
#  'street-fighter-v',
#  'fallout-tactics-brotherhood-of-steel',
#  'dragon-age-ii-legacy',
#  'street-fighter-6-years-1-2-fighters-edition',
#  'fossil-fighters-frontier',
#  'gauntlet-2014',
#  'lego-city-undercover',
#  'fallout-3-operation-anchorage',
#  'pokemon-moon',
#  'asherons-call',
#  'ratchet-and-clank-full-frontal-assault',
#  'ncaa-football-2004',
#  'yoshis-new-island',
#  'fable-iii-traitors-keep-quest-pack',
#  'hearthstone-heroes-of-warcraft-whispers-of-the-old',
#  'rise-race-the-future',
#  'soul-sacrifice-delta',
#  'forza-horizon-3-blizzard-mountain',
#  'sid-meiers-civilization-vi-gathering-storm',
#  'persona-5-royal',
#  'dark-cloud',
#  'singstar-queen',
#  'pillars-of-eternity-the-white-march-part-1',
#  'wildermyth',
#  'aidyn-chronicles-the-first-mage',
#  'mario-golf-world-tour',
#  'marathon-2-durandal',
#  'the-messenger',
#  'hearthstone-heroes-of-warcraft-journey-to-ungoro',
#  'half-life-alyx',
#  'astro-bot',
#  'street-fighter-alpha-3',
#  'nioh',
#  'pokken-tournament',
#  'revenge-of-the-savage-planet',
#  'hatsune-miku-project-diva-megamix-plus',
#  'fire-emblem-the-sacred-stones',
#  'dance-central-spotlight',
#  'street-fighter-6',
#  'the-elder-scrolls-blades',
#  'the-last-faith',
#  'bayonetta-origins-cereza-and-the-lost-demon',
#  'yo-kai-watch-2-bony-spirits',
#  'pokemon-violet',
#  'cadence-of-hyrule-crypt-of-the-necrodancer',
#  'street-fighter-x-tekken',
#  'shadow-complex-remastered',
#  'captain-toad-treasure-tracker-special-episode',
#  'mass-effect-legendary-edition',
#  'injustice-gods-among-us',
#  'crash-bandicoot-warped',
#  'guns-up',
#  'rockstar-games-presents-table-tennis',
#  'fable-iii-understone-quest-pack',
#  'd4-dark-dreams-dont-die',
#  'griefhelm',
#  'a-highland-song',
#  'forza-horizon',
#  'the-last-of-us-part-ii-remastered',
#  'mandragora-whispers-of-the-witch-tree',
#  'paper-mario-the-origami-king',
#  'sands-of-destruction',
#  'atv-offroad-fury-2',
#  'infamous-2',
#  'dead-rising-4',
#  'jewel-quest',
#  'driveclub-vr',
#  'super-street-fighter-ii-turbo-revival',
#  'yo-kai-watch-3',
#  'football-manager-2015',
#  'ea-sports-ufc-2',
#  'custom-robo',
#  'kirby-64-the-crystal-shards',
#  'gravity-rush',
#  'fallout-4-vr',
#  'shin-megami-tensei-v',
#  'nioh-2-the-tengus-disciple',
#  'mario-vs-donkey-kong-2-march-of-the-minis',
#  'fifa-soccer-13',
#  'pokken-tournament-dx',
#  'fable-anniversary',
#  'art-style-rotozoa',
#  'ratchet-and-clank-rift-apart',
#  'sid-meiers-civilization-vii',
#  'fallout-new-vegas-lonesome-road',
#  'diablo-iii-eternal-collection',
#  'pharaoh-a-new-era',
#  'amplitude-2003',
#  'cyberpunk-2077',
#  'marvels-spider-man-miles-morales',
#  'pokemon-lets-go-pikachu',
#  'shin-megami-tensei-devil-survivor-2',
#  'hearthstone-heroes-of-warcraft-goblins-vs-gnomes',
#  'top-darts',
#  'gran-turismo-sport',
#  'wii-sports-club',
#  'counter-strike-2',
#  'street-fighter-v-arcade-edition',
#  'pokemon-sword-shield-dual-pack',
#  'until-dawn',
#  'fallout-3-point-lookout',
#  'the-hundred-line-last-defense-academy',
#  'sparc',
#  'nintendo-land',
#  'age-of-empires-ii-the-conquerors-expansion',
#  'game-and-watch-gallery-4',
#  'f1-2021',
#  'kirby-planet-robobot',
#  'here-they-lie',
#  'affogato',
#  'mass-effect-3-leviathan',
#  'guacamelee',
#  'sid-meiers-civilization-vi',
#  'halo-wars-2',
#  'lips-party-classics',
#  'nintendo-switch-sports',
#  'pocket-card-jockey',
#  'forza-motorsport-5',
#  'uncharted-the-nathan-drake-collection',
#  'trials-evolution',
#  'donkey-kong-country',
#  'nfl-2k2',
#  'dungeon-fighter-live-fall-of-hendon-myre',
#  'f1-2001',
#  'ori-and-the-will-of-the-wisps',
#  'fifa-17',
#  'planescape-torment-enhanced-edition',
#  'soul-hackers-2',
#  'breath-of-fire-ii',
#  'forza-horizon-rally-expansion-pack',
#  'splatoon-3',
#  'fitness-boxing-3-your-personal-trainer',
#  'sam-and-max-beyond-time-and-space',
#  'pokemon-lets-go-eevee',
#  'paper-mario',
#  'pillars-of-eternity',
#  'fallout-new-vegas-honest-hearts',
#  'pixeljunk-shooter-2',
#  'the-last-of-us-part-ii',
#  'kirby-fighters-2',
#  'driveclub-bikes',
#  'pokemon-white-version-2',
#  'astral-ascent',
#  'world-of-warcraft-warlords-of-draenor',
#  'capcom-arcade-stadium',
#  'baten-kaitos-origins',
#  'stormland',
#  'sea-of-thieves',
#  'persona-5',
#  'the-elder-scrolls-iii-bloodmoon',
#  'steamworld-dig',
#  'goldeneye-007',
#  'pokemon-omega-ruby',
#  'final-fantasy-vii',
#  'game-of-thrones',
#  'dragon-age-ii-mark-of-the-assassin',
#  'life-is-strange-arcadia-bay-collection',
#  'phoenix-wright-ace-attorney-dual-destinies',
#  'street-fighter-iii-double-impact',
#  'rise-of-the-ronin',
#  'madden-nfl-17',
#  'super-stardust-portable',
#  'persona-2-eternal-punishment',
#  'donkey-kong-country-2-diddys-kong-quest',
#  'capcom-digital-collection',
#  'mario-golf-super-rush',
#  'ncaa-football-2003',
#  'legends-of-eisenwald',
#  'arc-the-lad-twilight-of-the-spirits',
#  'fallout-3-the-pitt',
#  'the-elder-scrolls-iii-tribunal',
#  'nfl-fever-2004',
#  'sly-cooper-collection',
#  'persona-5-the-phantom-x',
#  'panzer-dragoon-orta',
#  'tokyo-crash-mobs',
#  'f1-championship-season-2000',
#  'firewall-ultra',
#  'fifa-soccer-2002',
#  'nfl-fever-2003',
#  'puzzle-and-dragons-z-plus-puzzle-and-dragons-super',
#  'shenmue',
#  'tiger-woods-pga-tour-2005',
#  'everdeep-aurora',
#  'fitness-boxing-2-rhythm-and-exercise',
#  'madden-nfl-25-2013',
#  'inazuma-eleven-3-lightning-bolt',
#  'age-of-mythology-the-titans',
#  'deliver-at-all-costs',
#  'pokemon-pinball-ruby-and-sapphire',
#  'marvel-vs-capcom-infinite',
#  'asherons-call-dark-majesty',
#  'battlefield-1942',
#  'the-quiet-man',
#  'mortal-kombat-11',
#  'triple-play-baseball',
#  'nioh-defiant-honor',
#  'sid-meiers-civilization-vi-rise-and-fall',
#  'batman-arkham-knight',
#  'shin-megami-tensei-iv',
#  'mario-tennis-open',
#  'freedom-force-vs-the-3rd-reich',
#  'tao-feng-fist-of-the-lotus',
#  'mario-vs-donkey-kong',
#  'nintendo-labo-toycon-03-vehicle-kit',
#  'fallout-4-automatron',
#  'pokemon-friends',
#  'dragon-quest-xi-echoes-of-an-elusive-age',
#  'monster-hunter-4-ultimate',
#  'hatsune-miku-project-diva-megamix',
#  'conkers-bad-fur-day',
#  'eve-valkyrie',
#  'kersploosh',
#  'dragons-dogma',
#  'fusion-genesis',
#  'smugglers-run-warzones',
#  'forza-horizon-4',
#  'atv-offroad-fury',
#  'animal-crossing-amiibo-festival',
#  'portal-companion-collection',
#  'diablo-ii',
#  'nascar-thunder-2002',
#  'inmost',
#  'lost-kingdoms-ii',
#  'espn-nfl-football',
#  'attack-of-the-earthlings',
#  'battlefield-2-euro-force',
#  'puppeteer-2013',
#  'fitness-boxing',
#  'wargroove-2',
#  'lococycle',
#  'f1-25',
#  'littlebigplanet-3',
#  'feudal-alloy',
#  'football-manager-2018',
#  'kinect-rush-a-disney-pixar-adventure',
#  'persona-q-shadow-of-the-labyrinth',
#  'medal-of-honor-allied-assault-breakthrough',
#  'sid-meiers-civilization-beyond-earth',
#  'madden-nfl-15',
#  'mvp-baseball-2004',
#  'nier-automata',
#  'kirby-star-allies',
#  'tyranny-bastards-wound',
#  'the-elder-scrolls-v-skyrim-hearthfire',
#  'daxter',
#  'pokemon-ultra-moon',
#  'starfield-shattered-space',
#  'the-lions-song',
#  'pokemon-legends-arceus',
#  'mega-man-x6',
#  'fifa-18',
#  'fallout-new-vegas-old-world-blues',
#  'breath-of-fire-dragon-quarter',
#  'pokemon-shield',
#  'ryse-son-of-rome',
#  'kingdoms-of-amalur-reckoning-the-legend-of-dead',
#  'good-job',
#  'the-tomorrow-children',
#  '1503-a-d-the-new-world',
#  'heavy-rain',
#  'fluidity',
#  'fallout-4-nuka-world',
#  'super-smash-bros',
#  'another-code-r-a-journey-into-lost-memories',
#  'fallout-76',
#  'blood-1997',
#  'castlevania-aria-of-sorrow',
#  'infernax',
#  'flip-wars',
#  'yo-kai-watch',
#  'mass-effect-3-citadel',
#  'metroid-prime-federation-force',
#  'mario-and-luigi-superstar-saga-plus-bowsers',
#  'metroid-prime-remastered',
#  'might-and-magic-clash-of-heroes',
#  'fable-the-journey',
#  'grid-legends',
#  'football-manager-live',
#  'sid-meiers-antietam',
#  'mortal-kombat-xl',
#  'pokemon-sun',
#  'football-manager-2014',
#  'ashen',
#  'age-of-empires-iii-the-asian-dynasties',
#  'shuffle-tactics',
#  'fifa-2001-major-league-soccer',
#  'ori-and-the-blind-forest-definitive-edition',
#  'yo-kai-watch-2-psychic-specters',
#  'gris',
#  'frozen-synapse',
#  'slime-rancher',
#  'total-war-three-kingdoms-a-world-betrayed',
#  'guacamelee-super-turbo-championship-edition',
#  'professor-layton-and-the-miracle-mask',
#  'detroit-become-human',
#  'pokemon-ultra-sun',
#  'teenage-mutant-ninja-turtles-tactical-takedown',
#  'superbike-2001',
#  'mortal-shell',
#  'fluidity-spin-cycle',
#  'quake-iii-arena-1999',
#  'pokemon-sword',
#  'the-keep',
#  'halo-infinite',
#  'melbits-world',
#  'shovel-knight-dig',
#  'asherons-call-2-fallen-kings',
#  'jojos-bizarre-adventure-hd-ver',
#  'ea-sports-wrc',
#  'heavy-rain-move-edition',
#  'total-war-warhammer-iii',
#  'grapple-dogs-cosmic-canines',
#  'professor-layton-and-the-azran-legacy',
#  'okage-shadow-king',
#  'laika-aged-through-blood',
#  'disney-pixar-monsters-inc-2002',
#  'sing-party',
#  'suikoden-iii',
#  'resogun-heroes',
#  'halfway',
#  'freakyforms-deluxe-your-creations-alive',
#  'crimson-dragon',
#  'lips-number-one-hits',
#  'dead-rising-4-franks-big-package',
#  'donkey-kong-64',
#  'forza-horizon-2',
#  'dance-central-3',
#  'football-manager-2011',
#  'pokemon-puzzle-league',
#  'miitopia',
#  'pushmo-world',
#  'shadow-warrior-3',
#  'inside',
#  'cast-of-the-seven-godsends',
#  'the-typing-of-the-dead-overkill',
#  'risk-of-rain',
#  'capcom-arcade-2nd-stadium',
#  'devil-may-cry-3-special-edition',
#  'wizardry-tale-of-the-forsaken-land',
#  'batman-return-to-arkham',
#  'pokemon-y',
#  'spelunky',
#  'gato-roboto',
#  'motorstorm',
#  'banjo-kazooie',
#  'fifa-15',
#  'mario-tennis',
#  'smugglers-run',
#  'fallout-76-wastelanders',
#  'persona-4-arena-ultimax',
#  'bound-2016',
#  'total-war-three-kingdoms-the-furious-wild',
#  'perfect-dark-2000',
#  'shin-megami-tensei-devil-summoner-soul-hackers',
#  'paradise-cracked',
#  'nhl-23',
#  'romancing-saga-minstrel-song-remastered',
#  'f1-22',
#  'mass-effect-3-from-ashes',
#  'quake-iii-revolution',
#  'nintendo-labo-toycon-01-variety-kit',
#  'football-manager-2020',
#  'shovel-knight-king-of-cards',
#  'distraint',
#  'metal-slug-tactics',
#  'the-legendary-starfy',
#  'final-fantasy-xvi-the-rising-tide',
#  'shin-megami-tensei-iv-apocalypse',
#  'fallout-new-vegas-dead-money',
#  'ctr-crash-team-racing',
#  'football-manager-2012',
#  'rare-replay',
#  'pokemon-ruby-version',
#  'eyetoy-antigrav',
#  'testament-the-order-of-high-human',
#  'wipeout-omega-collection',
#  'gravity-rush-remastered',
#  'dragon-quest-ii',
#  'style-savvy-fashion-forward',
#  'stretchmo',
#  'battlefield-1942-the-road-to-rome',
#  'dyad-2012',
#  'witcheye',
#  'frequency',
#  'pocket-rumble',
#  'dex',
#  'pokemon-ranger',
#  'nintendo-labo-toycon-02-robot-kit',
#  'nuclear-dawn',
#  'bayonetta-and-vanquish',
#  'pikmin-3-deluxe',
#  'sea-of-stars-throes-of-the-watchmaker',
#  'donkey-kong-country-returns-hd',
#  'airblade',
#  'mega-man-battle-network-2',
#  '1-2-switch',
#  'street-fighter-v-champion-edition',
#  'ultimate-marvel-vs-capcom-3',
#  'football-manager-2010',
#  'the-muppets-movie-adventures',
#  'kirby-fighters-deluxe',
#  'middle-earth-shadow-of-mordor',
#  'kingdom-under-fire-heroes',
#  'pokemon-brilliant-diamond',
#  'madden-nfl-2004',
#  'dark-souls-iii',
#  'super-robot-taisen-original-generation-2',
#  'gran-turismo-6',
#  'guacamelee-gold-edition',
#  'lushfoil-photography-sim',
#  'grand-slam-tennis-2',
#  'kunai',
#  'the-outer-worlds',
#  'astros-playroom',
#  'capcom-beat-em-up-bundle',
#  'total-war-warhammer-ii-curse-of-the-vampire-coast',
#  'elden-ring',
#  'forza-horizon-2-presents-fast-and-furious',
#  'broforce',
#  'madden-nfl-21',
#  'nfl-fever-2002',
#  'the-elder-scrolls-iv-oblivion-remastered',
#  'personal-trainer-cooking',
#  'resogun-defenders',
#  'road-rash-jailbreak',
#  'pokemon-shining-pearl',
#  'devil-may-cry-4-special-edition',
#  'smugglers-run-2-hostile-territory',
#  'god-of-war-ragnarok',
#  'surfing-h3o',
#  'mickeys-speedway-usa',
#  'mafia-ii-joes-adventures',
#  'age-of-mythology',
#  'triangle-strategy',
#  'the-world-ends-with-you-final-remix',
#  'halo-5-guardians',
#  'super-smash-bros-melee',
#  'final-fantasy-xvi-echoes-of-the-fallen',
#  'donkey-konga-2',
#  'mario-kart-super-circuit',
#  'wipeout-hd-fury',
#  'rise-of-the-tomb-raider-20-year-celebration',
#  'total-war-rome-ii-caesar-in-gaul',
#  'skelattack',
#  'life-is-strange-remastered-collection',
#  'dark-cloud-2',
#  'devil-may-cry',
#  'capcom-fighting-collection-2',
#  'kirby-and-the-rainbow-curse',
#  'front-mission-4',
#  'shin-megami-tensei-devil-survivor-overclocked',
#  'mace-griffin-bounty-hunter',
#  'age-of-empires',
#  'look-outside',
#  'shovel-knight-showdown',
#  'mario-golf-toadstool-tour',
#  'kings-field-the-ancient-city',
#  'the-church-in-the-darkness',
#  'loco-motive',
#  'persona-4-arena',
#  'nfl-2k3',
#  'nintendo-labo-toycon-04-vr-kit',
#  'midtown-madness-3',
#  'monster-hunter-rise-sunbreak',
#  'shin-megami-tensei-v-vengeance',
#  'ultra-street-fighter-iv',
#  'snipperclips-plus-cut-it-out-together',
#  'inazuma-eleven-3-sekai-e-no-chousen-the-ogre',
#  'persona-3-reload',
#  'uncharted-legacy-of-thieves-collection',
#  'blazblue-continuum-shift-extend',
#  'ghost-of-tsushima-iki-island',
#  'microsoft-flight-simulator-2004-a-century-of-flig',
#  'american-mcgees-alice',
#  'wipeout-xl',
#  'nhl-2001',
#  'final-fantasy-xi',
#  'starbound',
#  'middle-earth-shadow-of-mordor-the-bright-lord',
#  'shox',
#  'nier-automata-become-as-gods-edition',
#  'one-finger-death-punch-2',
#  'killzone-shadow-fall-intercept',
#  'nintendo-switch-2-welcome-tour',
#  'world-of-final-fantasy-maxima',
#  'momodora-reverie-under-the-moonlight',
#  'dededes-drum-dash-deluxe',
#  'ultra-street-fighter-ii-the-final-challengers',
#  'until-dawn-rush-of-blood',
#  'style-savvy-styling-star',
#  'soul-sacrifice',
#  'a-r-e-s-extinction-agenda-ex',
#  'breath-of-fire-iv',
#  'dust-an-elysian-tail',
#  'wheel-world',
#  'forza-horizon-5-rally-adventure',
#  'starcraft-64',
#  'nhl-2k2',
#  'rushn-attack-ex-patriot',
#  'kirbys-adventure',
#  'monster-hunter-stories',
#  'mario-tennis-aces',
#  'lovecrafts-untold-stories-2',
#  'final-fantasy-tactics-advance',
#  'shin-megami-tensei-digital-devil-saga-2',
#  'prey',
#  'football-manager-classic-2014',
#  'dungeon-siege',
#  'jak-and-daxter-collection',
#  'trials-evolution-origin-of-pain',
#  'worldwide-soccer-manager-2009',
#  'dead-space-3-awakened',
#  'clive-barkers-undying',
#  'mario-golf',
#  'professor-layton-vs-ace-attorney',
#  'guild-wars-2-end-of-dragons',
#  'kirby-and-the-forgotten-land',
#  'dirt-4',
#  'sid-meiers-civilization-v-gods-and-kings',
#  'timespinner',
#  'monster-hunter-3-ultimate',
#  'fat-princess-adventures',
#  'killzone-shadow-fall',
#  'persona-q2-new-cinema-labyrinth',
#  'murakumo-renegade-mech-pursuit',
#  'nhl-25',
#  'the-witcher-3-wild-hunt',
#  'guild-wars-2',
#  'spelunker-party',
#  'infamous-first-light',
#  'ninja-gaiden-3-razor-s-edge',
#  'nfl-gameday-2001',
#  'jetpac-refuelled',
#  'nascar-thunder-2004',
#  'the-legend-of-dragoon',
#  'shadow-of-the-colossus',
#  'max-payne-3',
#  'the-witcher-2-assassins-of-kings',
#  'ghost-of-tsushima-directors-cut',
#  'football-manager-2017',
#  'the-last-guardian',
#  'the-last-remnant-remastered',
#  'monster-boy-and-the-cursed-kingdom',
#  'guacamelee-2',
#  'crashmo',
#  'shin-megami-tensei-devil-survivor-2-record-breaker',
#  'tiny-terrys-turbo-trip',
#  'world-of-final-fantasy',
#  'crackdown-3',
#  'sleeping-dogs-definitive-edition',
#  '140',
#  'injustice-gods-among-us-ultimate-edition',
#  'age-of-empires-ii-the-age-of-kings',
#  'football-manager-touch-2018',
#  'mega-man-x5',
#  'gt-legends',
#  'firewall-zero-hour',
#  'grapple-dog',
#  'gunbrella',
#  'part-time-ufo',
#  'dead-rising-2-off-the-record',
#  'gran-turismo',
#  'shovel-knight',
#  'monster-hunter-rise',
#  'datura',
#  'ridge-racer-64',
#  'dungeon-hearts',
#  'lost-judgment-the-kaito-files',
#  'fossil-fighters',
#  'anger-foot',
#  'super-mario-party-jamboree-nintendo-switch-2',
#  'dual-hearts',
#  'star-trucker',
#  'the-secrets-of-da-vinci-the-forbidden-manuscript',
#  'orwell',
#  'cyber-shadow',
#  'prince-of-qin',
#  'marvels-guardians-of-the-galaxy',
#  'ncaa-college-football-2k2-road-to-the-rose-bowl',
#  'tomb-raider',
#  'nhl-2003',
#  'total-war-attila',
#  'project-zero-2-wii-edition',
#  'inazuma-eleven-3-bomb-blast',
#  'star-fox-guard',
#  'syndicate-2012',
#  'super-t-i-m-e-force',
#  'resident-evil-chronicles-hd-collection',
#  'pokemon-black-version-2',
#  'the-lost-chronicles-of-zerzura',
#  'apollo-justice-ace-attorney-trilogy',
#  'battleblock-theater',
#  'uncharted-fight-for-fortune',
#  'astral-chain',
#  'art-academy-lessons-for-everyone',
#  'kirbys-return-to-dream-land-deluxe',
#  'football-manager-2019',
#  'popeye-rush-for-spinach',
#  'art-style-light-trax',
#  'age-of-mythology-extended-edition',
#  'star-fox-adventures',
#  'lost-sphear',
#  'nhl-24',
#  'company-of-heroes-2-the-western-front-armies',
#  ...]
