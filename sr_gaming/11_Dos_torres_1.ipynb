# %%
import os
# os.environ["KERAS_BACKEND"] = "jax" # TensorFlow
os.environ["KERAS_BACKEND"] = "tensorflow" # TensorFlow


import keras
from keras.saving import register_keras_serializable
import tensorflow as tf
import sqlite3
import pandas as pd
import pickle
import numpy as np

# %% [markdown]
# # Datos

# %%
conn = sqlite3.connect('sr_gaming/datos/metacritics.db')

df_scores = pd.read_sql("SELECT id_usuario, id_juego, score FROM interacciones WHERE score > 0", conn)
df_scores.head()
# Out:
#              id_usuario        id_juego  score
# 0  attack-of-the-fanboy  baldurs-gate-3    100
# 1            gamesradar  baldurs-gate-3    100
# 2           gamingtrend  baldurs-gate-3    100
# 3               ggrecon  baldurs-gate-3    100
# 4               gfinity  baldurs-gate-3    100

# %%
# diccionarios de traducción
# Para id de usuario se pasa a un num entero incluyendo todas las variables categorícas
# Para que funcionen en Red Neuronal de Tensor Flow
unique_user_id = df_scores["id_usuario"].unique().tolist()
user_id_2_id_mapping = {t: i for i, t in enumerate(unique_user_id)}
id_2_user_user_mapping = {user_id_2_id_mapping[k]: k for k in user_id_2_id_mapping}

unique_item_id = df_scores["id_juego"].unique().tolist()
item_id_2_id_mapping = {t: i for i, t in enumerate(unique_item_id)}
id_2_item_id_mapping = {item_id_2_id_mapping[k]: k for k in item_id_2_id_mapping}

mappings = {
    "user_id_2_id": user_id_2_id_mapping,
    "id_2_user_id": id_2_user_user_mapping,
    "item_id_2_id": item_id_2_id_mapping,
    "id_2_item_id": id_2_item_id_mapping,
}

with open("sr_gaming/datos/mappings_dt.pkl", "wb") as f:
    pickle.dump(mappings, f)

# %%
id_2_item_id_mapping
# Out:
# {0: 'baldurs-gate-3',
#  1: 'bioshock',
#  2: 'goldeneye-007',
#  3: 'grand-theft-auto-iii',
#  4: 'grand-theft-auto-iv',
#  5: 'grand-theft-auto-v',
#  6: 'half-life-2',
#  7: 'halo-combat-evolved',
#  8: 'mass-effect-2',
#  9: 'metroid-prime',
#  10: 'nfl-2k1',
#  11: 'perfect-dark-2000',
#  12: 'red-dead-redemption-2',
#  13: 'resident-evil-4-2005',
#  14: 'soulcalibur',
#  15: 'super-mario-galaxy',
#  16: 'super-mario-galaxy-2',
#  17: 'super-mario-odyssey',
#  18: 'tekken-3',
#  19: 'the-legend-of-zelda-breath-of-the-wild',
#  20: 'the-legend-of-zelda-ocarina-of-time',
#  21: 'the-orange-box',
#  22: 'tony-hawks-pro-skater-3',
#  23: 'uncharted-2-among-thieves',
#  24: 'baldurs-gate-ii-shadows-of-amn',
#  25: 'elden-ring',
#  26: 'gran-turismo',
#  27: 'gran-turismo-3-a-spec',
#  28: 'grand-theft-auto-double-pack',
#  29: 'grand-theft-auto-san-andreas',
#  30: 'grand-theft-auto-vice-city',
#  31: 'half-life',
#  32: 'halo-2',
#  33: 'littlebigplanet',
#  34: 'madden-nfl-2003',
#  35: 'metal-gear-solid-2-sons-of-liberty',
#  36: 'portal-companion-collection',
#  37: 'the-elder-scrolls-v-skyrim',
#  38: 'the-house-in-fata-morgana-dreams-of-the-revenants',
#  39: 'the-last-of-us',
#  40: 'the-legend-of-zelda-a-link-to-the-past-four-swords',
#  41: 'the-legend-of-zelda-breath-of-the-wild-nintendo',
#  42: 'the-legend-of-zelda-collectors-edition',
#  43: 'the-legend-of-zelda-majoras-mask',
#  44: 'the-legend-of-zelda-tears-of-the-kingdom',
#  45: 'the-legend-of-zelda-tears-of-the-kingdom-nintendo',
#  46: 'the-legend-of-zelda-the-wind-waker',
#  47: 'the-legend-of-zelda-twilight-princess',
#  48: 'astro-bot',
#  49: 'batman-arkham-city',
#  50: 'bioshock-infinite',
#  51: 'call-of-duty-4-modern-warfare',
#  52: 'chrono-cross',
#  53: 'devil-may-cry',
#  54: 'elden-ring-shadow-of-the-erdtree',
#  55: 'final-fantasy-ix',
#  56: 'gears-of-war',
#  57: 'god-of-war',
#  58: 'halo-3',
#  59: 'madden-nfl-2002',
#  60: 'madden-nfl-2004',
#  61: 'metaphor-refantazio',
#  62: 'metroid-prime-remastered',
#  63: 'persona-5-royal',
#  64: 'portal-2',
#  65: 'quake',
#  66: 'red-dead-redemption',
#  67: 'sid-meiers-civilization-ii',
#  68: 'the-elder-scrolls-iv-oblivion',
#  69: 'the-last-of-us-remastered',
#  70: 'the-legend-of-zelda-ocarina-of-time-3d',
#  71: 'tony-hawks-pro-skater-4',
#  72: 'burnout-3-takedown',
#  73: 'call-of-duty-modern-warfare-2',
#  74: 'company-of-heroes',
#  75: 'diablo',
#  76: 'god-of-war-2005',
#  77: 'god-of-war-ragnarok',
#  78: 'gran-turismo-2',
#  79: 'grand-theft-auto-chinatown-wars',
#  80: 'grim-fandango',
#  81: 'jet-set-radio-2000',
#  82: 'metal-gear-solid',
#  83: 'metal-gear-solid-3-subsistence',
#  84: 'metal-gear-solid-4-guns-of-the-patriots',
#  85: 'ninja-gaiden-black',
#  86: 'pac-man-championship-edition-dx',
#  87: 'resident-evil-code-veronica',
#  88: 'sid-meiers-civilization-iv',
#  89: 'star-wars-knights-of-the-old-republic',
#  90: 'super-mario-advance-4-super-mario-bros-3',
#  91: 'super-smash-bros-brawl',
#  92: 'the-last-of-us-part-ii',
#  93: 'tom-clancys-splinter-cell-chaos-theory',
#  94: 'tom-clancys-splinter-cell-pandora-tomorrow',
#  95: 'virtua-fighter-4',
#  96: 'braid',
#  97: 'discounty',
#  98: 'divinity-original-sin-ii',
#  99: 'dwarf-fortress',
#  100: 'fallout-3',
#  101: 'gears-of-war-2',
#  102: 'god-of-war-ii',
#  103: 'half-life-alyx',
#  104: 'herdling',
#  105: 'homeworld',
#  106: 'kill-the-brickman',
#  107: 'mafia-the-old-country',
#  108: 'mass-effect-3',
#  109: 'metal-gear-solid-delta-snake-eater',
#  110: 'metal-gear-solid-v-the-phantom-pain',
#  111: 'minecraft',
#  112: 'okami',
#  113: 'persona-4-golden',
#  114: 'persona-5',
#  115: 'pro-evolution-soccer-2',
#  116: 'quake-iii-arena-1999',
#  117: 'shinobi-art-of-vengeance',
#  118: 'soulcalibur-ii',
#  119: 'ssx-2000',
#  120: 'ssx-3',
#  121: 'starcraft-ii-wings-of-liberty',
#  122: 'story-of-seasons-grand-bazaar',
#  123: 'street-fighter-iv',
#  124: 'super-mario-3d-world',
#  125: 'sword-of-the-sea',
#  126: 'the-rogue-prince-of-persia',
#  127: 'tom-clancys-splinter-cell',
#  128: 'unreal-tournament-2004',
#  129: 'clair-obscur-expedition-33',
#  130: 'flipnote-studio',
#  131: 'forza-horizon-4',
#  132: 'god-of-war-iii',
#  133: 'hades',
#  134: 'inside',
#  135: 'mario-kart-super-circuit',
#  136: 'nba-2k1',
#  137: 'nfl-2k3',
#  138: 'nhl-2002',
#  139: 'paper-mario',
#  140: 'prince-of-persia-the-sands-of-time',
#  141: 'resident-evil-4',
#  142: 'rock-band-3',
#  143: 'skies-of-arcadia',
#  144: 'ssx-tricky',
#  145: 'super-smash-bros-ultimate',
#  146: 'the-legend-of-zelda-skyward-sword',
#  147: 'uncharted-4-a-thiefs-end',
#  148: 'viewtiful-joe',
#  149: 'virtua-fighter-4-evolution',
#  150: 'wipeout-xl',
#  151: 'world-of-warcraft',
#  152: 'world-soccer-winning-eleven-7-international',
#  153: 'advance-wars',
#  154: 'banjo-kazooie',
#  155: 'bloodborne',
#  156: 'celeste',
#  157: 'espn-nfl-2k5',
#  158: 'eternal-darkness-sanitys-requiem',
#  159: 'final-fantasy-vii-rebirth',
#  160: 'final-fantasy-xii',
#  161: 'forza-horizon-5',
#  162: 'forza-motorsport-2005',
#  163: 'rock-band',
#  164: 'sid-meiers-gettysburg',
#  165: 'street-fighter-6',
#  166: 'super-mario-bros-wonder',
#  167: 'super-mario-world-super-mario-advance-2',
#  168: 'super-smash-bros-melee',
#  169: 'system-shock-2',
#  170: 'team-fortress-2',
#  171: 'the-sims',
#  172: 'the-witcher-3-wild-hunt',
#  173: 'uncharted-3-drakes-deception',
#  174: 'vagrant-story',
#  175: 'warcraft-iii-reign-of-chaos',
#  176: 'xenoblade-chronicles-3-expansion-pass-wave-4',
#  177: 'age-of-empires-ii-the-age-of-kings',
#  178: 'batman-arkham-asylum',
#  179: 'blue-prince',
#  180: 'chrono-trigger',
#  181: 'conkers-bad-fur-day',
#  182: 'demons-souls',
#  183: 'divinity-original-sin-ii-definitive-edition',
#  184: 'final-fantasy-vii',
#  185: 'final-fantasy-x',
#  186: 'final-fantasy-xiv-endwalker',
#  187: 'fire-emblem-awakening',
#  188: 'forza-motorsport-3',
#  189: 'galactic-civilizations-ii-twilight-of-the-arnor',
#  190: 'guitar-hero-ii',
#  191: 'journey',
#  192: 'rome-total-war',
#  193: 'sid-meiers-alpha-centauri',
#  194: 'super-mario-sunshine',
#  195: 'super-smash-bros-for-nintendo-3ds-wii-u',
#  196: 'thief-the-dark-project',
#  197: 'tony-hawks-pro-skater',
#  198: 'undertale',
#  199: 'virtua-tennis',
#  200: 'wave-race-64',
#  201: 'against-the-storm',
#  202: 'baldurs-gate',
#  203: 'final-fantasy-vi',
#  204: 'guitar-hero',
#  205: 'i-was-a-teenage-exocolonist',
#  206: 'littlebigplanet-2',
#  207: 'madden-nfl-2001',
#  208: 'madden-nfl-2005',
#  209: 'mario-kart-8-deluxe',
#  210: 'medal-of-honor-allied-assault',
#  211: 'metroid-fusion',
#  212: 'metroid-prime-2-echoes',
#  213: 'metroid-prime-trilogy',
#  214: 'microsoft-flight-simulator',
#  215: 'myth-the-fallen-lords',
#  216: 'out-of-the-park-baseball-17',
#  217: 'rayman-legends',
#  218: 'rock-band-2',
#  219: 'slay-the-princess-the-pristine-cut',
#  220: 'the-ico-and-shadow-of-the-colossus-collection',
#  221: 'the-witcher-3-wild-hunt-blood-and-wine',
#  222: 'ufo-50',
#  223: 'world-of-warcraft-wrath-of-the-lich-king',
#  224: 'bayonetta-2',
#  225: 'colony-wars',
#  226: 'crysis',
#  227: 'doa2-hardcore',
#  228: 'dragon-quest-xi-s-echoes-of-an-elusive-age',
#  229: 'f1-challenge-99-02',
#  230: 'forza-horizon-3',
#  231: 'freespace-2',
#  232: 'god-of-war-chains-of-olympus',
#  233: 'il-2-sturmovik',
#  234: 'kentucky-route-zero-act-iii',
#  235: 'klonoa-2-lunateas-veil',
#  236: 'mario-tennis',
#  237: 'metal-gear-solid-3-snake-eater',
#  238: 'ncaa-football-2003',
#  239: 'ninja-gaiden-2004',
#  240: 'ratchet-and-clank-up-your-arsenal',
#  241: 'resident-evil-remake',
#  242: 'spyro-year-of-the-dragon',
#  243: 'the-legend-of-zelda-ocarina-of-time-master-quest-2002',
#  244: 'tomb-raider-1996',
#  245: 'twisted-metal-black',
#  246: 'world-of-warcraft-the-burning-crusade',
#  247: 'battlefield-2',
#  248: 'castlevania-aria-of-sorrow',
#  249: 'crusader-kings-iii',
#  250: 'espn-nfl-football',
#  251: 'forza-motorsport-4',
#  252: 'galactic-civilizations-ii-dark-avatar',
#  253: 'gears-of-war-3',
#  254: 'god-of-war-collection',
#  255: 'halo-reach',
#  256: 'killzone-2',
#  257: 'mass-effect',
#  258: 'mlb-10-the-show',
#  259: 'neverwinter-nights',
#  260: 'no-one-lives-forever-2-a-spy-in-h-a-r-m-s-way',
#  261: 'planescape-torment',
#  262: 'resident-evil',
#  263: 'resident-evil-3-nemesis',
#  264: 'shadow-of-the-colossus',
#  265: 'split-fiction',
#  266: 'star-wars-jedi-knight-dark-forces-ii',
#  267: 'the-longest-journey',
#  268: 'the-operative-no-one-lives-forever',
#  269: 'tony-hawks-pro-skater-2',
#  270: 'yoshis-island-super-mario-advance-3',
#  271: 'animal-crossing-new-horizons',
#  272: 'animal-well',
#  273: 'assassins-creed-ii',
#  274: 'balatro',
#  275: 'call-of-duty',
#  276: 'castlevania-circle-of-the-moon',
#  277: 'caves-of-qud',
#  278: 'crash-bandicoot-warped',
#  279: 'dark-souls-ii',
#  280: 'disco-elysium',
#  281: 'donkey-kong-bananza',
#  282: 'final-fantasy-xiv-shadowbringers',
#  283: 'golden-sun',
#  284: 'legacy-of-kain-soul-reaver',
#  285: 'mario-golf',
#  286: 'mario-kart-ds',
#  287: 'nier-automata-game-of-the-yorha-edition',
#  288: 'project-gotham-racing-2',
#  289: 'resident-evil-2',
#  290: 'satisfactory',
#  291: 'shovel-knight-treasure-trove',
#  292: 'the-legend-of-zelda-a-link-between-worlds',
#  293: 'the-sims-2',
#  294: 'world-soccer-winning-eleven-8-international',
#  295: 'ape-escape',
#  296: 'bayonetta',
#  297: 'black-and-white',
#  298: 'diablo-iii-ultimate-evil-edition',
#  299: 'factorio',
#  300: 'fifa-soccer-10',
#  301: 'fifa-soccer-12',
#  302: 'grand-theft-auto-iv-the-lost-and-damned',
#  303: 'ico',
#  304: 'mario-and-luigi-bowsers-inside-story',
#  305: 'mario-and-luigi-superstar-saga',
#  306: 'marvels-spider-man-2',
#  307: 'nba-street-vol-2',
#  308: 'portal',
#  309: 'ratchet-and-clank-going-commando',
#  310: 'slay-the-princess',
#  311: 'syphon-filter',
#  312: 'the-legend-of-zelda-phantom-hourglass',
#  313: 'the-legend-of-zelda-the-wind-waker-hd',
#  314: 'tom-clancys-ghost-recon-advanced-warfighter',
#  315: 'tony-hawks-underground',
#  316: 'trials-evolution',
#  317: 'world-of-goo',
#  318: 'world-of-warcraft-cataclysm',
#  319: 'advance-wars-dual-strike',
#  320: 'blast-corps',
#  321: 'dance-dance-revolution',
#  322: 'deus-ex',
#  323: 'donkey-kong-64',
#  324: 'half-life-2-episode-two',
#  325: 'hollow-knight',
#  326: 'jack-jeanne',
#  327: 'jak-and-daxter-the-precursor-legacy',
#  328: 'mlb-09-the-show',
#  329: 'mlb-11-the-show',
#  330: 'mvp-baseball-2004',
#  331: 'ncaa-football-2002',
#  332: 'nhl-2001',
#  333: 'nier-automata-become-as-gods-edition',
#  334: 'ori-and-the-will-of-the-wisps',
#  335: 'panzer-dragoon-orta',
#  336: 'portal-still-alive',
#  337: 'shin-megami-tensei-persona-4',
#  338: 'sid-meiers-civilization-iii',
#  339: 'star-wars-rogue-leader-rogue-squadron-ii',
#  340: 'stephens-sausage-roll',
#  341: 'tsukihime-a-piece-of-blue-glass-moon',
#  342: 'wwf-smackdown-2-know-your-role',
#  343: 'chained-echoes',
#  344: 'dave-the-diver',
#  345: 'dead-space-2',
#  346: 'dota-2',
#  347: 'falcon-4-0-allied-force',
#  348: 'flight-simulator-2002',
#  349: 'forza-motorsport-2',
#  350: 'geometry-wars-retro-evolved-2',
#  351: 'guild-wars-2',
#  352: 'limbo',
#  353: 'mario-kart-8-dlc-pack-2',
#  354: 'mark-of-the-ninja',
#  355: 'metroid-prime-3-corruption',
#  356: 'monster-hunter-world',
#  357: 'okami-hd',
#  358: 'pikmin-2',
#  359: 'sid-meiers-civilization-v',
#  360: 'silent-hunter-iii',
#  361: 'super-mario-3d-land',
#  362: 'super-meat-boy',
#  363: 'the-last-of-us-part-ii-remastered',
#  364: 'the-stanley-parable-ultra-deluxe',
#  365: 'timesplitters-2',
#  366: 'astro-bot-rescue-mission',
#  367: 'bayonetta-plus-bayonetta-2',
#  368: 'beetle-adventure-racing',
#  369: 'borderlands-2',
#  370: 'chicory-a-colorful-tale',
#  371: 'command-and-conquer-red-alert',
#  372: 'empire-total-war',
#  373: 'fifa-soccer-13',
#  374: 'final-fantasy-viii',
#  375: 'freedom-force',
#  376: 'gtr-2',
#  377: 'halo-2-multiplayer-map-pack',
#  378: 'into-the-breach',
#  379: 'kentucky-route-zero-act-iv',
#  380: 'nba-2k12',
#  381: 'neon-white',
#  382: 'pushmo',
#  383: 'sekiro-shadows-die-twice',
#  384: 'shin-megami-tensei-persona-3-portable',
#  385: 'star-wars-jedi-knight-ii-jedi-outcast',
#  386: 'tekken-8',
#  387: 'the-witcher-3-wild-hunt-hearts-of-stone',
#  388: 'total-war-shogun-2',
#  389: 'wipeout-hd-fury',
#  390: 'age-of-mythology',
#  391: 'burnout-revenge',
#  392: 'call-of-duty-2',
#  393: 'castlevania-symphony-of-the-night',
#  394: 'dead-cells',
#  395: 'demons-souls-2009',
#  396: 'despelote',
#  397: 'dragon-quest-viii-journey-of-the-cursed-king',
#  398: 'fable-ii',
#  399: 'fallout',
#  400: 'final-fantasy-chronicles',
#  401: 'metroid-zero-mission',
#  402: 'monster-hunter-world-iceborne',
#  403: 'nhl-2k3',
#  404: 'pikmin',
#  405: 'pillars-of-eternity',
#  406: 'rez',
#  407: 'rez-infinite',
#  408: 'sacrifice-2000',
#  409: 'the-legend-of-zelda-majoras-mask-3d',
#  410: 'the-walking-dead-a-telltale-games-series',
#  411: 'tiger-woods-pga-tour-2004',
#  412: 'wipeout-3',
#  413: 'xenoblade-chronicles-definitive-edition',
#  414: 'assassins-creed-brotherhood',
#  415: 'dark-souls',
#  416: 'dark-souls-iii',
#  417: 'death-stranding-2-on-the-beach',
#  418: 'f-zero-gx',
#  419: 'grand-theft-auto-iv-the-ballad-of-gay-tony',
#  420: 'gunstar-heroes',
#  421: 'jade-empire',
#  422: 'left-4-dead',
#  423: 'left-4-dead-2',
#  424: 'nascar-racing-2002-season',
#  425: 'nba-2k3',
#  426: 'nba-street-v3',
#  427: 'need-for-speed-hot-pursuit-2',
#  428: 'phantasy-star-online',
#  429: 'pizza-tower',
#  430: 'slay-the-spire',
#  431: 'super-mario-3d-world-plus-bowsers-fury',
#  432: 'tekken-2',
#  433: 'thank-goodness-youre-here',
#  434: 'the-talos-principle-reawakened',
#  435: 'titanfall-2',
#  436: 'worldwide-soccer-manager-2005',
#  437: 'xenoblade-chronicles-3',
#  438: 'ace-combat-04-shattered-skies',
#  439: 'atari-50-the-anniversary-celebration',
#  440: 'cave-story',
#  441: 'combat-mission-barbarossa-to-berlin',
#  442: 'cyberpunk-2077-phantom-liberty',
#  443: 'dead-space',
#  444: 'fez',
#  445: 'final-fantasy-vii-remake-intergrade',
#  446: 'fire-emblem-three-houses',
#  447: 'football-manager-handheld',
#  448: 'guild-wars',
#  449: 'hollow-knight-voidheart-edition',
#  450: 'homeworld-cataclysm',
#  451: 'kynseed',
#  452: 'max-payne',
#  453: 'ncaa-football-2004',
#  454: 'nier-automata-the-end-of-yorha-edition',
#  455: 'out-of-the-park-baseball-15',
#  456: 'streets-of-rage-2',
#  457: 'tetris-effect',
#  458: 'the-legend-of-zelda-the-minish-cap',
#  459: 'the-walking-dead-episode-5-no-time-left',
#  460: 'world-in-conflict',
#  461: 'world-soccer-winning-eleven-9',
#  462: 'apex-legends',
#  463: 'battlefield-1942',
#  464: 'battlefield-3',
#  465: 'castlevania-dawn-of-sorrow',
#  466: 'cuphead-in-the-delicious-last-course',
#  467: 'dark-souls-artorias-of-the-abyss',
#  468: 'dead-space-2008',
#  469: 'descent-3',
#  470: 'destiny-2-the-final-shape',
#  471: 'far-cry',
#  472: 'horizon-forbidden-west-complete-edition',
#  473: 'like-a-dragon-infinite-wealth',
#  474: 'lone-echo',
#  475: 'metal-gear-solid-hd-collection',
#  476: 'nascar-racing-2003-season',
#  477: 'nascar-racing-4',
#  478: 'norco',
#  479: 'nuclear-throne',
#  480: 'quake-ii-enhanced-edition',
#  481: 'rise-of-nations-2003',
#  482: 'shin-megami-tensei-persona-3-fes',
#  483: 'the-curse-of-monkey-island',
#  484: 'world-series-baseball-2k3',
#  485: 'xcom-enemy-unknown',
#  486: 'advance-wars-2-black-hole-rising',
#  487: 'alan-wake-ii',
#  488: 'castlevania-dominus-collection',
#  489: 'deus-ex-human-revolution',
#  490: 'dreams',
#  491: 'einhander',
#  492: 'gran-turismo-4',
#  493: 'grandia',
#  494: 'l-a-noire',
#  495: 'lumines',
#  496: 'metal-gear-solid-peace-walker',
#  497: 'nba-2k2',
#  498: 'new-super-mario-bros',
#  499: 'peggle',
#  500: 'ratchet-and-clank-future-tools-of-destruction',
#  501: 'return-of-the-obra-dinn',
#  502: 'silent-hill-2-2001',
#  503: 'synth-riders',
#  504: 'the-beatles-rock-band',
#  505: 'the-chronicles-of-riddick-escape-from-butcher-bay',
#  506: 'tony-hawks-pro-skater-1-plus-2',
#  507: 'warioware-inc-mega-microgame',
#  508: 'wwf-no-mercy',
#  509: 'a-short-hike',
#  510: 'asgards-wrath',
#  511: 'burnout-paradise',
#  512: 'colors-3d',
#  513: 'devil-may-cry-5-special-edition',
#  514: 'disco-elysium-the-final-cut',
#  515: 'dusk',
#  516: 'espn-nba-basketball',
#  517: 'excitebike-64',
#  518: 'horizon-zero-dawn',
#  519: 'medieval-total-war',
#  520: 'microsoft-flight-simulator-2004-a-century-of-flig',
#  521: 'nba-2k11',
#  522: 'nba-street',
#  523: 'r4-ridge-racer-type-4',
#  524: 'railroad-tycoon-ii',
#  525: 'shenmue',
#  526: 'soul-edge',
#  527: 'stardew-valley',
#  528: 'the-last-of-us-part-i',
#  529: 'tiger-woods-pga-tour-2005',
#  530: 'top-spin',
#  531: 'wipeout-pure',
#  532: 'xcom-2-war-of-the-chosen',
#  533: 'abiotic-factor',
#  534: 'brothers-in-arms-road-to-hill-30',
#  535: 'call-of-duty-modern-warfare-3',
#  536: 'cocoon',
#  537: 'crusader-kings-ii-the-old-gods',
#  538: 'ctr-crash-team-racing',
#  539: 'deus-ex-human-revolution-directors-cut',
#  540: 'dishonored',
#  541: 'f-e-a-r',
#  542: 'kingdom-come-deliverance-ii',
#  543: 'lorelei-and-the-laser-eyes',
#  544: 'mario-kart-8',
#  545: 'medal-of-honor-frontline',
#  546: 'monster-hunter-wilds',
#  547: 'pinball-fx-2-marvel-pinball-avengers-chronicles',
#  548: 'psychonauts',
#  549: 'shadow-complex',
#  550: 'super-mario-maker',
#  551: 'superbike-2001',
#  552: 'tekken-5',
#  553: 'tetris-effect-connected',
#  554: 'the-binding-of-isaac-rebirth',
#  555: 'ultimate-fighting-championship',
#  556: 'what-remains-of-edith-finch',
#  557: 'age-of-empires-ii-the-conquerors-expansion',
#  558: 'assassins-creed-iv-black-flag',
#  559: 'bioshock-2',
#  560: 'diddy-kong-racing',
#  561: 'far-cry-3',
#  562: 'it-takes-two',
#  563: 'kerbal-space-program',
#  564: 'meteos',
#  565: 'mullet-madjack',
#  566: 'nhl-09',
#  567: 'nhl-10',
#  568: 'nier-automata',
#  569: 'ori-and-the-blind-forest-definitive-edition',
#  570: 'rise-of-the-tomb-raider-20-year-celebration',
#  571: 'star-fox-64',
#  572: 'starcraft',
#  573: 'streets-of-rage-4-mr-x-nightmare',
#  574: 'super-street-fighter-ii-turbo-hd-remix',
#  575: 'tactics-ogre-the-knight-of-lodis',
#  576: 'the-last-of-us-left-behind',
#  577: 'tom-clancys-rainbow-six-vegas',
#  578: 'tribes-2',
#  579: 'uncharted-drakes-fortune',
#  580: 'warcraft-iii-the-frozen-throne',
#  581: 'battlefield-bad-company-2',
#  582: 'dead-cells-return-to-castlevania',
#  583: 'dishonored-2',
#  584: 'divinity-original-sin-enhanced-edition',
#  585: 'espn-nhl-hockey',
#  586: 'fight-night-round-2',
#  587: 'injustice-2-legendary-edition',
#  588: 'jsrf-jet-set-radio-future',
#  589: 'myth-ii-soulblighter',
#  590: 'nba-2k17',
#  591: 'ncaa-football-2005',
#  592: 'project-gotham-racing-3',
#  593: 'ratchet-and-clank',
#  594: 'ratchet-and-clank-rift-apart',
#  595: 'red-faction',
#  596: 'rogue-legacy-2',
#  597: 'star-wars-pinball-balance-of-the-force',
#  598: 'the-crimson-diamond',
#  599: 'the-secret-of-monkey-island-special-edition',
#  600: 'the-world-ends-with-you',
#  601: 'tiger-woods-pga-tour-2003',
#  602: 'torchlight-ii',
#  603: 'xcom-2',
#  604: 'xcom-enemy-within',
#  605: 'deathloop',
#  606: 'f1-2002',
#  607: 'final-fantasy-tactics',
#  608: 'fire-emblem-fates-special-edition',
#  609: 'grand-theft-auto-liberty-city-stories',
#  610: 'hearthstone-heroes-of-warcraft',
#  611: 'kill-knight',
#  612: 'medieval-ii-total-war',
#  613: 'metroid-dread',
#  614: 'nhl-11',
#  615: 'ori-and-the-blind-forest',
#  616: 'pinball-fx-2',
#  617: 'pokemon-y',
#  618: 'shogo-mobile-armor-division',
#  619: 'sly-2-band-of-thieves',
#  620: 'super-mario-maker-2',
#  621: 'the-elder-scrolls-iii-morrowind-game-of-the-yea',
#  622: 'the-talos-principle-2',
#  623: 'the-witcher-2-assassins-of-kings',
#  624: 'thirty-flights-of-loving',
#  625: 'unity-of-command-ii',
#  626: 'wario-land-4',
#  627: 'warioware-twisted',
#  628: 'battlefield-1',
#  629: 'bomberman-tournament',
#  630: 'counter-strike-source',
#  631: 'diablo-iii',
#  632: 'diablo-iii-eternal-collection',
#  633: 'espn-nhl-2k5',
#  634: 'eve-online-special-edition',
#  635: 'fifa-soccer-2003',
#  636: 'fire-emblem',
#  637: 'fire-emblem-fates-revelation',
#  638: 'god-of-war-ragnarok-valhalla',
#  639: 'guacamelee-gold-edition',
#  640: 'heretic-plus-hexen',
#  641: 'monster-hunter-rise',
#  642: 'oddworld-strangers-wrath',
#  643: 'paper-mario-the-thousand-year-door',
#  644: 'resident-evil-4-separate-ways',
#  645: 'rise-of-nations-thrones-and-patriots',
#  646: 'shogun-showdown',
#  647: 'sid-meiers-civilization-vi',
#  648: 'sid-meiers-pirates',
#  649: 'starcraft-ii-legacy-of-the-void',
#  650: 'tekken-5-dark-resurrection',
#  651: 'the-stanley-parable',
#  652: 'armadillo-run',
#  653: 'art-of-balance-touch',
#  654: 'baldurs-gate-ii-throne-of-bhaal',
#  655: 'battlefield-bad-company-2-vietnam',
#  656: 'cave-story-plus',
#  657: 'crimson-skies-high-road-to-revenge',
#  658: 'dark-age-of-camelot',
#  659: 'doom-eternal',
#  660: 'fifa-soccer-11',
#  661: 'hyper-demon',
#  662: 'joe-danger-special-edition',
#  663: 'littlebigplanet-ps-vita',
#  664: 'mouthwashing',
#  665: 'nascar-thunder-2004',
#  666: 'need-for-speed-hot-pursuit',
#  667: 'nex-machina-death-machine',
#  668: 'night-in-the-woods',
#  669: 'nioh',
#  670: 'owlboy',
#  671: 'pillars-of-eternity-ii-deadfire',
#  672: 'ridge-racer',
#  673: 'steamworld-dig-2',
#  674: 'the-talos-principle-deluxe-edition',
#  675: 'world-of-warcraft-legion',
#  676: 'animal-crossing-new-leaf',
#  677: 'bloodborne-the-old-hunters',
#  678: 'devil-may-cry-5',
#  679: 'diablo-ii',
#  680: 'doom-3',
#  681: 'final-fantasy-xiv-stormblood',
#  682: 'football-manager-2010',
#  683: 'ghost-of-tsushima-directors-cut',
#  684: 'guacamelee-super-turbo-championship-edition',
#  685: 'halls-of-torment',
#  686: 'halo-4',
#  687: 'hitman-3',
#  688: 'injustice-2',
#  689: 'mortal-kombat-11-ultimate',
#  690: 'nba-2k13',
#  691: 'need-for-speed-iii-hot-pursuit',
#  692: 'oddworld-abes-exoddus',
#  693: 'persona-3-reload',
#  694: 'plants-vs-zombies',
#  695: 'rallisport-challenge-2',
#  696: 'rocksmith-2014-edition',
#  697: 'socom-ii-u-s-navy-seals',
#  698: 'subnautica',
#  699: 'the-witness',
#  700: 'astral-chain',
#  701: 'baldurs-gate-dark-alliance',
#  702: 'critter-crunch',
#  703: 'crypt-of-the-necrodancer',
#  704: 'dragon-quest-ix-sentinels-of-the-starry-skies',
#  705: 'europa-universalis-ii',
#  706: 'fifa-soccer-09',
#  707: 'final-fantasy-vii-remake',
#  708: 'guilty-gear-strive-',
#  709: 'jeanne-darc',
#  710: 'kathy-rain-directors-cut',
#  711: 'legends-of-runeterra',
#  712: 'metropolis-street-racer',
#  713: 'monster-train-2',
#  714: 'pokemon-sun',
#  715: 'pokemon-white-version',
#  716: 'pokemon-x',
#  717: 'power-stone-2',
#  718: 'rimworld',
#  719: 'sea-of-stars',
#  720: 'shin-megami-tensei-v-vengeance',
#  721: 'street-fighter-v-arcade-edition',
#  722: 'tactical-breach-wizards',
#  723: 'the-nioh-collection',
#  724: 'castlevania-harmony-of-dissonance',
#  725: 'crusader-kings-iii-roads-to-power',
#  726: 'diablo-ii-lord-of-destruction',
#  727: 'dirt-3',
#  728: 'earthion',
#  729: 'final-fantasy-xvi',
#  730: 'five-nights-at-freddys-into-the-pit',
#  731: 'gran-turismo-7',
#  732: 'half-life-2-episode-one',
#  733: 'heavy-rain',
#  734: 'kentucky-route-zero-tv-edition',
#  735: 'mass-effect-2-lair-of-the-shadow-broker',
#  736: 'mechwarrior-4-vengeance',
#  737: 'pikmin-4',
#  738: 'pokemon-soulsilver-version',
#  739: 'sins-of-a-solar-empire',
#  740: 'spin-rhythm-xd',
#  741: 'super-monkey-ball-2',
#  742: 'syphon-filter-dark-mirror',
#  743: 'tactics-ogre-1995',
#  744: 'the-elder-scrolls-iii-morrowind',
#  745: 'the-swapper',
#  746: 'thief-ii-the-metal-age',
#  747: 'uncharted-legacy-of-thieves-collection',
#  748: 'bangai-o',
#  749: 'batman-arkham-knight',
#  750: 'battlefield-3-armored-kill',
#  751: 'dead-or-alive-3',
#  752: 'donkey-kong-country-returns',
#  753: 'dragon-ball-fighterz',
#  754: 'elite-beat-agents',
#  755: 'final-fantasy-tactics-advance',
#  756: 'forza-motorsport-6',
#  757: 'icewind-dale',
#  758: 'immortality',
#  759: 'jak-ii',
#  760: 'mario-kart-8-dlc-pack-1',
#  761: 'mario-kart-double-dash',
#  762: 'marvels-spider-man',
#  763: 'mini-motorways',
#  764: 'ncaa-football-06',
#  765: 'new-super-mario-bros-wii',
#  766: 'paper-mario-the-thousand-year-door-2004',
#  767: 'pokemon-moon',
#  768: 'rallisport-challenge',
#  769: 'red-dead-redemption-undead-nightmare-pack',
#  770: 'the-legend-of-zelda-links-awakening',
#  771: 'ultimate-card-games',
#  772: 'animal-crossing',
#  773: 'bully',
#  774: 'call-of-duty-black-ops',
#  775: 'diablo-iii-reaper-of-souls',
#  776: 'fight-night-round-4',
#  777: 'fire-emblem-if',
#  778: 'kohan-immortal-sovereigns',
#  779: 'little-kings-story',
#  780: 'mechassault',
#  781: 'metal-gear-solid-portable-ops',
#  782: 'mlb-13-the-show',
#  783: 'nfl-2k2',
#  784: 'pipistrello-and-the-cursed-yoyo',
#  785: 'pokemon-heartgold-version',
#  786: 'pro-evolution-soccer-2016',
#  787: 'psychonauts-2',
#  788: 'raw-data',
#  789: 'shogun-total-war-warlord-edition',
#  790: 'tearaway',
#  791: 'the-legend-of-zelda-spirit-tracks',
#  792: 'theatrhythm-final-bar-line',
#  793: 'towerfall-ascension',
#  794: 'zack-and-wiki-quest-for-barbaros-treasure',
#  795: 'zero-escape-the-nonary-games',
#  796: 'call-of-duty-united-offensive',
#  797: 'company-of-heroes-opposing-fronts',
#  798: 'dirt-2',
#  799: 'divinity-original-sin',
#  800: 'final-fantasy-vi-pixel-remaster',
#  801: 'forza-horizon-3-blizzard-mountain',
#  802: 'grand-prix-3',
#  803: 'grindstone',
#  804: 'katamari-damacy-reroll',
#  805: 'mass-effect-legendary-edition',
#  806: 'metal-gear-solid-2-substance',
#  807: 'mlb-12-the-show',
#  808: 'odin-sphere-leifdrasir',
#  809: 'outrun',
#  810: 'pokemon-black-version',
#  811: 'rayman-origins',
#  812: 'return-to-monkey-island',
#  813: 'serious-sam-the-first-encounter',
#  814: 'sin-and-punishment-star-successor',
#  815: 'unavowed',
#  816: 'wipeout-hd',
#  817: 'wolfenstein-ii-the-new-colossus',
#  818: 'worldwide-soccer-manager-2007',
#  819: 'dark-souls-ii-scholar-of-the-first-sin',
#  820: 'driver',
#  821: 'europa-universalis-iv',
#  822: 'flower',
#  823: 'hi-fi-rush',
#  824: 'marvel-vs-capcom-fighting-collection-arcade',
#  825: 'minishoot-adventures',
#  826: 'nba-2k16',
#  827: 'neva',
#  828: 'out-of-the-park-baseball-4',
#  829: 'pikmin-3',
#  830: 'pinball-fx-2-star-wars-pinball',
#  831: 'resistance-2',
#  832: 'sonic-mania-plus',
#  833: 'spelunky',
#  834: 'spelunky-2',
#  835: 'sunless-skies',
#  836: 'super-monkey-ball',
#  837: 'tales-of-arise',
#  838: 'the-making-of-karateka',
#  839: 'total-war-warhammer-ii',
#  840: 'velocity',
#  841: 'velocity-ultra',
#  842: 'zeus-master-of-olympus',
#  843: 'antonblast',
#  844: 'arco',
#  845: 'dark-cloud-2',
#  846: 'fallout-4',
#  847: 'forza-horizon-3-hot-wheels',
#  848: 'grid-2008',
#  849: 'guilty-gear-x2',
#  850: 'halo-infinite',
#  851: 'hex-shards-of-fate',
#  852: 'kingdom-hearts-ii',
#  853: 'lonely-mountains-snow-riders',
#  854: 'marvels-spider-man-remastered',
#  855: 'motogp-2',
#  856: 'pixeljunk-shooter',
#  857: 'ratchet-and-clank-future-a-crack-in-time',
#  858: 'shin-megami-tensei-persona-3',
#  859: 'sonic-advance',
#  860: 'spider-man-2000',
#  861: 'teenage-mutant-ninja-turtles-shredders-revenge-2023',
#  862: 'tenchu-stealth-assassins',
#  863: 'there-is-no-game-wrong-dimension',
#  864: 'warhammer-40-000-dawn-of-war-dark-crusade',
#  865: 'world-of-warcraft-warlords-of-draenor',
#  866: 'xenoblade-chronicles-x-definitive-edition',
#  867: 'bomberman-blast',
#  868: 'burnout-legends',
#  869: 'bustafellows',
#  870: 'enemy-engaged-rah-66-comanche-versus-ka-52-hokum',
#  871: 'fallout-2',
#  872: 'football-manager-2013',
#  873: 'gone-home',
#  874: 'kirby-canvas-curse',
#  875: 'kirbys-epic-yarn',
#  876: 'lostwinds-winter-of-the-melodias',
#  877: 'mario-kart-8-deluxe-booster-course-pass-wave-4',
#  878: 'minds-beneath-us',
#  879: 'pac-man-championship-edition-dx-plus',
#  880: 'pixeljunk-monsters-deluxe',
#  881: 'silent-hill-1999',
#  882: 'startopia',
#  883: 'supreme-commander',
#  884: 'tales-from-the-borderlands-episode-5-the-vault-of',
#  885: 'the-elder-scrolls-iv-shivering-isles',
#  886: 'the-great-ace-attorney-chronicles',
#  887: 'the-last-friend',
#  888: 'total-war-shogun-2-fall-of-the-samurai',
#  889: 'turbo-overkill',
#  890: 'uncharted-the-nathan-drake-collection',
#  891: 'astebreed',
#  892: 'boom-blox-bash-party',
#  893: 'cuphead',
#  894: 'diablo-iv',
#  895: 'f1-2017',
#  896: 'f1-2020',
#  897: 'ground-control',
#  898: 'kentucky-route-zero',
#  899: 'killer-instinct-season-3',
#  900: 'might-and-magic-clash-of-heroes',
#  901: 'monster-hunter-rise-sunbreak',
#  902: 'mvp-baseball-2005',
#  903: 'out-of-the-park-baseball-14',
#  904: 'overboard-2021',
#  905: 'resistance-fall-of-man',
#  906: 'the-messenger',
#  907: 'the-roottrees-are-dead',
#  908: 'the-witcher-enhanced-edition',
#  909: 'total-war-warhammer',
#  910: 'unicorn-overlord',
#  911: 'valkyria-chronicles',
#  912: 'vampire-survivors',
#  913: 'velocity-2x',
#  914: 'warhammer-40k-rogue-trader-void-shadows',
#  915: '1000xresist',
#  916: 'blazblue-calamity-trigger',
#  917: 'destiny-2-the-witch-queen',
#  918: 'dragon-age-origins',
#  919: 'dragon-quest-builders-2',
#  920: 'everquest-omens-of-war',
#  921: 'fluidity',
#  922: 'freedom-force-vs-the-3rd-reich',
#  923: 'golden-sun-the-lost-age',
#  924: 'mercenaries-playground-of-destruction',
#  925: 'monster-boy-and-the-cursed-kingdom',
#  926: 'monster-hunter-4-ultimate',
#  927: 'patapon',
#  928: 'picross-3d-round-2',
#  929: 'saints-row-iv',
#  930: 'sid-meiers-civilization-iv-beyond-the-sword',
#  931: 'steel-beasts',
#  932: 'steinsgate-elite',
#  933: 'street-fighter-6-years-1-2-fighters-edition',
#  934: 'test-drive-v-rally',
#  935: 'the-sims-3',
#  936: 'titanfall',
#  937: 'tomb-raider',
#  938: 'total-annihilation',
#  939: 'alundra',
#  940: 'anonymouscode',
#  941: 'asgards-wrath-2',
#  942: 'bayonetta-3',
#  943: 'borderlands-2-tiny-tinas-assault-on-dragon-keep',
#  944: 'dungeon-siege',
#  945: 'espn-college-hoops-2k5',
#  946: 'god-of-war-ghost-of-sparta',
#  947: 'guilty-gear-xrd-revelator-',
#  948: 'her-story',
#  949: 'lunar-2-eternal-blue',
#  950: 'ni-no-kuni-wrath-of-the-white-witch-remastered',
#  951: 'panzer-corps-2',
#  952: 'pentiment',
#  953: 'pinball-fx-2-marvel-pinball',
#  954: 'prince-of-persia-the-lost-crown',
#  955: 'punch-out-2009',
#  956: 'radiant-silvergun',
#  957: 'silent-hill-2',
#  958: 'starcraft-ii-heart-of-the-swarm',
#  959: 'suikoden-iii',
#  960: 'trials-hd',
#  961: 'tribes-ascend',
#  962: 'animal-crossing-wild-world',
#  963: 'beyond-good-and-evil',
#  964: 'brothers-a-tale-of-two-sons',
#  965: 'crashmo',
#  966: 'dino-crisis-2',
#  967: 'dmc-devil-may-cry',
#  968: 'final-fantasy-xii-the-zodiac-age',
#  969: 'galactic-civilizations-ii-dread-lords',
#  970: 'guilty-gear-xx-reload',
#  971: 'homeworld-remastered-collection',
#  972: 'mario-and-luigi-partners-in-time',
#  973: 'mario-kart-world',
#  974: 'max-payne-2-the-fall-of-max-payne',
#  975: 'medal-of-honor-underground',
#  976: 'mortal-kombat-2011',
#  977: 'ncaa-football-11',
#  978: 'need-for-speed-high-stakes',
#  979: 'planet-puzzle-league',
#  980: 'riven',
#  981: 'soulcalibur-iii',
#  982: 'star-trek-voyager-elite-force',
#  983: 'star-wars-knights-of-the-old-republic-ii-the-sit',
#  984: 'star-wars-pinball',
#  985: 'street-fighter-iii-3rd-strike',
#  986: 'amplitude-2003',
#  987: 'bastion',
#  988: 'colin-mcrae-rally-3',
#  989: 'dance-central-2',
#  990: 'daytona-usa',
#  991: 'devotion',
#  992: 'fight-night-round-3',
#  993: 'geometry-wars-retro-evolved',
#  994: 'grapple-dogs-cosmic-canines',
#  995: 'hrot',
#  996: 'il-2-sturmovik-forgotten-battles',
#  997: 'joe-danger',
#  998: 'nioh-2-the-complete-edition',
#  999: 'professor-layton-and-the-unwound-future',
#  ...}

# %%
df_scores["id_usuario"] = df_scores["id_usuario"].apply(lambda x: user_id_2_id_mapping[x])
df_scores["id_juego"] = df_scores["id_juego"].apply(lambda x: item_id_2_id_mapping[x])

df_scores.head()
# Out:
#    id_usuario  id_juego  score
# 0           0         0    100
# 1           1         0    100
# 2           2         0    100
# 3           3         0    100
# 4           4         0    100

# %%
# Entradas
dataset_inputs = {
    "user_id": df_scores['id_usuario'].to_numpy(dtype="float32"),
    'item_id': df_scores['id_juego'].to_numpy(dtype="float32")
}

# Salidas
#Normalizar para que los datos numéricos para que redes neuoranles funcionen
# y que no haya quilombo con los pesos
dataset_outputs = df_scores['score'].to_numpy()/ 100.0

dataset = tf.data.Dataset.from_tensor_slices((dataset_inputs, dataset_outputs))
dataset = dataset.shuffle(100_000, seed=42, reshuffle_each_iteration=False)

cut = int(df_scores.shape[0] * 0.8)
train_dataset = dataset.take(cut).batch(256).cache()
test_dataset = dataset.skip(df_scores.shape[0] - cut).batch(256).cache()

# %%
dataset_outputs
# Out:
# array([1.  , 1.  , 1.  , ..., 0.15, 0.1 , 0.1 ], shape=(344977,))

# %% [markdown]
# ## Modelo

# %%
class RankingModel(keras.Model):
    """Crea un modelo de ranking

    Args:
      num_users: Number of entries in the user embedding table.
      num_items: Number of entries in the candidate embedding table.
      embedding_dimension: Output dimension for user and movie embedding tables.
    """

    def __init__(
        self,
        num_users,
        num_items,
        embedding_dimension=32,
        **kwargs,
    ):
        super().__init__(**kwargs)

        # Embedding de los usuarios
        self.user_embedding = keras.layers.Embedding(num_users, embedding_dimension)

        # Embedding de los items
        self.item_embedding = keras.layers.Embedding(num_items, embedding_dimension)

        # Predicciones
        self.scores = keras.Sequential( #Se puede mejorar la arquitectura
            [
                # Capas densas
                keras.layers.Dense(256, activation="relu"),
                keras.layers.Dense(64, activation="relu"),

                # Predicciones en la capa final
                keras.layers.Dense(1),
            ]
        )

    def call(self, inputs):
        user_id = inputs["user_id"]
        item_id = inputs["item_id"]

        user_embeddings = self.user_embedding(user_id) # Le mete los embeddings de usuario
        item_embeddings = self.item_embedding(item_id) # Le mete los embeddings de item

        #Concatenar horizontalmente como estructura de 2 
        # Sería lo mismo que hacer un filtrado colaborativo
        return self.scores(keras.ops.concatenate([user_embeddings, item_embeddings], axis=1))

# %%
@register_keras_serializable()
class RankingModel(keras.Model):
    def __init__(
        self,
        num_users,
        num_items,
        embedding_dimension=32,
        **kwargs,
    ):
        super().__init__(**kwargs)

        # guardar estos parámetros para get_config
        self.num_users = num_users
        self.num_items = num_items
        self.embedding_dimension = embedding_dimension

        self.user_embedding = keras.layers.Embedding(
            self.num_users, self.embedding_dimension
        )
        self.item_embedding = keras.layers.Embedding(
            self.num_items, self.embedding_dimension
        )

        self.scores = keras.Sequential(
            [
                keras.layers.Dense(256, activation="relu"),
                keras.layers.Dense(64, activation="relu"),
                keras.layers.Dense(1),
            ]
        )

    def call(self, inputs):
        user_id = inputs["user_id"]
        item_id = inputs["item_id"]

        user_embeddings = self.user_embedding(user_id)
        item_embeddings = self.item_embedding(item_id)

        x = keras.ops.concatenate([user_embeddings, item_embeddings], axis=1)
        return self.scores(x)

    def get_config(self):
        # config base de keras.Model (name, trainable, etc.)
        config = super().get_config()
        # agregamos nuestros parámetros del constructor
        config.update(
            {
                "num_users": self.num_users,
                "num_items": self.num_items,
                "embedding_dimension": self.embedding_dimension,
            }
        )
        return config

    @classmethod
    def from_config(cls, config):
        # esto permite reconstruir correctamente desde el config
        return cls(**config)

# %% [markdown]
# ## Entrenamiento y evaluación

# %%
ranking_model = RankingModel(len(unique_user_id) + 1, len(unique_item_id) + 1)
ranking_model.compile(
    loss=keras.losses.MeanSquaredError(),
    metrics=[keras.metrics.RootMeanSquaredError()],
    optimizer=keras.optimizers.Adagrad(learning_rate=0.1), #hiperparámetros que se podría optimizar
)

# Detiene el entrenamiento cuando no hay mejora en loss en tres épocas consecutivas
es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# Graba el modelo cuando cambia val_root_mean_squared_error
#mc_callback = keras.callbacks.ModelCheckpoint(filepath="checkpoint.{val_root_mean_squared_error:.2f}.weights.h5", monitor="val_root_mean_squared_error", mode="min",  save_weights_only=True, save_best_only=True)
mc_callback = keras.callbacks.ModelCheckpoint(filepath="checkpoint.{val_root_mean_squared_error:.2f}.keras", monitor="val_root_mean_squared_error", mode="min",  save_weights_only=False, save_best_only=True)

history = ranking_model.fit(train_dataset,
                    validation_data=test_dataset,
                    validation_freq=1,
                    epochs=100,
                    batch_size=1024,
                    callbacks=[es_callback, mc_callback]
                    )
# Out:
# Epoch 1/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - loss: 0.0159 - root_mean_squared_error: 0.1260 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1694
# Epoch 2/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0276 - val_root_mean_squared_error: 0.1661
# Epoch 3/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.1189 - val_loss: 0.0272 - val_root_mean_squared_error: 0.1649
# Epoch 4/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - val_loss: 0.0269 - val_root_mean_squared_error: 0.1639
# Epoch 5/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0139 - root_mean_squared_error: 0.1180 - val_loss: 0.0265 - val_root_mean_squared_error: 0.1627
# Epoch 6/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0138 - root_mean_squared_error: 0.1175 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1612
# Epoch 7/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0136 - root_mean_squared_error: 0.1168 - val_loss: 0.0253 - val_root_mean_squared_error: 0.1591
# Epoch 8/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0134 - root_mean_squared_error: 0.1159 - val_loss: 0.0244 - val_root_mean_squared_error: 0.1563
# Epoch 9/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0131 - root_mean_squared_error: 0.1146 - val_loss: 0.0233 - val_root_mean_squared_error: 0.1528
# Epoch 10/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.1131 - val_loss: 0.0219 - val_root_mean_squared_error: 0.1481
# Epoch 11/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0124 - root_mean_squared_error: 0.1113 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1429
# Epoch 12/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0119 - root_mean_squared_error: 0.1093 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1372
# Epoch 13/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0115 - root_mean_squared_error: 0.1071 - val_loss: 0.0173 - val_root_mean_squared_error: 0.1315
# Epoch 14/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0110 - root_mean_squared_error: 0.1049 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1263
# Epoch 15/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0105 - root_mean_squared_error: 0.1027 - val_loss: 0.0149 - val_root_mean_squared_error: 0.1220
# Epoch 16/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0101 - root_mean_squared_error: 0.1006 - val_loss: 0.0141 - val_root_mean_squared_error: 0.1186
# Epoch 17/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0097 - root_mean_squared_error: 0.0987 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1160
# Epoch 18/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0094 - root_mean_squared_error: 0.0971 - val_loss: 0.0129 - val_root_mean_squared_error: 0.1137
# Epoch 19/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0092 - root_mean_squared_error: 0.0957 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1116
# Epoch 20/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1097
# Epoch 21/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0088 - root_mean_squared_error: 0.0936 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1081
# Epoch 22/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0086 - root_mean_squared_error: 0.0929 - val_loss: 0.0114 - val_root_mean_squared_error: 0.1069
# Epoch 23/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0923 - val_loss: 0.0112 - val_root_mean_squared_error: 0.1058
# Epoch 24/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0084 - root_mean_squared_error: 0.0918 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1050
# Epoch 25/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0084 - root_mean_squared_error: 0.0915 - val_loss: 0.0109 - val_root_mean_squared_error: 0.1043
# Epoch 26/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0083 - root_mean_squared_error: 0.0912 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1037
# Epoch 27/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0083 - root_mean_squared_error: 0.0909 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1033
# Epoch 28/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0082 - root_mean_squared_error: 0.0907 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1029
# Epoch 29/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0082 - root_mean_squared_error: 0.0906 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1027
# Epoch 30/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0082 - root_mean_squared_error: 0.0904 - val_loss: 0.0105 - val_root_mean_squared_error: 0.1023
# Epoch 31/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0082 - root_mean_squared_error: 0.0903 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1022
# Epoch 32/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0902 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1020
# Epoch 33/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0901 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1018
# Epoch 34/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0900 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1017
# Epoch 35/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0899 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1016
# Epoch 36/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0081 - root_mean_squared_error: 0.0898 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1014
# Epoch 37/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0081 - root_mean_squared_error: 0.0898 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
# Epoch 38/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0897 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1012
# Epoch 39/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0896 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1012
# Epoch 40/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1011
# Epoch 41/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1010
# Epoch 42/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0894 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1009
# Epoch 43/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0894 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1008
# Epoch 44/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0893 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1008
# Epoch 45/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0892 - val_loss: 0.0102 - val_root_mean_squared_error: 0.1008
# Epoch 46/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0079 - root_mean_squared_error: 0.0892 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1007
# Epoch 47/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0079 - root_mean_squared_error: 0.0891 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 48/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1006
# Epoch 49/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 50/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0079 - root_mean_squared_error: 0.0889 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1005
# Epoch 51/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004
# Epoch 52/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004
# Epoch 53/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0079 - root_mean_squared_error: 0.0887 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1004
# Epoch 54/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0079 - root_mean_squared_error: 0.0886 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
# Epoch 55/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 56/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0885 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1002
# Epoch 57/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0884 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 58/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0883 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 59/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0882 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1001
# Epoch 60/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0100 - val_root_mean_squared_error: 0.1000
# Epoch 61/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0078 - root_mean_squared_error: 0.0881 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 62/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
# Epoch 63/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0077 - root_mean_squared_error: 0.0879 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 64/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 65/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0077 - root_mean_squared_error: 0.0877 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
# Epoch 66/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0997
# Epoch 67/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - loss: 0.0077 - root_mean_squared_error: 0.0875 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 68/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0076 - root_mean_squared_error: 0.0874 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 69/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0996
# Epoch 70/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0076 - root_mean_squared_error: 0.0872 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0995
# Epoch 71/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0076 - root_mean_squared_error: 0.0870 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 72/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - loss: 0.0076 - root_mean_squared_error: 0.0869 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0994
# Epoch 73/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0993
# Epoch 74/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0075 - root_mean_squared_error: 0.0867 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0993
# Epoch 75/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
# Epoch 76/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0075 - root_mean_squared_error: 0.0864 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0991
# Epoch 77/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0990
# Epoch 78/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0074 - root_mean_squared_error: 0.0861 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0989
# Epoch 79/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 80/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - loss: 0.0074 - root_mean_squared_error: 0.0858 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0988
# Epoch 81/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0856 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0987
# Epoch 82/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0855 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0986
# Epoch 83/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0073 - root_mean_squared_error: 0.0853 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0985
# Epoch 84/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0072 - root_mean_squared_error: 0.0851 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
# Epoch 85/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0072 - root_mean_squared_error: 0.0849 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0983
# Epoch 86/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0072 - root_mean_squared_error: 0.0847 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0982
# Epoch 87/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
# Epoch 88/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0980
# Epoch 89/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0071 - root_mean_squared_error: 0.0841 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 90/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0979
# Epoch 91/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0977
# Epoch 92/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0070 - root_mean_squared_error: 0.0835 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0976
# Epoch 93/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 0.0069 - root_mean_squared_error: 0.0832 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
# Epoch 94/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0069 - root_mean_squared_error: 0.0830 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0974
# Epoch 95/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0069 - root_mean_squared_error: 0.0828 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0972
# Epoch 96/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0068 - root_mean_squared_error: 0.0825 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0971
# Epoch 97/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0068 - root_mean_squared_error: 0.0823 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0970
# Epoch 98/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0067 - root_mean_squared_error: 0.0820 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
# Epoch 99/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0067 - root_mean_squared_error: 0.0818 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0966
# Epoch 100/100
# 1079/1079 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 0.0066 - root_mean_squared_error: 0.0815 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0966

# %% [markdown]
# ## Predicción

# %%
user_id = 42
item_ids = [241, 141, 131, 122, 2232]
predictions = ranking_model.predict({
    "user_id": keras.ops.array([user_id] * len(item_ids)),
    "item_id": keras.ops.array(item_ids),
})

predictions = keras.ops.convert_to_numpy(keras.ops.squeeze(predictions, axis=1))

for id_juego, prediction in zip(item_ids, predictions):
    print(f"{id_2_item_id_mapping[id_juego]}: {prediction * 100.0:,.2f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# resident-evil-remake: 92.48
# resident-evil-4: 90.36
# forza-horizon-4: 91.77
# story-of-seasons-grand-bazaar: 81.77
# outer-wilds-echoes-of-the-eye: 86.02

# %% [markdown]
# Predecir todos los items para un ususario

# %%
keras.ops.array([user_id] * len(item_ids))
keras.ops.array(item_ids)
# Out:
# <tf.Tensor: shape=(5,), dtype=int32, numpy=array([ 241,  141,  131,  122, 2232], dtype=int32)>

# %%
user_id = 42

# Obtiene los juegos que el usuario no ha puntuado
df_item_ids = pd.read_sql("SELECT id_juego FROM juegos WHERE id_juego NOT IN (SELECT id_juego FROM interacciones WHERE id_usuario = ?)", conn, params=[user_id])
item_ids = [item_id_2_id_mapping[u] for u in df_item_ids["id_juego"].to_list()]

predictions = ranking_model.predict({
    "user_id": keras.ops.array([user_id] * len(item_ids)),
    "item_id": keras.ops.array(item_ids),
}).squeeze()

predictions
# Out:
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([0.6045486 , 0.7489085 , 0.6949247 , ..., 0.76386225, 0.69388723,
#        0.7850012 ], shape=(13672,), dtype=float32)

# %%
item_ids_internal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 item_ids_internal
#
# NameError: name 'item_ids_internal' is not defined

# %%
user_id = 42

# Juegos NO vistos por el usuario
df_item_ids = pd.read_sql(
    """
    SELECT id_juego 
    FROM juegos 
    WHERE id_juego NOT IN (
        SELECT id_juego 
        FROM interacciones 
        WHERE id_usuario = ?
    )
    """, 
    conn, 
    params=[user_id]
)

item_ids_raw = df_item_ids["id_juego"].tolist()

item_ids_internal = [item_id_2_id_mapping[j] for j in item_ids_raw]


preds = ranking_model.predict({
    "user_id": keras.ops.array([user_id] * len(item_ids_internal)),
    "item_id": keras.ops.array(item_ids_internal),
}).squeeze()



df_preds = pd.DataFrame({
    "item_id_raw": item_ids_raw,               # ID real del juego
    "item_id_int": item_ids_internal,          # ID interno
    "score": preds                       # score del modelo
})

df_juegos = df_preds.sort_values("score", ascending=False)

id_juegos = [i for i in df_juegos["item_id_raw"]]

id_juegos
# Out:
# 428/428 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ['the-legend-of-zelda-breath-of-the-wild',
#  'grand-theft-auto-iv',
#  'the-elder-scrolls-iv-oblivion',
#  'the-legend-of-zelda-tears-of-the-kingdom',
#  'neverwinter-nights',
#  'uncharted-2-among-thieves',
#  'the-last-of-us-part-ii',
#  'red-dead-redemption',
#  'mass-effect-2',
#  'grand-theft-auto-v',
#  'the-elder-scrolls-v-skyrim',
#  'baldurs-gate-3',
#  'final-fantasy-vii-remake',
#  'elden-ring',
#  'uncharted-4-a-thiefs-end',
#  'super-mario-galaxy-2',
#  'god-of-war-ragnarok',
#  'castlevania-dawn-of-sorrow',
#  'astro-bot',
#  'god-of-war',
#  'bioshock',
#  'super-smash-bros-ultimate',
#  'bloodborne',
#  'red-dead-redemption-2',
#  'divinity-original-sin-ii',
#  'forza-motorsport-4',
#  'littlebigplanet',
#  'the-sims-2',
#  'sid-meiers-civilization-v',
#  'project-gotham-racing-2',
#  'super-mario-bros-wonder',
#  'tom-clancys-splinter-cell-pandora-tomorrow',
#  'dark-souls-ii',
#  'super-mario-galaxy',
#  'madden-nfl-2004',
#  'gears-of-war-3',
#  'goodbye-volcano-high',
#  'othello',
#  'diablo-iii',
#  'god-of-war-chains-of-olympus',
#  'uncharted-3-drakes-deception',
#  'super-smash-bros-brawl',
#  'call-of-duty-modern-warfare-2',
#  'inside',
#  'grand-theft-auto-san-andreas',
#  'nhl-11',
#  'the-legend-of-zelda-ocarina-of-time-3d',
#  'the-legend-of-zelda-twilight-princess',
#  'blue-prince',
#  'meteos',
#  'destiny-the-taken-king',
#  'tekken-3',
#  'quake-iii-arena-1999',
#  'super-mario-odyssey',
#  'resident-evil-4',
#  'the-legend-of-zelda-majoras-mask-3d',
#  'littlebigplanet-ps-vita',
#  'god-of-war-iii',
#  'the-last-of-us-part-i',
#  'ninja-gaiden-2004',
#  'the-legend-of-zelda-the-wind-waker-hd',
#  'half-life-2',
#  'golden-lap',
#  'mario-kart-8-deluxe',
#  'halo-3',
#  'demons-souls-2009',
#  'halo-2',
#  'batman-arkham-city',
#  'split-fiction',
#  'silent-hill-2-2001',
#  'cradle',
#  'donkey-kong-bananza',
#  'sid-meiers-alpha-centauri',
#  'super-mario-3d-world',
#  'xenoblade-chronicles-definitive-edition',
#  'resident-evil-4-2005',
#  'sekiro-shadows-die-twice',
#  'fallout-3',
#  'fez',
#  'street-fighter-6',
#  'super-mario-3d-world-plus-bowsers-fury',
#  'dead-space-3-awakened',
#  'the-talos-principle-road-to-gehenna',
#  'xenoblade-chronicles-3',
#  'shadow-of-the-colossus',
#  'braid',
#  'trinity-universe',
#  'ratchet-and-clank-rift-apart',
#  'gears-of-war',
#  'far-cry',
#  'the-master-chief-collection',
#  'spectral-force-genesis',
#  'hades',
#  'animal-crossing-new-leaf',
#  'diablo-iii-reaper-of-souls',
#  'call-of-duty-4-modern-warfare',
#  'xcom-2-war-of-the-chosen',
#  'virtua-tennis',
#  'madden-nfl-2005',
#  'psychonauts',
#  'resident-evil-2',
#  'rock-band-3',
#  'halo-combat-evolved',
#  'grand-theft-auto-iv-the-lost-and-damned',
#  'fifa-soccer-10',
#  'unreal-tournament-2004',
#  'ghost-of-tsushima-directors-cut',
#  'under-night-in-birth-exelatecl-r',
#  'worldwide-soccer-manager-2008',
#  'deathloop',
#  'rock-band',
#  'monster-hunter-world-iceborne',
#  'marvels-spider-man-2',
#  'final-fantasy-vii-remake-intergrade',
#  'animal-crossing-new-horizons',
#  'gran-turismo-4',
#  'borderlands-2',
#  'metroid-prime',
#  'need-for-speed-hot-pursuit',
#  'the-orange-box',
#  'final-fantasy-x',
#  'star-wars-knights-of-the-old-republic',
#  'forza-horizon-4',
#  'darwin-project',
#  'clair-obscur-expedition-33',
#  'command-and-conquer-3-tiberium-wars',
#  'guitar-hero-ii',
#  'nba-2k13',
#  'final-fantasy-vii-rebirth',
#  'the-talos-principle-2',
#  'crimson-skies-high-road-to-revenge',
#  'the-legend-of-zelda-skyward-sword',
#  'final-fantasy-xii',
#  'super-mega-baseball-3',
#  'elite-beat-agents',
#  'grandia-ii-remastered',
#  'tom-clancys-splinter-cell-chaos-theory',
#  'metroid-prime-remastered',
#  'dino-frontier',
#  'prototype-2009',
#  'burnout-revenge',
#  'grand-theft-auto-chinatown-wars',
#  'resident-evil-7-biohazard',
#  'death-stranding-2-on-the-beach',
#  'jett-the-far-shore',
#  'uncharted-drakes-fortune',
#  'immortals-fenyx-rising-the-lost-gods',
#  'taxi-life-a-city-driving-simulator',
#  'mark-of-the-ninja',
#  'dead-nation-road-of-devastation',
#  'persona-4-golden',
#  'sonic-the-hedgehog-4-episode-1',
#  'battlefield-bad-company-2',
#  'just-dance-2017',
#  'forza-motorsport-2005',
#  'gears-of-war-2',
#  'wizardry-tale-of-the-forsaken-land',
#  'her-story',
#  'rally-trophy',
#  'final-fantasy-xvi',
#  'boom-blox-bash-party',
#  'breath-of-fire-iv',
#  'empires-dawn-of-the-modern-world',
#  'horizon-zero-dawn',
#  'stray',
#  'masquerada-songs-and-shadows',
#  'lumines',
#  'call-of-duty-modern-warfare-3',
#  'tom-clancys-splinter-cell',
#  'edens-zero',
#  'industria',
#  'the-legend-of-zelda-the-wind-waker',
#  'ninja-gaiden-black',
#  'resident-evil-hd-remaster',
#  'crypt-of-the-necrodancer',
#  'silence-of-the-sleep',
#  'enigma-rising-tide',
#  'kingdom-come-deliverance-ii',
#  'world-of-warcraft-the-burning-crusade',
#  'portal-2',
#  'embr',
#  'ni-no-kuni-ii-revenant-kingdom',
#  'the-legend-of-zelda-skyward-sword-hd',
#  'dead-space',
#  'grandia-ii',
#  'street-fighter-iv',
#  'tales-of-symphonia',
#  'guilty-gear-x',
#  'metal-gear-solid-4-guns-of-the-patriots',
#  'the-elder-scrolls-iv-shivering-isles',
#  'the-world-ends-with-you',
#  'grand-theft-auto-vice-city',
#  'the-cave-2013',
#  'nier-automata',
#  'triangle-strategy',
#  'greg-hastings-tournament-paintball-maxd',
#  'tetris-effect',
#  'sin-and-punishment-star-successor',
#  'assassins-creed-ii',
#  'resident-evil',
#  'spirit-city-lofi-sessions',
#  'cadence-of-hyrule-crypt-of-the-necrodancer',
#  'the-last-of-us-left-behind',
#  'ratchet-and-clank-up-your-arsenal',
#  'bioshock-infinite',
#  'kid-icarus',
#  'rallisport-challenge-2',
#  'anno-1800-console-edition',
#  'nba-hoopz',
#  'rock-band-2',
#  'way-of-the-passive-fist',
#  'littlebigplanet-2',
#  'need-for-speed-iii-hot-pursuit',
#  'baldurs-gate-ii-shadows-of-amn',
#  'mlb-2003',
#  'corpse-of-discovery',
#  'kerbal-space-program-making-history',
#  'asterigos-curse-of-the-stars',
#  'medieval-ii-total-war',
#  'master-detective-archives-rain-code',
#  'the-ico-and-shadow-of-the-colossus-collection',
#  'nba-jam-on-fire-edition',
#  'tearaway',
#  'avadon-the-black-fortress',
#  'nioh',
#  'super-trucks-racing',
#  'maximo-ghosts-to-glory',
#  'wario-land-4',
#  'the-yakuza-remastered-collection',
#  'gryphon-knight-epic',
#  'capcom-classics-collection',
#  'armored-core-nine-breaker',
#  'final-fantasy-xi',
#  'oh-my-godheads',
#  'ori-and-the-will-of-the-wisps',
#  'punch-out-2009',
#  'super-mario-sunshine',
#  'metal-gear-solid-v-the-phantom-pain',
#  'mega-man-zero-4',
#  'pokemon-sun',
#  'rise-of-the-triad-ludicrous-edition',
#  'danganronpa-decadence',
#  'mlb-the-show-19',
#  'the-witcher-2-assassins-of-kings',
#  'overgrowth-2013',
#  'like-a-dragon-infinite-wealth',
#  'grand-theft-auto-iv-the-ballad-of-gay-tony',
#  'sly-cooper-collection',
#  'slam-bolt-scrappers',
#  'neopets-puzzle-adventure',
#  'ico',
#  'the-yawhg',
#  'zack-and-wiki-quest-for-barbaros-treasure',
#  'gatling-gears',
#  'gears-of-war-4',
#  'total-war-three-kingdoms-the-furious-wild',
#  'doc-clock-the-toasted-sandwich-of-time',
#  'pokemon-x',
#  'age-of-mythology-the-titans',
#  'world-of-warcraft',
#  'world-in-conflict',
#  'need-for-speed-hot-pursuit-2',
#  'max-payne-3',
#  'lydia',
#  'the-inner-friend',
#  'monster-hunter-rise',
#  'persona-3-reload',
#  'tom-clancys-rainbow-six-covert-ops-essentials',
#  'killzone-2',
#  'mario-kart-8',
#  'slay-the-princess-the-pristine-cut',
#  'ooga-booga',
#  'batman-arkham-asylum',
#  'alan-wake-ii',
#  'dragon-quest-xi-echoes-of-an-elusive-age',
#  'battlefield-1',
#  'pdc-world-championship-darts-2009',
#  'tony-hawks-underground-2',
#  'rims-racing',
#  'contra',
#  'the-sims-life-stories',
#  'the-outer-worlds',
#  'mom-hid-my-game',
#  'fallout-2',
#  'warcraft-iii-reign-of-chaos',
#  'bear-and-breakfast',
#  'days-gone',
#  'lover-pretend',
#  'tomb-raider-chronicles',
#  'larry-ragland-4x4-challenge',
#  'fire-emblem-three-houses',
#  'naruto-shippuden-ninja-destiny-2',
#  'a-robot-named-fight',
#  'silent-hill-2',
#  'burnout-3-takedown',
#  'metroid-dread',
#  'the-last-faith',
#  'forza-motorsport-6',
#  'final-fantasy-ix',
#  'fifa-soccer-08',
#  'elden-ring-shadow-of-the-erdtree',
#  'pillars-of-eternity',
#  'super-smash-bros-for-nintendo-3ds-wii-u',
#  'dead-space-2008',
#  'dragon-quest-viii-journey-of-the-cursed-king',
#  'medal-of-honor-infiltrator',
#  'super-mario-3d-land',
#  'metal-gear-solid-delta-snake-eater',
#  'forza-motorsport-3',
#  'prince-of-persia-the-sands-of-time',
#  'into-the-breach',
#  'skulls-of-the-shogun',
#  'forza-horizon-5-hot-wheels',
#  'starcraft-ii-wings-of-liberty',
#  'the-beast-inside',
#  'persona-5',
#  'demons-souls',
#  'uncharted-the-nathan-drake-collection',
#  'gyruss',
#  'call-of-duty-2',
#  'saints-row-the-third',
#  'starseed-pilgrim',
#  'star-control-origins',
#  'guitar-hero-5',
#  'persona-5-royal',
#  'the-legend-of-zelda-breath-of-the-wild-nintendo',
#  'freedom-fighters',
#  'the-hundred-line-last-defense-academy',
#  'empires-apart',
#  'wrc-2-fia-world-rally-championship-2011',
#  'the-witness',
#  'greg-hastings-tournament-paintball',
#  'bayonetta',
#  'the-witcher-3-wild-hunt',
#  'guild-wars',
#  'chrono-trigger',
#  'top-darts',
#  'wattam',
#  'the-legend-of-zelda-echoes-of-wisdom',
#  'green-hell',
#  'espn-nfl-football',
#  'tom-clancys-rainbow-six-3',
#  'sonic-rivals-2',
#  'quake',
#  'divinity-original-sin',
#  'gran-turismo-3-a-spec',
#  'ib',
#  'f1-2002',
#  'rome-total-war',
#  'gran-turismo-7',
#  'castlevania-symphony-of-the-night',
#  'nba-2k17',
#  'teslagrad',
#  'blazblue-chrono-phantasma-extend',
#  'crazy-machines-3',
#  'afterlove-ep',
#  'dragon-quest-xi-s-echoes-of-an-elusive-age',
#  'gears-5',
#  'tom-clancys-splinter-cell-conviction',
#  'taur',
#  'operation-flashpoint-resistance',
#  'portal-still-alive',
#  'galactic-civilizations-ii-twilight-of-the-arnor',
#  'devil-daggers',
#  'wasteland-3',
#  'dirt',
#  'fable-ii',
#  'penny-arcade-adventures-episode-two',
#  'total-war-warhammer-iii',
#  'rumble-racing',
#  'ssx-2000',
#  'republique-episode-4-gods-acre',
#  'heroes-of-the-pacific',
#  'mario-kart-world',
#  'metroid-fusion',
#  'fifa-soccer-12',
#  'rhapsody-a-musical-adventure',
#  'south-park-the-stick-of-truth',
#  'cocoon',
#  'attack-of-the-movies-3d',
#  'rez-infinite',
#  'oddworld-soulstorm-oddtimized-edition',
#  'shinobi-art-of-vengeance',
#  'the-tiny-bang-story',
#  'reventure',
#  'mlb-the-show-22',
#  'mass-effect-3',
#  'embracelet',
#  'xenoblade-chronicles-x-definitive-edition',
#  'little-kings-story',
#  'austerlitz-napoleons-greatest-victory',
#  'steinsgate-elite',
#  'unruly-heroes',
#  'halo-reach',
#  'mercenaries-playground-of-destruction',
#  'malicious-fallen',
#  'james-bond-007-everything-or-nothing',
#  'joe-danger-special-edition',
#  'x-type-plus',
#  'crysis',
#  'steinsgate-0',
#  'steamworld-dig-2',
#  'tennis-in-the-face',
#  'tokyo-xtreme-racer-zero',
#  'the-outer-worlds-spacers-choice-edition',
#  'planescape-torment',
#  'bayonetta-2',
#  'trials-evolution-gold-edition',
#  'journey',
#  'trigger-witch',
#  'mushroom-wars-2',
#  'cuphead',
#  'outlive-2001',
#  'torchlight-ii',
#  'pokemon-pearl-version',
#  'doom-eternal',
#  'legend-of-grimrock',
#  'the-legend-of-zelda-a-link-between-worlds',
#  'borderlands-3',
#  'attack-of-the-friday-monsters-a-tokyo-tale',
#  'harvest-moon-magical-melody',
#  'bloodsportstv',
#  'gish',
#  'last-days-of-lazarus',
#  'lock-on-modern-air-combat',
#  'virtua-fighter-4-evolution',
#  'advance-wars-dual-strike',
#  'a-r-e-s-extinction-agenda-ex',
#  'dragon-quest-iii-hd-2d-remake',
#  'ace-combat-04-shattered-skies',
#  'persona-4-arena-ultimax',
#  'soulcalibur-ii',
#  'primal-planet',
#  'lego-star-wars-the-complete-saga',
#  'super-mario-maker',
#  'new-super-mario-bros-wii',
#  'unreal-tournament-2003',
#  'katamari-damacy',
#  'salt-and-sanctuary',
#  'nioh-2-the-complete-edition',
#  'magical-beat',
#  'guitar-hero',
#  'rise-of-nations-thrones-and-patriots',
#  'dragon-ball-fighterz',
#  'metroid-prime-2-echoes',
#  'the-book-of-unwritten-tales-2',
#  '3-on-3-nhl-arcade',
#  'dreams',
#  'not-for-broadcast',
#  'hurry-up-hedgehog',
#  'jet-set-radio-2000',
#  'madden-nfl-12',
#  'spelunky',
#  'massive-assault-network-2',
#  'atelier-yumia-the-alchemist-of-memories-and-the',
#  'pinball-m',
#  'call-of-duty',
#  'rampage-puzzle-attack',
#  'destroy-all-humans-big-willy-unleashed',
#  'microsoft-flight-simulator',
#  'iridium-runners',
#  'total-war-shogun-2-fall-of-the-samurai',
#  'everhood',
#  'naruto-shippuden-ultimate-ninja-storm-3-full-burs',
#  'shovel-knight-showdown',
#  'bloodborne-the-old-hunters',
#  'dj-hero',
#  'read-only-memories-neurodiver',
#  'the-elder-scrolls-iii-bloodmoon',
#  'this-war-of-mine',
#  'fire-emblem-if',
#  'hunters-legacy',
#  'blackguards-2',
#  'two-point-museum',
#  'flinthook',
#  'left-4-dead-2',
#  'x-men-origins-wolverine-2009',
#  'age-of-conan-unchained',
#  'henry-hatsworth-in-the-puzzling-adventure',
#  'the-simpsons-hit-and-run',
#  'the-survivalists',
#  'the-walking-dead-the-telltale-series-a-new',
#  'bass-strike',
#  'ori-and-the-blind-forest',
#  'csi-ny',
#  'dungeon-defenders-awakened',
#  'snooker-19',
#  'links-2004',
#  'mega-man-battle-network-5-team-colonel',
#  'the-king-of-fighters-ex-neo-blood',
#  'pillars-of-eternity-complete-edition',
#  'eastshade',
#  'alternativa',
#  'luigis-mansion-dark-moon',
#  'company-of-heroes-2-the-british-forces',
#  'redux-dark-matters',
#  'terminator-resistance-annihilation-line',
#  'bleach-the-blade-of-fate',
#  'sportsfriends',
#  'final-fantasy-iv-3d-remake',
#  'dance-dance-revolution-supernova-2',
#  'soul-nomad-and-the-world-eaters',
#  'far-cry-new-dawn',
#  'gigantosaurus-the-game',
#  'endless-space',
#  'crusader-kings-iii',
#  'fatal-fury-battle-archives-volume-2',
#  'just-dance-2021',
#  'mario-plus-rabbids-sparks-of-hope',
#  'lost-in-random-the-eternal-die',
#  'the-last-of-us-part-ii-remastered',
#  'mind-path-to-thalamus',
#  'the-sims-4-eco-lifestyle',
#  'the-secret-of-monkey-island-special-edition',
#  'bladestorm-the-hundred-years-war',
#  'virtua-tennis-world-tour',
#  'mlb-the-show-20',
#  'tokyo-42',
#  'sinking-island',
#  'threefold-recital',
#  'god-of-war-ii',
#  'blacktail',
#  'nhl-09',
#  'dr-mario-64',
#  'atv-offroad-fury-pro',
#  'black-desert-online-land-of-the-morning-light',
#  'pikmin-4',
#  'uncharted-legacy-of-thieves-collection',
#  'gods-and-heroes-rome-rising',
#  'cyberpunk-2077',
#  'tomba-special-edition',
#  'assassins-creed-brotherhood',
#  'fatal-fury-city-of-the-wolves',
#  'the-raven-legacy-of-a-master-thief-ancestry-of',
#  'starfield',
#  'total-war-warhammer-ii',
#  'xdefiant',
#  'clockwork-empires',
#  'pokemon-platinum-version',
#  'aggressors-ancient-rome',
#  'rise-of-nations-rise-of-legends',
#  'where-is-my-heart',
#  'flower',
#  'labyrinth-city-pierre-the-maze-detective',
#  'grand-prix-3',
#  'daxter',
#  'the-sims-2-bon-voyage',
#  'rocksmith',
#  'the-sinking-city',
#  'shatter-2009',
#  'cities-in-motion',
#  'batman-the-brave-and-the-bold-the-videogame',
#  'need-for-speed-high-stakes',
#  'anomaly-agent',
#  'brute-force',
#  'new-legends',
#  'diablo-iv',
#  'tom-clancys-splinter-cell-double-agent',
#  'xcom-enemy-within-expansion',
#  'prince-of-persia-the-lost-crown',
#  'mortal-kombat-1-khaos-reigns',
#  'looney-tunes-wacky-world-of-sports',
#  'fru',
#  'neva',
#  'star-wars-obi-wan',
#  'boxboy-plus-boxgirl',
#  'the-last-door-2014',
#  'doom-the-dark-ages',
#  'hotline-miami-2-wrong-number',
#  'rabbids-alive-and-kicking',
#  'hogwarts-legacy',
#  'forza-horizon',
#  'golden-sun',
#  'harvest-moon-tree-of-tranquility',
#  'geometry-wars-3-dimensions',
#  'the-kings-dilemma-chronicles',
#  'mary-skelter-2',
#  'yu-gi-oh-reshef-of-destruction',
#  'batman-arkham-origins',
#  'castlevania-order-of-ecclesia',
#  'the-nioh-collection',
#  'the-legend-of-zelda-phantom-hourglass',
#  'lady-sia',
#  'battlefield-2',
#  'superhot-vr',
#  'deus-ex-mankind-divided',
#  'shin-rorona-no-atelier-hajimari-no-monogatari-a',
#  'gigantic',
#  'infamous',
#  'crysis-3',
#  'puyo-puyo-tsuu',
#  'wakeboarding-unleashed-featuring-shaun-murray',
#  'dragon-age-inquisition',
#  'the-last-of-us',
#  'sega-gt',
#  'bandle-tale-a-league-of-legends-story',
#  'shin-megami-tensei-persona',
#  'the-sims-unleashed',
#  'earthworm-jim',
#  'cat-girl-without-salad-amuse-bouche',
#  'warhammer-vermintide-2',
#  'dirt-2',
#  'trillion-god-of-destruction',
#  'spellforce-iii-reforced',
#  'apollo-justice-ace-attorney',
#  'deadly-dozen-pacific-theater',
#  'real-boxing',
#  'etrian-odyssey-ii-heroes-of-lagaard',
#  'olliolli-world',
#  'command-and-conquer-red-alert',
#  'lil-guardsman',
#  'driver-renegade',
#  'dancemasters',
#  'wandersong',
#  'grand-theft-auto-double-pack',
#  'hatsune-miku-project-diva-f',
#  'bloody-roar-3',
#  'martha-is-dead',
#  'warioware-inc-mega-microgame',
#  'broken-pieces',
#  'battlefield-3-back-to-karkand',
#  'smashing-drive',
#  'guitar-hero-metallica',
#  'tom-clancys-ghost-recon-advanced-warfighter',
#  'pirates-of-black-cove',
#  'mushroom-11',
#  'nascar-14',
#  'metal-gear-solid-hd-collection',
#  'mario-and-luigi-superstar-saga',
#  'space-invaders-revolution',
#  'apex-legends',
#  'silpheed-the-lost-planet',
#  'thief-ii-the-metal-age',
#  'dead-effect-2',
#  'call-of-duty-united-offensive',
#  'wolfenstein-ii-the-new-colossus',
#  'the-adventures-of-cookie-and-cream',
#  'the-sims-superstar',
#  'gungrave-overdose',
#  'genji-dawn-of-the-samurai',
#  'red-dead-redemption-undead-nightmare-pack',
#  'remote-assault',
#  'titanfall',
#  'nascar-racing-4',
#  'r4-ridge-racer-type-4',
#  'the-talos-principle-reawakened',
#  'the-legend-of-zelda-twilight-princess-hd',
#  'x-men-next-dimension',
#  'warhammer-40-000-dawn-of-war-ii',
#  'fairy-tail-dungeons',
#  'child-of-eden',
#  'pillars-of-eternity-ii-deadfire',
#  'fragpunk',
#  'there-came-an-echo',
#  'fire-pro-wrestling-2001',
#  'pac-man-championship-edition-dx',
#  'mad-rat-dead',
#  'ratchet-and-clank-size-matters',
#  'hey-you-pikachu',
#  'dr-mario-puzzle-league',
#  'theatrhythm-final-fantasy',
#  'world-series-of-poker',
#  'metal-gear-solid-3-subsistence',
#  'gravity-rush',
#  'rezero-starting-life-in-another-world-the-prophecy',
#  'rare-replay',
#  'spellforce-2-shadow-wars',
#  'blossom-tales-the-sleeping-king',
#  'station-to-station',
#  'espn-college-hoops-2k5',
#  'frogger-2',
#  'total-overdose-a-gunslingers-tale-in-mexico',
#  'phantaruk',
#  'wwe-road-to-wrestlemania-x8',
#  'evergate',
#  'infamous-2',
#  'hearthstone-heroes-of-warcraft-blackrock-mountain',
#  'neversong',
#  'the-chronicles-of-riddick-escape-from-butcher-bay',
#  'world-of-warcraft-cataclysm',
#  'rails-across-america',
#  'final-fantasy-xiv-heavensward',
#  'capcom-fighting-collection-2',
#  'railroad-tycoon-ii',
#  'warborn',
#  'assassins-creed-iv-black-flag',
#  'thomas-was-alone',
#  'samurai-warriors-spirit-of-sanada',
#  'star-trek-resurgence',
#  'quarantine-circular',
#  'shin-megami-tensei-persona-3',
#  'warioware-twisted',
#  'return-of-the-obra-dinn',
#  'mass-effect',
#  'duck-game',
#  'mlb-10-the-show',
#  'metroid-samus-returns',
#  'far-cry-4',
#  'haunt-2012',
#  'star-wars-demolition',
#  'ghost-of-tsushima',
#  'harvest-moon-ds-grand-bazaar',
#  'warioware-snapped',
#  'anno-2205',
#  'windward-2012',
#  'thumper',
#  'super-monkey-ball-step-and-roll',
#  'the-drifter',
#  'fifa-16',
#  'the-legend-of-zelda-the-minish-cap',
#  'call-of-duty-2-big-red-one',
#  'clustertruck',
#  'back-to-the-future-the-game-episode-i-its-abo',
#  'the-valiant',
#  'might-and-magic-chess-royale',
#  'prey-the-stars',
#  'turrican-flashback-collection',
#  'the-evil-within-the-consequence',
#  'monster-hunter-wilds',
#  'fear-factor-unleashed',
#  'metro-exodus-enhanced-edition',
#  'wipeout-pure',
#  'total-immersion-racing',
#  'the-walking-dead-the-telltale-series-a-new-4',
#  'corpse-party',
#  'vitamin-connection',
#  'shin-megami-tensei-v-vengeance',
#  'might-and-magic-clash-of-heroes',
#  'doom-3',
#  'singstar-abba',
#  'art-style-light-trax',
#  'circus-electrique',
#  'warhammer-40-000-dawn-of-war-ii-chaos-rising',
#  'trajectile',
#  'god-of-war-origins-collection',
#  'bonkies',
#  'star-wars-starfighter',
#  'gunfire-reborn',
#  'bloodroots',
#  'legends-of-war-pattons-campaign',
#  'budget-cuts',
#  'framed-collection',
#  'breakout-recharged',
#  'dead-or-alive-4',
#  'stephens-sausage-roll',
#  'hyrule-warriors',
#  'sonic-advance',
#  'horizon-zero-dawn-remastered',
#  'paranormasight-the-seven-mysteries-of-honjo',
#  'returnal',
#  'tsioque',
#  'spongebob-squarepants-lights-camera-pants',
#  'jade-empire',
#  'titan-quest-immortal-throne',
#  'portal',
#  'lords-of-the-fallen-2014',
#  'tekken-8',
#  'boom-blox',
#  'wasteland-2',
#  'darkspore',
#  'trapped-dead',
#  'late-shift',
#  'endless-dungeon',
#  'pro-evolution-soccer-2018',
#  'max-payne-2-the-fall-of-max-payne',
#  'pro-evolution-soccer-2015',
#  'xenoblade-chronicles-x',
#  'total-war-warhammer',
#  'darkest-dungeon-the-crimson-court',
#  'dungeons-4',
#  'lorelei-and-the-laser-eyes',
#  'warhammer-40-000-dawn-of-war',
#  'disneys-hide-and-sneak',
#  'the-mageseeker-a-league-of-legends-story',
#  'left-4-dead',
#  'gone-home',
#  'disneys-extreme-skate-adventure',
#  '2010-fifa-world-cup-south-africa',
#  'wik-and-the-fable-of-souls',
#  'ncaa-football-2002',
#  'super-rude-bear-resurrection',
#  'i-heart-geeks',
#  'picross-e3',
#  'dragon-ball-gt-transformation',
#  'air-traffic-chaos',
#  'turok-2-seeds-of-evil-remaster',
#  'driven',
#  'falcon-age',
#  'hyper-light-drifter',
#  'atelier-sophie-2-the-alchemist-of-the-mysterious',
#  'batman-the-telltale-series',
#  'sherlock-holmes-the-devils-daughter',
#  'ratchet-and-clank-future-tools-of-destruction',
#  'phoenix-wright-ace-attorney-trilogy',
#  'dragon-ball-revenge-of-king-piccolo',
#  'shadow-man-remastered',
#  'planet-coaster',
#  'super-exploding-zoo',
#  'lode-runner-legacy',
#  'call-of-duty-black-ops-ii-uprising',
#  'regalia-of-men-and-monarchs-royal-edition',
#  'the-dark-crystal-age-of-resistance-tactics',
#  'tales-of-graces',
#  'funky-lab-rat',
#  'the-legend-of-zelda-links-awakening',
#  'scurge-hive',
#  'disney-pixar-monsters-inc-2002',
#  'lego-star-wars',
#  'shadow-harvest-phantom-ops',
#  'ufo-50',
#  'delta-force-xtreme',
#  'uefa-euro-2012',
#  'mega-man-anniversary-collection',
#  'super-meat-boy',
#  'red-faction-guerrilla',
#  'f-e-a-r-2-project-origin',
#  'vaccine-2017',
#  'the-king-of-fighters-02-03',
#  'aegis-of-earth-protonovus-assault',
#  'nba-inside-drive-2003',
#  'harvest-moon-the-tale-of-two-towns',
#  'phoenix-wright-ace-attorney',
#  'the-showdown-effect',
#  'god-of-war-2005',
#  'kirbys-adventure',
#  'pinball-fx-2-marvel-pinball-avengers-chronicles',
#  'star-wars-hunters',
#  'pokemon-conquest',
#  'nba-2k11',
#  'halo-2-multiplayer-map-pack',
#  'tenchu-wrath-of-heaven',
#  'dogs-of-war-battle-on-primus-iv',
#  'flyn',
#  'huntdown',
#  'phoenix-springs',
#  'nex-machina-death-machine',
#  'valkyrie-profile-2-silmeria',
#  'eternal-darkness-sanitys-requiem',
#  'kingdoms-of-amalur-re-reckoning',
#  'airblade',
#  'dragon-is-dead',
#  'expedition-zero',
#  'cargo-commander',
#  'sumioni-demon-arts',
#  'score-rush-extended',
#  'alien-havoc',
#  'black-and-white',
#  'ncaa-football-2003',
#  'bioshock-2',
#  'promise-mascot-agency',
#  'gunman-clive-hd-collection',
#  'against-the-storm',
#  'final-fantasy-xii-the-zodiac-age',
#  'forza-horizon-rally-expansion-pack',
#  'looney-tunes-space-race',
#  'valkyria-chronicles',
#  'antonblast',
#  'call-of-duty-black-ops-4',
#  'fallout-new-vegas-honest-hearts',
#  'wetrix',
#  'wwe-2k23',
#  'nhl-06',
#  'kingdom-hearts',
#  'nhl-hitz-20-02',
#  'start-the-party-save-the-world',
#  'boomerang-x',
#  'medieval-ii-total-war-kingdoms',
#  'penumbra-requiem',
#  'espn-final-round-golf-2002',
#  'command-and-conquer-red-alert-3-commanders-c',
#  'full-spectrum-warrior',
#  'mvp-baseball-2005',
#  'phantom-breaker-omnia',
#  'batman-the-telltale-series-episode-5-city-of-light',
#  'forza-horizon-2',
#  'mario-kart-7',
#  'lotus-challenge',
#  'the-legend-of-dragoon',
#  'namco-museum-virtual-arcade',
#  'cult-of-the-lamb',
#  'nba-2k15',
#  'trade-empires',
#  'agatha-christie-the-abc-murders',
#  'grid-2008',
#  'prison-architect',
#  'nhl-20',
#  'ultimate-block-party',
#  'rhythm-heaven-megamix',
#  'playerunknowns-battlegrounds',
#  'after-burner-black-falcon',
#  'borderlands-a-telltale-game-series',
#  'westerado',
#  'jacob-jones-and-the-bigfoot-mystery-episode-one',
#  'far-cry-3',
#  'final-fantasy-xiv-shadowbringers',
#  'oddworld-abes-oddysee-new-n-tasty',
#  'einhander',
#  'forever-worlds-enter-the-unknown',
#  'slender-the-arrival',
#  'crash-of-the-titans',
#  'hatsune-miku-project-diva-future-tone-colorful',
#  'heretic-plus-hexen',
#  'dynasty-tactics',
#  'company-of-heroes-2-the-western-front-armies',
#  'rive',
#  'xenoblade-chronicles',
#  'affordable-space-adventures',
#  'silent-storm',
#  'the-last-spell',
#  'danganronpa-v3-killing-harmony',
#  'trainz',
#  'allegiance',
#  'the-sims-makin-magic',
#  'starcraft-ii-legacy-of-the-void',
#  'thief-the-dark-project',
#  'yo-kai-watch-3',
#  'order-up-2011',
#  'the-dark-eye-demonicon',
#  'broken-sword-shadow-of-the-templars',
#  'burnout-paradise',
#  'ni-no-kuni-wrath-of-the-white-witch',
#  'prince-of-persia-2008',
#  'cocoro-line-defender',
#  'here-they-lie',
#  'antichamber',
#  'world-championship-poker-2-featuring-howard-leder',
#  'battleblock-theater',
#  'yakuza-5-remastered',
#  'mario-golf-advance-tour',
#  'planet-puzzle-league',
#  'swat-4',
#  'gravity-games-bike-street-vert-dirt',
#  'beam-breakers',
#  'xcom-enemy-unknown',
#  'ncaa-march-madness-2004',
#  'clive-barkers-undying',
#  'lost-in-harmony',
#  'nier-automata-the-end-of-yorha-edition',
#  'bridge-constructor-portal',
#  'mtv-sports-skateboarding-featuring-andy-macdonald',
#  'mighty-switch-force-2',
#  'asgards-wrath',
#  'infamous-second-son',
#  'motorsport-manager',
#  'fantasian-neo-dimension',
#  'europa-universalis-iv',
#  'sonic-and-knuckles',
#  'janes-attack-squadron',
#  'snoopy-flying-ace',
#  'command-and-conquer-3-kanes-wrath',
#  'crisis-core-final-fantasy-vii-reunion',
#  'life-is-strange-episode-1',
#  'hauntii',
#  'dual-blades',
#  'technobabylon',
#  'the-munchables',
#  'blast-off',
#  'crash-bandicoot-4-its-about-time',
#  'baldurs-gate',
#  'neighbors-from-hell',
#  'hex-shards-of-fate',
#  'atelier-ryza-ever-darkness-and-the-secret-hideout',
#  'maize-2016',
#  'steel-seed',
#  'microbot',
#  'world-series-of-poker-2008-battle-for-the-bracele',
#  'for-the-king',
#  'paradigm-paradox',
#  'tom-clancys-rainbow-six-vegas',
#  'star-wars-galaxies-an-empire-divided',
#  'chaos-field',
#  'rugby-2005',
#  'a-memoir-blue',
#  'onslaught-2009',
#  'drakensang-the-dark-eye',
#  'touchmaster',
#  'giga-wing-2',
#  'brunswick-pro-bowling-2007',
#  'shadows-over-loathing',
#  'destiny-2',
#  'destiny-2-warmind',
#  'emergency-2012',
#  'spyro-season-of-ice',
#  'shadow-of-the-tomb-raider',
#  'reus',
#  'legion-arena',
#  'nelly-cootalot-the-fowl-fleet',
#  'astral-chain',
#  'papers-please',
#  'viva-pinata',
#  'arcana-heart-3',
#  'dead-rising-4',
#  'syberia-the-world-before',
#  'bayonetta-plus-bayonetta-2',
#  'unicorn-overlord',
#  'another-code-r-a-journey-into-lost-memories',
#  'f-zero-gx',
#  'sheltered',
#  'portal-companion-collection',
#  'karaoke-revolution-volume-3',
#  ...]

# %%
[(i,j) for i,j in zip(df_juegos["item_id_raw"], df_juegos["score"])]
# Out:
# [('the-legend-of-zelda-breath-of-the-wild', 0.8989982008934021),
#  ('grand-theft-auto-iv', 0.8752790689468384),
#  ('the-elder-scrolls-iv-oblivion', 0.8674384951591492),
#  ('the-legend-of-zelda-tears-of-the-kingdom', 0.8666650056838989),
#  ('neverwinter-nights', 0.8645586371421814),
#  ('uncharted-2-among-thieves', 0.8611711859703064),
#  ('the-last-of-us-part-ii', 0.8600700497627258),
#  ('red-dead-redemption', 0.8578047156333923),
#  ('mass-effect-2', 0.8545241951942444),
#  ('grand-theft-auto-v', 0.852694571018219),
#  ('the-elder-scrolls-v-skyrim', 0.8481279611587524),
#  ('baldurs-gate-3', 0.8458714485168457),
#  ('final-fantasy-vii-remake', 0.8437809944152832),
#  ('elden-ring', 0.8429677486419678),
#  ('uncharted-4-a-thiefs-end', 0.8423599004745483),
#  ('super-mario-galaxy-2', 0.8418518900871277),
#  ('god-of-war-ragnarok', 0.8400197625160217),
#  ('castlevania-dawn-of-sorrow', 0.8385034799575806),
#  ('astro-bot', 0.8378661274909973),
#  ('god-of-war', 0.8350633382797241),
#  ('bioshock', 0.8346384167671204),
#  ('super-smash-bros-ultimate', 0.8323065042495728),
#  ('bloodborne', 0.8313848376274109),
#  ('red-dead-redemption-2', 0.8297555446624756),
#  ('divinity-original-sin-ii', 0.8290472626686096),
#  ('forza-motorsport-4', 0.8289896845817566),
#  ('littlebigplanet', 0.8288776278495789),
#  ('the-sims-2', 0.8286908864974976),
#  ('sid-meiers-civilization-v', 0.8282555341720581),
#  ('project-gotham-racing-2', 0.8278968334197998),
#  ('super-mario-bros-wonder', 0.8267814517021179),
#  ('tom-clancys-splinter-cell-pandora-tomorrow', 0.826587438583374),
#  ('dark-souls-ii', 0.8259784579277039),
#  ('super-mario-galaxy', 0.8258031606674194),
#  ('madden-nfl-2004', 0.8256783485412598),
#  ('gears-of-war-3', 0.8243330121040344),
#  ('goodbye-volcano-high', 0.8238025307655334),
#  ('othello', 0.8234599232673645),
#  ('diablo-iii', 0.8232880234718323),
#  ('god-of-war-chains-of-olympus', 0.8231228590011597),
#  ('uncharted-3-drakes-deception', 0.82305508852005),
#  ('super-smash-bros-brawl', 0.8225395083427429),
#  ('call-of-duty-modern-warfare-2', 0.8222306966781616),
#  ('inside', 0.8215764164924622),
#  ('grand-theft-auto-san-andreas', 0.8214903473854065),
#  ('nhl-11', 0.8212684988975525),
#  ('the-legend-of-zelda-ocarina-of-time-3d', 0.820871889591217),
#  ('the-legend-of-zelda-twilight-princess', 0.8205047845840454),
#  ('blue-prince', 0.8204768896102905),
#  ('meteos', 0.8196859955787659),
#  ('destiny-the-taken-king', 0.8195963501930237),
#  ('tekken-3', 0.8191391825675964),
#  ('quake-iii-arena-1999', 0.8179435133934021),
#  ('super-mario-odyssey', 0.8177522420883179),
#  ('resident-evil-4', 0.8173476457595825),
#  ('the-legend-of-zelda-majoras-mask-3d', 0.8171245455741882),
#  ('littlebigplanet-ps-vita', 0.8166866898536682),
#  ('god-of-war-iii', 0.8157145977020264),
#  ('the-last-of-us-part-i', 0.8154485821723938),
#  ('ninja-gaiden-2004', 0.8151841759681702),
#  ('the-legend-of-zelda-the-wind-waker-hd', 0.8150718212127686),
#  ('half-life-2', 0.8137577176094055),
#  ('golden-lap', 0.8134884834289551),
#  ('mario-kart-8-deluxe', 0.8134550452232361),
#  ('halo-3', 0.8120557069778442),
#  ('demons-souls-2009', 0.8118199706077576),
#  ('halo-2', 0.8117112517356873),
#  ('batman-arkham-city', 0.8108025789260864),
#  ('split-fiction', 0.8105601668357849),
#  ('silent-hill-2-2001', 0.8104812502861023),
#  ('cradle', 0.810391366481781),
#  ('donkey-kong-bananza', 0.8101806044578552),
#  ('sid-meiers-alpha-centauri', 0.8093168139457703),
#  ('super-mario-3d-world', 0.8092498183250427),
#  ('xenoblade-chronicles-definitive-edition', 0.8090929388999939),
#  ('resident-evil-4-2005', 0.8090693354606628),
#  ('sekiro-shadows-die-twice', 0.808880090713501),
#  ('fallout-3', 0.8086023330688477),
#  ('fez', 0.8085899949073792),
#  ('street-fighter-6', 0.8084460496902466),
#  ('super-mario-3d-world-plus-bowsers-fury', 0.8081874847412109),
#  ('dead-space-3-awakened', 0.808183491230011),
#  ('the-talos-principle-road-to-gehenna', 0.8081380724906921),
#  ('xenoblade-chronicles-3', 0.807826042175293),
#  ('shadow-of-the-colossus', 0.8077848553657532),
#  ('braid', 0.8075360655784607),
#  ('trinity-universe', 0.8075004816055298),
#  ('ratchet-and-clank-rift-apart', 0.8074589371681213),
#  ('gears-of-war', 0.8074473142623901),
#  ('far-cry', 0.8064154982566833),
#  ('the-master-chief-collection', 0.8062023520469666),
#  ('spectral-force-genesis', 0.8059415817260742),
#  ('hades', 0.8053019642829895),
#  ('animal-crossing-new-leaf', 0.8052543997764587),
#  ('diablo-iii-reaper-of-souls', 0.804858386516571),
#  ('call-of-duty-4-modern-warfare', 0.8047351241111755),
#  ('xcom-2-war-of-the-chosen', 0.8045802116394043),
#  ('virtua-tennis', 0.8044277429580688),
#  ('madden-nfl-2005', 0.8039884567260742),
#  ('psychonauts', 0.8025115132331848),
#  ('resident-evil-2', 0.8021572232246399),
#  ('rock-band-3', 0.8021041750907898),
#  ('halo-combat-evolved', 0.8017405867576599),
#  ('grand-theft-auto-iv-the-lost-and-damned', 0.8011481761932373),
#  ('fifa-soccer-10', 0.8010532855987549),
#  ('unreal-tournament-2004', 0.8008986115455627),
#  ('ghost-of-tsushima-directors-cut', 0.8008056879043579),
#  ('under-night-in-birth-exelatecl-r', 0.8005744218826294),
#  ('worldwide-soccer-manager-2008', 0.8005173802375793),
#  ('deathloop', 0.8002856373786926),
#  ('rock-band', 0.7996333837509155),
#  ('monster-hunter-world-iceborne', 0.7995583415031433),
#  ('marvels-spider-man-2', 0.7993080019950867),
#  ('final-fantasy-vii-remake-intergrade', 0.7990973591804504),
#  ('animal-crossing-new-horizons', 0.798976480960846),
#  ('gran-turismo-4', 0.7988498210906982),
#  ('borderlands-2', 0.7981225252151489),
#  ('metroid-prime', 0.7980921864509583),
#  ('need-for-speed-hot-pursuit', 0.7980713248252869),
#  ('the-orange-box', 0.798028290271759),
#  ('final-fantasy-x', 0.7979292273521423),
#  ('star-wars-knights-of-the-old-republic', 0.7971647381782532),
#  ('forza-horizon-4', 0.7971435189247131),
#  ('darwin-project', 0.7969812750816345),
#  ('clair-obscur-expedition-33', 0.7969261407852173),
#  ('command-and-conquer-3-tiberium-wars', 0.7968218326568604),
#  ('guitar-hero-ii', 0.7967249751091003),
#  ('nba-2k13', 0.7966357469558716),
#  ('final-fantasy-vii-rebirth', 0.7965027093887329),
#  ('the-talos-principle-2', 0.7962586283683777),
#  ('crimson-skies-high-road-to-revenge', 0.7959292531013489),
#  ('the-legend-of-zelda-skyward-sword', 0.7956792116165161),
#  ('final-fantasy-xii', 0.7954487800598145),
#  ('super-mega-baseball-3', 0.795352578163147),
#  ('elite-beat-agents', 0.7952823638916016),
#  ('grandia-ii-remastered', 0.7952228784561157),
#  ('tom-clancys-splinter-cell-chaos-theory', 0.7949345707893372),
#  ('metroid-prime-remastered', 0.7946768403053284),
#  ('dino-frontier', 0.7945265769958496),
#  ('prototype-2009', 0.7944349050521851),
#  ('burnout-revenge', 0.7943350076675415),
#  ('grand-theft-auto-chinatown-wars', 0.7941816449165344),
#  ('resident-evil-7-biohazard', 0.7935509085655212),
#  ('death-stranding-2-on-the-beach', 0.7933006286621094),
#  ('jett-the-far-shore', 0.7932387590408325),
#  ('uncharted-drakes-fortune', 0.7932111620903015),
#  ('immortals-fenyx-rising-the-lost-gods', 0.7932041883468628),
#  ('taxi-life-a-city-driving-simulator', 0.7930344343185425),
#  ('mark-of-the-ninja', 0.7929828763008118),
#  ('dead-nation-road-of-devastation', 0.7928058505058289),
#  ('persona-4-golden', 0.7927379012107849),
#  ('sonic-the-hedgehog-4-episode-1', 0.7921798825263977),
#  ('battlefield-bad-company-2', 0.7919774055480957),
#  ('just-dance-2017', 0.7917085886001587),
#  ('forza-motorsport-2005', 0.7916764616966248),
#  ('gears-of-war-2', 0.7916356921195984),
#  ('wizardry-tale-of-the-forsaken-land', 0.7915839552879333),
#  ('her-story', 0.7914713621139526),
#  ('rally-trophy', 0.7913452982902527),
#  ('final-fantasy-xvi', 0.7913147807121277),
#  ('boom-blox-bash-party', 0.7909998297691345),
#  ('breath-of-fire-iv', 0.790922999382019),
#  ('empires-dawn-of-the-modern-world', 0.7907516360282898),
#  ('horizon-zero-dawn', 0.7907194495201111),
#  ('stray', 0.7906869053840637),
#  ('masquerada-songs-and-shadows', 0.7906743884086609),
#  ('lumines', 0.7906524538993835),
#  ('call-of-duty-modern-warfare-3', 0.7905521988868713),
#  ('tom-clancys-splinter-cell', 0.7904985547065735),
#  ('edens-zero', 0.7904321551322937),
#  ('industria', 0.7903068661689758),
#  ('the-legend-of-zelda-the-wind-waker', 0.7899410724639893),
#  ('ninja-gaiden-black', 0.7896994948387146),
#  ('resident-evil-hd-remaster', 0.789633572101593),
#  ('crypt-of-the-necrodancer', 0.7896004915237427),
#  ('silence-of-the-sleep', 0.7895186543464661),
#  ('enigma-rising-tide', 0.789506196975708),
#  ('kingdom-come-deliverance-ii', 0.7892288565635681),
#  ('world-of-warcraft-the-burning-crusade', 0.7891480326652527),
#  ('portal-2', 0.7890446782112122),
#  ('embr', 0.7889938354492188),
#  ('ni-no-kuni-ii-revenant-kingdom', 0.7888241410255432),
#  ('the-legend-of-zelda-skyward-sword-hd', 0.788762629032135),
#  ('dead-space', 0.7885765433311462),
#  ('grandia-ii', 0.7882847785949707),
#  ('street-fighter-iv', 0.7881618738174438),
#  ('tales-of-symphonia', 0.7881354093551636),
#  ('guilty-gear-x', 0.7879640460014343),
#  ('metal-gear-solid-4-guns-of-the-patriots', 0.7879204154014587),
#  ('the-elder-scrolls-iv-shivering-isles', 0.7878287434577942),
#  ('the-world-ends-with-you', 0.7877393364906311),
#  ('grand-theft-auto-vice-city', 0.7877338528633118),
#  ('the-cave-2013', 0.7876763939857483),
#  ('nier-automata', 0.7876322865486145),
#  ('triangle-strategy', 0.7874143719673157),
#  ('greg-hastings-tournament-paintball-maxd', 0.7873801589012146),
#  ('tetris-effect', 0.7872025966644287),
#  ('sin-and-punishment-star-successor', 0.7871926426887512),
#  ('assassins-creed-ii', 0.787013590335846),
#  ('resident-evil', 0.7869945168495178),
#  ('spirit-city-lofi-sessions', 0.7868673205375671),
#  ('cadence-of-hyrule-crypt-of-the-necrodancer', 0.7867699265480042),
#  ('the-last-of-us-left-behind', 0.7865707278251648),
#  ('ratchet-and-clank-up-your-arsenal', 0.7864654660224915),
#  ('bioshock-infinite', 0.7862937450408936),
#  ('kid-icarus', 0.7858758568763733),
#  ('rallisport-challenge-2', 0.7858604192733765),
#  ('anno-1800-console-edition', 0.7857977747917175),
#  ('nba-hoopz', 0.7856764197349548),
#  ('rock-band-2', 0.7852484583854675),
#  ('way-of-the-passive-fist', 0.7851918935775757),
#  ('littlebigplanet-2', 0.7850961089134216),
#  ('need-for-speed-iii-hot-pursuit', 0.7850272059440613),
#  ('baldurs-gate-ii-shadows-of-amn', 0.7850188612937927),
#  ('mlb-2003', 0.7850084900856018),
#  ('corpse-of-discovery', 0.78499835729599),
#  ('kerbal-space-program-making-history', 0.7849948406219482),
#  ('asterigos-curse-of-the-stars', 0.7848318219184875),
#  ('medieval-ii-total-war', 0.7848290801048279),
#  ('master-detective-archives-rain-code', 0.784796416759491),
#  ('the-ico-and-shadow-of-the-colossus-collection', 0.7847682237625122),
#  ('nba-jam-on-fire-edition', 0.7847602963447571),
#  ('tearaway', 0.7846501469612122),
#  ('avadon-the-black-fortress', 0.7844815254211426),
#  ('nioh', 0.7843248844146729),
#  ('super-trucks-racing', 0.7840889096260071),
#  ('maximo-ghosts-to-glory', 0.7839772701263428),
#  ('wario-land-4', 0.78396075963974),
#  ('the-yakuza-remastered-collection', 0.7838220000267029),
#  ('gryphon-knight-epic', 0.7837067246437073),
#  ('capcom-classics-collection', 0.7835766673088074),
#  ('armored-core-nine-breaker', 0.7834097743034363),
#  ('final-fantasy-xi', 0.7833705544471741),
#  ('oh-my-godheads', 0.7833662033081055),
#  ('ori-and-the-will-of-the-wisps', 0.7833588123321533),
#  ('punch-out-2009', 0.783276379108429),
#  ('super-mario-sunshine', 0.7831671237945557),
#  ('metal-gear-solid-v-the-phantom-pain', 0.783158004283905),
#  ('mega-man-zero-4', 0.7830930352210999),
#  ('pokemon-sun', 0.7830665111541748),
#  ('rise-of-the-triad-ludicrous-edition', 0.7830272316932678),
#  ('danganronpa-decadence', 0.7829815745353699),
#  ('mlb-the-show-19', 0.7828384041786194),
#  ('the-witcher-2-assassins-of-kings', 0.7827437520027161),
#  ('overgrowth-2013', 0.7826157212257385),
#  ('like-a-dragon-infinite-wealth', 0.7825179696083069),
#  ('grand-theft-auto-iv-the-ballad-of-gay-tony', 0.7824928760528564),
#  ('sly-cooper-collection', 0.7824210524559021),
#  ('slam-bolt-scrappers', 0.78238844871521),
#  ('neopets-puzzle-adventure', 0.7823849320411682),
#  ('ico', 0.7822176218032837),
#  ('the-yawhg', 0.7818885445594788),
#  ('zack-and-wiki-quest-for-barbaros-treasure', 0.7817287445068359),
#  ('gatling-gears', 0.7817171216011047),
#  ('gears-of-war-4', 0.7814369201660156),
#  ('total-war-three-kingdoms-the-furious-wild', 0.7813760638237),
#  ('doc-clock-the-toasted-sandwich-of-time', 0.7813501358032227),
#  ('pokemon-x', 0.781168520450592),
#  ('age-of-mythology-the-titans', 0.7811436653137207),
#  ('world-of-warcraft', 0.7811194062232971),
#  ('world-in-conflict', 0.7809711694717407),
#  ('need-for-speed-hot-pursuit-2', 0.7808992266654968),
#  ('max-payne-3', 0.7808856964111328),
#  ('lydia', 0.7808786034584045),
#  ('the-inner-friend', 0.78083735704422),
#  ('monster-hunter-rise', 0.7807767987251282),
#  ('persona-3-reload', 0.7807741165161133),
#  ('tom-clancys-rainbow-six-covert-ops-essentials', 0.7807138562202454),
#  ('killzone-2', 0.780550479888916),
#  ('mario-kart-8', 0.7804452776908875),
#  ('slay-the-princess-the-pristine-cut', 0.7803602814674377),
#  ('ooga-booga', 0.7803545594215393),
#  ('batman-arkham-asylum', 0.7803444266319275),
#  ('alan-wake-ii', 0.7803201079368591),
#  ('dragon-quest-xi-echoes-of-an-elusive-age', 0.7802359461784363),
#  ('battlefield-1', 0.7801838517189026),
#  ('pdc-world-championship-darts-2009', 0.7800736427307129),
#  ('tony-hawks-underground-2', 0.7800415754318237),
#  ('rims-racing', 0.7799915671348572),
#  ('contra', 0.7798857092857361),
#  ('the-sims-life-stories', 0.7798382043838501),
#  ('the-outer-worlds', 0.7798237204551697),
#  ('mom-hid-my-game', 0.7796311378479004),
#  ('fallout-2', 0.7795711755752563),
#  ('warcraft-iii-reign-of-chaos', 0.7794777154922485),
#  ('bear-and-breakfast', 0.7793624401092529),
#  ('days-gone', 0.7792531251907349),
#  ('lover-pretend', 0.7792094945907593),
#  ('tomb-raider-chronicles', 0.7788402438163757),
#  ('larry-ragland-4x4-challenge', 0.7788195013999939),
#  ('fire-emblem-three-houses', 0.7787220478057861),
#  ('naruto-shippuden-ninja-destiny-2', 0.7786863446235657),
#  ('a-robot-named-fight', 0.7783693075180054),
#  ('silent-hill-2', 0.778171718120575),
#  ('burnout-3-takedown', 0.7781655192375183),
#  ('metroid-dread', 0.7781252264976501),
#  ('the-last-faith', 0.7780909538269043),
#  ('forza-motorsport-6', 0.7779566645622253),
#  ('final-fantasy-ix', 0.7775260806083679),
#  ('fifa-soccer-08', 0.7773900628089905),
#  ('elden-ring-shadow-of-the-erdtree', 0.7773048281669617),
#  ('pillars-of-eternity', 0.7772684693336487),
#  ('super-smash-bros-for-nintendo-3ds-wii-u', 0.7772655487060547),
#  ('dead-space-2008', 0.7772647738456726),
#  ('dragon-quest-viii-journey-of-the-cursed-king', 0.7772417664527893),
#  ('medal-of-honor-infiltrator', 0.7772066593170166),
#  ('super-mario-3d-land', 0.7770856022834778),
#  ('metal-gear-solid-delta-snake-eater', 0.7770715355873108),
#  ('forza-motorsport-3', 0.7769333720207214),
#  ('prince-of-persia-the-sands-of-time', 0.7768688797950745),
#  ('into-the-breach', 0.7768509984016418),
#  ('skulls-of-the-shogun', 0.7768294215202332),
#  ('forza-horizon-5-hot-wheels', 0.776624321937561),
#  ('starcraft-ii-wings-of-liberty', 0.7766242027282715),
#  ('the-beast-inside', 0.7766103744506836),
#  ('persona-5', 0.7765699028968811),
#  ('demons-souls', 0.7765142321586609),
#  ('uncharted-the-nathan-drake-collection', 0.7764936089515686),
#  ('gyruss', 0.7763527035713196),
#  ('call-of-duty-2', 0.7763033509254456),
#  ('saints-row-the-third', 0.776289165019989),
#  ('starseed-pilgrim', 0.7760531306266785),
#  ('star-control-origins', 0.7760497331619263),
#  ('guitar-hero-5', 0.7758293151855469),
#  ('persona-5-royal', 0.7755786776542664),
#  ('the-legend-of-zelda-breath-of-the-wild-nintendo', 0.775404155254364),
#  ('freedom-fighters', 0.7754016518592834),
#  ('the-hundred-line-last-defense-academy', 0.7753327488899231),
#  ('empires-apart', 0.7752546072006226),
#  ('wrc-2-fia-world-rally-championship-2011', 0.7752158045768738),
#  ('the-witness', 0.7751972079277039),
#  ('greg-hastings-tournament-paintball', 0.7751805186271667),
#  ('bayonetta', 0.775157630443573),
#  ('the-witcher-3-wild-hunt', 0.7749279737472534),
#  ('guild-wars', 0.7749109864234924),
#  ('chrono-trigger', 0.7747871279716492),
#  ('top-darts', 0.7747148275375366),
#  ('wattam', 0.7746788263320923),
#  ('the-legend-of-zelda-echoes-of-wisdom', 0.7746647596359253),
#  ('green-hell', 0.7745563387870789),
#  ('espn-nfl-football', 0.7745471596717834),
#  ('tom-clancys-rainbow-six-3', 0.7742998600006104),
#  ('sonic-rivals-2', 0.774248480796814),
#  ('quake', 0.7741948962211609),
#  ('divinity-original-sin', 0.7740235924720764),
#  ('gran-turismo-3-a-spec', 0.774001955986023),
#  ('ib', 0.7740012407302856),
#  ('f1-2002', 0.7739889025688171),
#  ('rome-total-war', 0.7739144563674927),
#  ('gran-turismo-7', 0.7738731503486633),
#  ('castlevania-symphony-of-the-night', 0.7738516330718994),
#  ('nba-2k17', 0.7738001346588135),
#  ('teslagrad', 0.7736998200416565),
#  ('blazblue-chrono-phantasma-extend', 0.7736822962760925),
#  ('crazy-machines-3', 0.7735756635665894),
#  ('afterlove-ep', 0.7735497951507568),
#  ('dragon-quest-xi-s-echoes-of-an-elusive-age', 0.7733772993087769),
#  ('gears-5', 0.7733628153800964),
#  ('tom-clancys-splinter-cell-conviction', 0.7732841372489929),
#  ('taur', 0.7732410430908203),
#  ('operation-flashpoint-resistance', 0.7732054591178894),
#  ('portal-still-alive', 0.7730823159217834),
#  ('galactic-civilizations-ii-twilight-of-the-arnor', 0.7730802893638611),
#  ('devil-daggers', 0.773001492023468),
#  ('wasteland-3', 0.7729690670967102),
#  ('dirt', 0.7729490995407104),
#  ('fable-ii', 0.7729319930076599),
#  ('penny-arcade-adventures-episode-two', 0.7728655338287354),
#  ('total-war-warhammer-iii', 0.772858738899231),
#  ('rumble-racing', 0.772834300994873),
#  ('ssx-2000', 0.7726603150367737),
#  ('republique-episode-4-gods-acre', 0.7724922299385071),
#  ('heroes-of-the-pacific', 0.7724876999855042),
#  ('mario-kart-world', 0.7724509239196777),
#  ('metroid-fusion', 0.7723821401596069),
#  ('fifa-soccer-12', 0.7723514437675476),
#  ('rhapsody-a-musical-adventure', 0.7722379565238953),
#  ('south-park-the-stick-of-truth', 0.772219717502594),
#  ('cocoon', 0.7720444798469543),
#  ('attack-of-the-movies-3d', 0.7719601988792419),
#  ('rez-infinite', 0.7718467712402344),
#  ('oddworld-soulstorm-oddtimized-edition', 0.7717732787132263),
#  ('shinobi-art-of-vengeance', 0.7716989517211914),
#  ('the-tiny-bang-story', 0.771666944026947),
#  ('reventure', 0.7715926170349121),
#  ('mlb-the-show-22', 0.7714243531227112),
#  ('mass-effect-3', 0.7714242339134216),
#  ('embracelet', 0.7714160680770874),
#  ('xenoblade-chronicles-x-definitive-edition', 0.7713449001312256),
#  ('little-kings-story', 0.7712188363075256),
#  ('austerlitz-napoleons-greatest-victory', 0.7711213231086731),
#  ('steinsgate-elite', 0.7710691094398499),
#  ('unruly-heroes', 0.7710280418395996),
#  ('halo-reach', 0.7709575295448303),
#  ('mercenaries-playground-of-destruction', 0.770912230014801),
#  ('malicious-fallen', 0.7709065079689026),
#  ('james-bond-007-everything-or-nothing', 0.7708376049995422),
#  ('joe-danger-special-edition', 0.7708296179771423),
#  ('x-type-plus', 0.7708027958869934),
#  ('crysis', 0.7706814408302307),
#  ('steinsgate-0', 0.7706699967384338),
#  ('steamworld-dig-2', 0.7704827189445496),
#  ('tennis-in-the-face', 0.7703698873519897),
#  ('tokyo-xtreme-racer-zero', 0.7703562378883362),
#  ('the-outer-worlds-spacers-choice-edition', 0.7703098058700562),
#  ('planescape-torment', 0.7702785134315491),
#  ('bayonetta-2', 0.7701781988143921),
#  ('trials-evolution-gold-edition', 0.7700743675231934),
#  ('journey', 0.7700682878494263),
#  ('trigger-witch', 0.7699256539344788),
#  ('mushroom-wars-2', 0.7698975801467896),
#  ('cuphead', 0.769865095615387),
#  ('outlive-2001', 0.7698472738265991),
#  ('torchlight-ii', 0.7696524858474731),
#  ('pokemon-pearl-version', 0.7696342468261719),
#  ('doom-eternal', 0.7695504426956177),
#  ('legend-of-grimrock', 0.7695500254631042),
#  ('the-legend-of-zelda-a-link-between-worlds', 0.7695426344871521),
#  ('borderlands-3', 0.7695309519767761),
#  ('attack-of-the-friday-monsters-a-tokyo-tale', 0.7695005536079407),
#  ('harvest-moon-magical-melody', 0.7694621682167053),
#  ('bloodsportstv', 0.7694452404975891),
#  ('gish', 0.7691957950592041),
#  ('last-days-of-lazarus', 0.7691227793693542),
#  ('lock-on-modern-air-combat', 0.769096314907074),
#  ('virtua-fighter-4-evolution', 0.7690186500549316),
#  ('advance-wars-dual-strike', 0.7689920663833618),
#  ('a-r-e-s-extinction-agenda-ex', 0.7689544558525085),
#  ('dragon-quest-iii-hd-2d-remake', 0.7689531445503235),
#  ('ace-combat-04-shattered-skies', 0.7689358592033386),
#  ('persona-4-arena-ultimax', 0.7688934803009033),
#  ('soulcalibur-ii', 0.76888108253479),
#  ('primal-planet', 0.7688215374946594),
#  ('lego-star-wars-the-complete-saga', 0.7687197327613831),
#  ('super-mario-maker', 0.768718421459198),
#  ('new-super-mario-bros-wii', 0.768703818321228),
#  ('unreal-tournament-2003', 0.7686668038368225),
#  ('katamari-damacy', 0.7686516046524048),
#  ('salt-and-sanctuary', 0.7686426043510437),
#  ('nioh-2-the-complete-edition', 0.7686095833778381),
#  ('magical-beat', 0.7686071991920471),
#  ('guitar-hero', 0.7685999274253845),
#  ('rise-of-nations-thrones-and-patriots', 0.7685765624046326),
#  ('dragon-ball-fighterz', 0.7683306932449341),
#  ('metroid-prime-2-echoes', 0.7682901620864868),
#  ('the-book-of-unwritten-tales-2', 0.7682836055755615),
#  ('3-on-3-nhl-arcade', 0.7682501673698425),
#  ('dreams', 0.7682138085365295),
#  ('not-for-broadcast', 0.7681748270988464),
#  ('hurry-up-hedgehog', 0.7681602835655212),
#  ('jet-set-radio-2000', 0.7681493163108826),
#  ('madden-nfl-12', 0.7681338787078857),
#  ('spelunky', 0.7680251002311707),
#  ('massive-assault-network-2', 0.7680066823959351),
#  ('atelier-yumia-the-alchemist-of-memories-and-the', 0.7679991126060486),
#  ('pinball-m', 0.7679371237754822),
#  ('call-of-duty', 0.7678853869438171),
#  ('rampage-puzzle-attack', 0.7677955031394958),
#  ('destroy-all-humans-big-willy-unleashed', 0.7676761150360107),
#  ('microsoft-flight-simulator', 0.7676469087600708),
#  ('iridium-runners', 0.7676107287406921),
#  ('total-war-shogun-2-fall-of-the-samurai', 0.7675027251243591),
#  ('everhood', 0.7674339413642883),
#  ('naruto-shippuden-ultimate-ninja-storm-3-full-burs', 0.7674160599708557),
#  ('shovel-knight-showdown', 0.7674041986465454),
#  ('bloodborne-the-old-hunters', 0.7673652172088623),
#  ('dj-hero', 0.767317533493042),
#  ('read-only-memories-neurodiver', 0.7671456933021545),
#  ('the-elder-scrolls-iii-bloodmoon', 0.7671294808387756),
#  ('this-war-of-mine', 0.7670133709907532),
#  ('fire-emblem-if', 0.767009437084198),
#  ('hunters-legacy', 0.7670052647590637),
#  ('blackguards-2', 0.7669569849967957),
#  ('two-point-museum', 0.7669438719749451),
#  ('flinthook', 0.7669242024421692),
#  ('left-4-dead-2', 0.7669200301170349),
#  ('x-men-origins-wolverine-2009', 0.7668761610984802),
#  ('age-of-conan-unchained', 0.7668306827545166),
#  ('henry-hatsworth-in-the-puzzling-adventure', 0.7668253779411316),
#  ('the-simpsons-hit-and-run', 0.7667801380157471),
#  ('the-survivalists', 0.766773521900177),
#  ('the-walking-dead-the-telltale-series-a-new', 0.7667401432991028),
#  ('bass-strike', 0.7667396068572998),
#  ('ori-and-the-blind-forest', 0.7667370438575745),
#  ('csi-ny', 0.766685426235199),
#  ('dungeon-defenders-awakened', 0.7666406035423279),
#  ('snooker-19', 0.7666288018226624),
#  ('links-2004', 0.7665300965309143),
#  ('mega-man-battle-network-5-team-colonel', 0.7665229439735413),
#  ('the-king-of-fighters-ex-neo-blood', 0.7664698958396912),
#  ('pillars-of-eternity-complete-edition', 0.7664561867713928),
#  ('eastshade', 0.7664517164230347),
#  ('alternativa', 0.7664506435394287),
#  ('luigis-mansion-dark-moon', 0.7663498520851135),
#  ('company-of-heroes-2-the-british-forces', 0.7662369608879089),
#  ('redux-dark-matters', 0.7662262320518494),
#  ('terminator-resistance-annihilation-line', 0.7662051916122437),
#  ('bleach-the-blade-of-fate', 0.7661701440811157),
#  ('sportsfriends', 0.7661152482032776),
#  ('final-fantasy-iv-3d-remake', 0.7661105394363403),
#  ('dance-dance-revolution-supernova-2', 0.7660988569259644),
#  ('soul-nomad-and-the-world-eaters', 0.7660933136940002),
#  ('far-cry-new-dawn', 0.7660899758338928),
#  ('gigantosaurus-the-game', 0.7660893797874451),
#  ('endless-space', 0.7659668326377869),
#  ('crusader-kings-iii', 0.76591557264328),
#  ('fatal-fury-battle-archives-volume-2', 0.7659055590629578),
#  ('just-dance-2021', 0.7658776640892029),
#  ('mario-plus-rabbids-sparks-of-hope', 0.7658728361129761),
#  ('lost-in-random-the-eternal-die', 0.7657961249351501),
#  ('the-last-of-us-part-ii-remastered', 0.7657535672187805),
#  ('mind-path-to-thalamus', 0.7657358646392822),
#  ('the-sims-4-eco-lifestyle', 0.7657279372215271),
#  ('the-secret-of-monkey-island-special-edition', 0.7656811475753784),
#  ('bladestorm-the-hundred-years-war', 0.7656671404838562),
#  ('virtua-tennis-world-tour', 0.7655814290046692),
#  ('mlb-the-show-20', 0.7654666304588318),
#  ('tokyo-42', 0.7653730511665344),
#  ('sinking-island', 0.7653301954269409),
#  ('threefold-recital', 0.7652718424797058),
#  ('god-of-war-ii', 0.7652024030685425),
#  ('blacktail', 0.7651292681694031),
#  ('nhl-09', 0.7651084661483765),
#  ('dr-mario-64', 0.7650906443595886),
#  ('atv-offroad-fury-pro', 0.7649943828582764),
#  ('black-desert-online-land-of-the-morning-light', 0.7649846076965332),
#  ('pikmin-4', 0.7649357318878174),
#  ('uncharted-legacy-of-thieves-collection', 0.7649325132369995),
#  ('gods-and-heroes-rome-rising', 0.7648889422416687),
#  ('cyberpunk-2077', 0.7648298144340515),
#  ('tomba-special-edition', 0.7648195624351501),
#  ('assassins-creed-brotherhood', 0.7647581696510315),
#  ('fatal-fury-city-of-the-wolves', 0.7647399306297302),
#  ('the-raven-legacy-of-a-master-thief-ancestry-of', 0.7647380232810974),
#  ('starfield', 0.764533519744873),
#  ('total-war-warhammer-ii', 0.7645329236984253),
#  ('xdefiant', 0.7644514441490173),
#  ('clockwork-empires', 0.76445072889328),
#  ('pokemon-platinum-version', 0.7643560171127319),
#  ('aggressors-ancient-rome', 0.764346182346344),
#  ('rise-of-nations-rise-of-legends', 0.7643434405326843),
#  ('where-is-my-heart', 0.7643308043479919),
#  ('flower', 0.7643287777900696),
#  ('labyrinth-city-pierre-the-maze-detective', 0.764260470867157),
#  ('grand-prix-3', 0.7642483115196228),
#  ('daxter', 0.7642430067062378),
#  ('the-sims-2-bon-voyage', 0.7642300128936768),
#  ('rocksmith', 0.7641972303390503),
#  ('the-sinking-city', 0.7641693949699402),
#  ('shatter-2009', 0.7641585469245911),
#  ('cities-in-motion', 0.7641496658325195),
#  ('batman-the-brave-and-the-bold-the-videogame', 0.7641248106956482),
#  ('need-for-speed-high-stakes', 0.7638678550720215),
#  ('anomaly-agent', 0.7638257145881653),
#  ('brute-force', 0.7637620568275452),
#  ('new-legends', 0.7635812163352966),
#  ('diablo-iv', 0.7635751366615295),
#  ('tom-clancys-splinter-cell-double-agent', 0.7634934782981873),
#  ('xcom-enemy-within-expansion', 0.7634038329124451),
#  ('prince-of-persia-the-lost-crown', 0.7634024620056152),
#  ('mortal-kombat-1-khaos-reigns', 0.7633967995643616),
#  ('looney-tunes-wacky-world-of-sports', 0.7633441686630249),
#  ('fru', 0.7632392048835754),
#  ('neva', 0.7632169127464294),
#  ('star-wars-obi-wan', 0.7631264328956604),
#  ('boxboy-plus-boxgirl', 0.7631129026412964),
#  ('the-last-door-2014', 0.7630490660667419),
#  ('doom-the-dark-ages', 0.7630247473716736),
#  ('hotline-miami-2-wrong-number', 0.762982189655304),
#  ('rabbids-alive-and-kicking', 0.7629619240760803),
#  ('hogwarts-legacy', 0.7628354430198669),
#  ('forza-horizon', 0.7627540230751038),
#  ('golden-sun', 0.7627317309379578),
#  ('harvest-moon-tree-of-tranquility', 0.7627031207084656),
#  ('geometry-wars-3-dimensions', 0.762681245803833),
#  ('the-kings-dilemma-chronicles', 0.7626765966415405),
#  ('mary-skelter-2', 0.7625745534896851),
#  ('yu-gi-oh-reshef-of-destruction', 0.7624801993370056),
#  ('batman-arkham-origins', 0.7624387741088867),
#  ('castlevania-order-of-ecclesia', 0.7624160051345825),
#  ('the-nioh-collection', 0.7624031901359558),
#  ('the-legend-of-zelda-phantom-hourglass', 0.76240074634552),
#  ('lady-sia', 0.7623826861381531),
#  ('battlefield-2', 0.762322723865509),
#  ('superhot-vr', 0.7622895836830139),
#  ('deus-ex-mankind-divided', 0.7622602581977844),
#  ('shin-rorona-no-atelier-hajimari-no-monogatari-a', 0.7620602250099182),
#  ('gigantic', 0.7618991136550903),
#  ('infamous', 0.761885404586792),
#  ('crysis-3', 0.7618573307991028),
#  ('puyo-puyo-tsuu', 0.7618266940116882),
#  ('wakeboarding-unleashed-featuring-shaun-murray', 0.7617648243904114),
#  ('dragon-age-inquisition', 0.761764645576477),
#  ('the-last-of-us', 0.7616980671882629),
#  ('sega-gt', 0.761673629283905),
#  ('bandle-tale-a-league-of-legends-story', 0.7616657018661499),
#  ('shin-megami-tensei-persona', 0.7616146206855774),
#  ('the-sims-unleashed', 0.7615825533866882),
#  ('earthworm-jim', 0.7615141868591309),
#  ('cat-girl-without-salad-amuse-bouche', 0.7614807486534119),
#  ('warhammer-vermintide-2', 0.7614670991897583),
#  ('dirt-2', 0.7614509463310242),
#  ('trillion-god-of-destruction', 0.7614405155181885),
#  ('spellforce-iii-reforced', 0.7613757848739624),
#  ('apollo-justice-ace-attorney', 0.761362612247467),
#  ('deadly-dozen-pacific-theater', 0.7613508105278015),
#  ('real-boxing', 0.7613024711608887),
#  ('etrian-odyssey-ii-heroes-of-lagaard', 0.7612808346748352),
#  ('olliolli-world', 0.7612717747688293),
#  ('command-and-conquer-red-alert', 0.7612588405609131),
#  ('lil-guardsman', 0.7612507939338684),
#  ('driver-renegade', 0.7612335085868835),
#  ('dancemasters', 0.7612056732177734),
#  ('wandersong', 0.7611827850341797),
#  ('grand-theft-auto-double-pack', 0.761172890663147),
#  ('hatsune-miku-project-diva-f', 0.7611601948738098),
#  ('bloody-roar-3', 0.7611600160598755),
#  ('martha-is-dead', 0.7611578106880188),
#  ('warioware-inc-mega-microgame', 0.7610713839530945),
#  ('broken-pieces', 0.7610706686973572),
#  ('battlefield-3-back-to-karkand', 0.7609760761260986),
#  ('smashing-drive', 0.7609423995018005),
#  ('guitar-hero-metallica', 0.7609149813652039),
#  ('tom-clancys-ghost-recon-advanced-warfighter', 0.7608813643455505),
#  ('pirates-of-black-cove', 0.7607954740524292),
#  ('mushroom-11', 0.76075279712677),
#  ('nascar-14', 0.7607192993164062),
#  ('metal-gear-solid-hd-collection', 0.7607009410858154),
#  ('mario-and-luigi-superstar-saga', 0.7607004046440125),
#  ('space-invaders-revolution', 0.7606809139251709),
#  ('apex-legends', 0.760625422000885),
#  ('silpheed-the-lost-planet', 0.7605925798416138),
#  ('thief-ii-the-metal-age', 0.7605887055397034),
#  ('dead-effect-2', 0.760537326335907),
#  ('call-of-duty-united-offensive', 0.760530948638916),
#  ('wolfenstein-ii-the-new-colossus', 0.7605277895927429),
#  ('the-adventures-of-cookie-and-cream', 0.7604955434799194),
#  ('the-sims-superstar', 0.7604444622993469),
#  ('gungrave-overdose', 0.7604350447654724),
#  ('genji-dawn-of-the-samurai', 0.7604308128356934),
#  ('red-dead-redemption-undead-nightmare-pack', 0.7603912949562073),
#  ('remote-assault', 0.7603187561035156),
#  ('titanfall', 0.7602984309196472),
#  ('nascar-racing-4', 0.7602230310440063),
#  ('r4-ridge-racer-type-4', 0.7601618766784668),
#  ('the-talos-principle-reawakened', 0.7601603269577026),
#  ('the-legend-of-zelda-twilight-princess-hd', 0.7601544260978699),
#  ('x-men-next-dimension', 0.7601490616798401),
#  ('warhammer-40-000-dawn-of-war-ii', 0.7600818872451782),
#  ('fairy-tail-dungeons', 0.760061502456665),
#  ('child-of-eden', 0.7599958777427673),
#  ('pillars-of-eternity-ii-deadfire', 0.7599928975105286),
#  ('fragpunk', 0.7599890828132629),
#  ('there-came-an-echo', 0.7599235773086548),
#  ('fire-pro-wrestling-2001', 0.7598657011985779),
#  ('pac-man-championship-edition-dx', 0.7598468661308289),
#  ('mad-rat-dead', 0.759796679019928),
#  ('ratchet-and-clank-size-matters', 0.7597719430923462),
#  ('hey-you-pikachu', 0.7597535848617554),
#  ('dr-mario-puzzle-league', 0.7597439885139465),
#  ('theatrhythm-final-fantasy', 0.7597420811653137),
#  ('world-series-of-poker', 0.7597416043281555),
#  ('metal-gear-solid-3-subsistence', 0.7597227692604065),
#  ('gravity-rush', 0.7597177028656006),
#  ('rezero-starting-life-in-another-world-the-prophecy', 0.7597047686576843),
#  ('rare-replay', 0.7596957087516785),
#  ('spellforce-2-shadow-wars', 0.7596750855445862),
#  ('blossom-tales-the-sleeping-king', 0.7596445083618164),
#  ('station-to-station', 0.7595531344413757),
#  ('espn-college-hoops-2k5', 0.7595504522323608),
#  ('frogger-2', 0.7595356106758118),
#  ('total-overdose-a-gunslingers-tale-in-mexico', 0.759505569934845),
#  ('phantaruk', 0.7594906091690063),
#  ('wwe-road-to-wrestlemania-x8', 0.7594634890556335),
#  ('evergate', 0.7593773007392883),
#  ('infamous-2', 0.7593683004379272),
#  ('hearthstone-heroes-of-warcraft-blackrock-mountain', 0.7593635320663452),
#  ('neversong', 0.7593488097190857),
#  ('the-chronicles-of-riddick-escape-from-butcher-bay', 0.7592822313308716),
#  ('world-of-warcraft-cataclysm', 0.7592543363571167),
#  ('rails-across-america', 0.7592452168464661),
#  ('final-fantasy-xiv-heavensward', 0.7592015862464905),
#  ('capcom-fighting-collection-2', 0.7591754794120789),
#  ('railroad-tycoon-ii', 0.7591274976730347),
#  ('warborn', 0.7590646147727966),
#  ('assassins-creed-iv-black-flag', 0.759053111076355),
#  ('thomas-was-alone', 0.7590304017066956),
#  ('samurai-warriors-spirit-of-sanada', 0.7590193152427673),
#  ('star-trek-resurgence', 0.7589359879493713),
#  ('quarantine-circular', 0.758905291557312),
#  ('shin-megami-tensei-persona-3', 0.7588911056518555),
#  ('warioware-twisted', 0.758870005607605),
#  ('return-of-the-obra-dinn', 0.7588338255882263),
#  ('mass-effect', 0.7588198184967041),
#  ('duck-game', 0.7588174939155579),
#  ('mlb-10-the-show', 0.7587889432907104),
#  ('metroid-samus-returns', 0.7587647438049316),
#  ('far-cry-4', 0.7587579488754272),
#  ('haunt-2012', 0.7587562203407288),
#  ('star-wars-demolition', 0.7587489485740662),
#  ('ghost-of-tsushima', 0.7587487101554871),
#  ('harvest-moon-ds-grand-bazaar', 0.7587400674819946),
#  ('warioware-snapped', 0.7587294578552246),
#  ('anno-2205', 0.7586824297904968),
#  ('windward-2012', 0.7586725950241089),
#  ('thumper', 0.7586353421211243),
#  ('super-monkey-ball-step-and-roll', 0.7586204409599304),
#  ('the-drifter', 0.7586156725883484),
#  ('fifa-16', 0.7586014866828918),
#  ('the-legend-of-zelda-the-minish-cap', 0.7585763931274414),
#  ('call-of-duty-2-big-red-one', 0.758571207523346),
#  ('clustertruck', 0.7585561275482178),
#  ('back-to-the-future-the-game-episode-i-its-abo', 0.7585280537605286),
#  ('the-valiant', 0.7585219740867615),
#  ('might-and-magic-chess-royale', 0.7584473490715027),
#  ('prey-the-stars', 0.7583828568458557),
#  ('turrican-flashback-collection', 0.7582853436470032),
#  ('the-evil-within-the-consequence', 0.7582255005836487),
#  ('monster-hunter-wilds', 0.7582151293754578),
#  ('fear-factor-unleashed', 0.7581498026847839),
#  ('metro-exodus-enhanced-edition', 0.758124828338623),
#  ('wipeout-pure', 0.7580991387367249),
#  ('total-immersion-racing', 0.7580745220184326),
#  ('the-walking-dead-the-telltale-series-a-new-4', 0.7580277323722839),
#  ('corpse-party', 0.7579964995384216),
#  ('vitamin-connection', 0.7579651474952698),
#  ('shin-megami-tensei-v-vengeance', 0.7579002976417542),
#  ('might-and-magic-clash-of-heroes', 0.7578616738319397),
#  ('doom-3', 0.7578181028366089),
#  ('singstar-abba', 0.7577491402626038),
#  ('art-style-light-trax', 0.757738471031189),
#  ('circus-electrique', 0.7576206922531128),
#  ('warhammer-40-000-dawn-of-war-ii-chaos-rising', 0.7575598359107971),
#  ('trajectile', 0.7575406432151794),
#  ('god-of-war-origins-collection', 0.7574689984321594),
#  ('bonkies', 0.7573783993721008),
#  ('star-wars-starfighter', 0.7573729157447815),
#  ('gunfire-reborn', 0.7573588490486145),
#  ('bloodroots', 0.7573546767234802),
#  ('legends-of-war-pattons-campaign', 0.7573276162147522),
#  ('budget-cuts', 0.7572755813598633),
#  ('framed-collection', 0.7572483420372009),
#  ('breakout-recharged', 0.7571846842765808),
#  ('dead-or-alive-4', 0.7571641802787781),
#  ('stephens-sausage-roll', 0.7571151256561279),
#  ('hyrule-warriors', 0.7570855021476746),
#  ('sonic-advance', 0.7570793032646179),
#  ('horizon-zero-dawn-remastered', 0.7570381164550781),
#  ('paranormasight-the-seven-mysteries-of-honjo', 0.757014811038971),
#  ('returnal', 0.7570046782493591),
#  ('tsioque', 0.7569704651832581),
#  ('spongebob-squarepants-lights-camera-pants', 0.7569637894630432),
#  ('jade-empire', 0.7569072842597961),
#  ('titan-quest-immortal-throne', 0.7569066882133484),
#  ('portal', 0.7568965554237366),
#  ('lords-of-the-fallen-2014', 0.7568503022193909),
#  ('tekken-8', 0.7568457722663879),
#  ('boom-blox', 0.7568345069885254),
#  ('wasteland-2', 0.7568303346633911),
#  ('darkspore', 0.7568143606185913),
#  ('trapped-dead', 0.7567301988601685),
#  ('late-shift', 0.756714403629303),
#  ('endless-dungeon', 0.7566964030265808),
#  ('pro-evolution-soccer-2018', 0.7566937804222107),
#  ('max-payne-2-the-fall-of-max-payne', 0.7566503882408142),
#  ('pro-evolution-soccer-2015', 0.7566038966178894),
#  ('xenoblade-chronicles-x', 0.7565892338752747),
#  ('total-war-warhammer', 0.7565699815750122),
#  ('darkest-dungeon-the-crimson-court', 0.7565466165542603),
#  ('dungeons-4', 0.7565456032752991),
#  ('lorelei-and-the-laser-eyes', 0.7565286755561829),
#  ('warhammer-40-000-dawn-of-war', 0.7564557790756226),
#  ('disneys-hide-and-sneak', 0.7563905119895935),
#  ('the-mageseeker-a-league-of-legends-story', 0.7563216090202332),
#  ('left-4-dead', 0.7562796473503113),
#  ('gone-home', 0.7562453150749207),
#  ('disneys-extreme-skate-adventure', 0.7561688423156738),
#  ('2010-fifa-world-cup-south-africa', 0.7560467720031738),
#  ('wik-and-the-fable-of-souls', 0.7560465931892395),
#  ('ncaa-football-2002', 0.7560161352157593),
#  ('super-rude-bear-resurrection', 0.7560158371925354),
#  ('i-heart-geeks', 0.7560077905654907),
#  ('picross-e3', 0.7559941411018372),
#  ('dragon-ball-gt-transformation', 0.7559731006622314),
#  ('air-traffic-chaos', 0.7559379935264587),
#  ('turok-2-seeds-of-evil-remaster', 0.7559293508529663),
#  ('driven', 0.7559288144111633),
#  ('falcon-age', 0.7558706998825073),
#  ('hyper-light-drifter', 0.7558542490005493),
#  ('atelier-sophie-2-the-alchemist-of-the-mysterious', 0.7558335661888123),
#  ('batman-the-telltale-series', 0.755830705165863),
#  ('sherlock-holmes-the-devils-daughter', 0.7558150887489319),
#  ('ratchet-and-clank-future-tools-of-destruction', 0.7558041214942932),
#  ('phoenix-wright-ace-attorney-trilogy', 0.7557716965675354),
#  ('dragon-ball-revenge-of-king-piccolo', 0.7557356953620911),
#  ('shadow-man-remastered', 0.7557112574577332),
#  ('planet-coaster', 0.7556698322296143),
#  ('super-exploding-zoo', 0.7556629776954651),
#  ('lode-runner-legacy', 0.755652904510498),
#  ('call-of-duty-black-ops-ii-uprising', 0.7556436657905579),
#  ('regalia-of-men-and-monarchs-royal-edition', 0.755615770816803),
#  ('the-dark-crystal-age-of-resistance-tactics', 0.7555601596832275),
#  ('tales-of-graces', 0.7555363774299622),
#  ('funky-lab-rat', 0.7555232048034668),
#  ('the-legend-of-zelda-links-awakening', 0.7554938793182373),
#  ('scurge-hive', 0.755479633808136),
#  ('disney-pixar-monsters-inc-2002', 0.7554774880409241),
#  ('lego-star-wars', 0.7554309368133545),
#  ('shadow-harvest-phantom-ops', 0.7553964853286743),
#  ('ufo-50', 0.7553814053535461),
#  ('delta-force-xtreme', 0.7553812265396118),
#  ('uefa-euro-2012', 0.7553561329841614),
#  ('mega-man-anniversary-collection', 0.7553404569625854),
#  ('super-meat-boy', 0.7552927136421204),
#  ('red-faction-guerrilla', 0.7552852034568787),
#  ('f-e-a-r-2-project-origin', 0.755211591720581),
#  ('vaccine-2017', 0.7552065253257751),
#  ('the-king-of-fighters-02-03', 0.7551740407943726),
#  ('aegis-of-earth-protonovus-assault', 0.7551437020301819),
#  ('nba-inside-drive-2003', 0.755103588104248),
#  ('harvest-moon-the-tale-of-two-towns', 0.7550801038742065),
#  ('phoenix-wright-ace-attorney', 0.7549784779548645),
#  ('the-showdown-effect', 0.754803478717804),
#  ('god-of-war-2005', 0.7547921538352966),
#  ('kirbys-adventure', 0.7547698616981506),
#  ('pinball-fx-2-marvel-pinball-avengers-chronicles', 0.7547693252563477),
#  ('star-wars-hunters', 0.7547234892845154),
#  ('pokemon-conquest', 0.7547051906585693),
#  ('nba-2k11', 0.7546944618225098),
#  ('halo-2-multiplayer-map-pack', 0.754690945148468),
#  ('tenchu-wrath-of-heaven', 0.7546666264533997),
#  ('dogs-of-war-battle-on-primus-iv', 0.7546544671058655),
#  ('flyn', 0.7546510100364685),
#  ('huntdown', 0.7546212077140808),
#  ('phoenix-springs', 0.7546126246452332),
#  ('nex-machina-death-machine', 0.754522979259491),
#  ('valkyrie-profile-2-silmeria', 0.7545105814933777),
#  ('eternal-darkness-sanitys-requiem', 0.7544997334480286),
#  ('kingdoms-of-amalur-re-reckoning', 0.754481852054596),
#  ('airblade', 0.7544729709625244),
#  ('dragon-is-dead', 0.7544636130332947),
#  ('expedition-zero', 0.7544476389884949),
#  ('cargo-commander', 0.754360020160675),
#  ('sumioni-demon-arts', 0.7543534636497498),
#  ('score-rush-extended', 0.7542989253997803),
#  ('alien-havoc', 0.7542954683303833),
#  ('black-and-white', 0.7542567849159241),
#  ('ncaa-football-2003', 0.7542497515678406),
#  ('bioshock-2', 0.7542325854301453),
#  ('promise-mascot-agency', 0.7541127800941467),
#  ('gunman-clive-hd-collection', 0.7541101574897766),
#  ('against-the-storm', 0.7541027665138245),
#  ('final-fantasy-xii-the-zodiac-age', 0.7540779709815979),
#  ('forza-horizon-rally-expansion-pack', 0.7540774941444397),
#  ('looney-tunes-space-race', 0.7540508508682251),
#  ('valkyria-chronicles', 0.7540106177330017),
#  ('antonblast', 0.7539903521537781),
#  ('call-of-duty-black-ops-4', 0.753951370716095),
#  ('fallout-new-vegas-honest-hearts', 0.7538536787033081),
#  ('wetrix', 0.7538418173789978),
#  ('wwe-2k23', 0.753840446472168),
#  ('nhl-06', 0.7538145184516907),
#  ('kingdom-hearts', 0.7537825703620911),
#  ('nhl-hitz-20-02', 0.7537400722503662),
#  ('start-the-party-save-the-world', 0.7537000775337219),
#  ('boomerang-x', 0.753674328327179),
#  ('medieval-ii-total-war-kingdoms', 0.7536538243293762),
#  ('penumbra-requiem', 0.7536421418190002),
#  ('espn-final-round-golf-2002', 0.7536218762397766),
#  ('command-and-conquer-red-alert-3-commanders-c', 0.7536037564277649),
#  ('full-spectrum-warrior', 0.7536036372184753),
#  ('mvp-baseball-2005', 0.753593921661377),
#  ('phantom-breaker-omnia', 0.7535712122917175),
#  ('batman-the-telltale-series-episode-5-city-of-light', 0.7535412907600403),
#  ('forza-horizon-2', 0.7535325288772583),
#  ('mario-kart-7', 0.7534800171852112),
#  ('lotus-challenge', 0.7534776329994202),
#  ('the-legend-of-dragoon', 0.7534732222557068),
#  ('namco-museum-virtual-arcade', 0.7534564733505249),
#  ('cult-of-the-lamb', 0.7534198760986328),
#  ('nba-2k15', 0.7534001469612122),
#  ('trade-empires', 0.753399670124054),
#  ('agatha-christie-the-abc-murders', 0.7533980011940002),
#  ('grid-2008', 0.7533849477767944),
#  ('prison-architect', 0.7533494830131531),
#  ('nhl-20', 0.7533479332923889),
#  ('ultimate-block-party', 0.7533445358276367),
#  ('rhythm-heaven-megamix', 0.7533291578292847),
#  ('playerunknowns-battlegrounds', 0.7533169388771057),
#  ('after-burner-black-falcon', 0.7532883286476135),
#  ('borderlands-a-telltale-game-series', 0.7531154155731201),
#  ('westerado', 0.7531061172485352),
#  ('jacob-jones-and-the-bigfoot-mystery-episode-one', 0.7530995011329651),
#  ('far-cry-3', 0.7530016899108887),
#  ('final-fantasy-xiv-shadowbringers', 0.75300133228302),
#  ('oddworld-abes-oddysee-new-n-tasty', 0.7529922127723694),
#  ('einhander', 0.752977728843689),
#  ('forever-worlds-enter-the-unknown', 0.7529096007347107),
#  ('slender-the-arrival', 0.7528905868530273),
#  ('crash-of-the-titans', 0.7528828978538513),
#  ('hatsune-miku-project-diva-future-tone-colorful', 0.7528539299964905),
#  ('heretic-plus-hexen', 0.7528336644172668),
#  ('dynasty-tactics', 0.7528336644172668),
#  ('company-of-heroes-2-the-western-front-armies', 0.7528058886528015),
#  ('rive', 0.7527616024017334),
#  ('xenoblade-chronicles', 0.7527481317520142),
#  ('affordable-space-adventures', 0.7526987791061401),
#  ('silent-storm', 0.7526552677154541),
#  ('the-last-spell', 0.7526140213012695),
#  ('danganronpa-v3-killing-harmony', 0.7526074647903442),
#  ('trainz', 0.7525554299354553),
#  ('allegiance', 0.7525414228439331),
#  ('the-sims-makin-magic', 0.7525259852409363),
#  ('starcraft-ii-legacy-of-the-void', 0.7524996995925903),
#  ('thief-the-dark-project', 0.7524922490119934),
#  ('yo-kai-watch-3', 0.7524628043174744),
#  ('order-up-2011', 0.7524583339691162),
#  ('the-dark-eye-demonicon', 0.7524346709251404),
#  ('broken-sword-shadow-of-the-templars', 0.7523995041847229),
#  ('burnout-paradise', 0.7523919939994812),
#  ('ni-no-kuni-wrath-of-the-white-witch', 0.7523693442344666),
#  ('prince-of-persia-2008', 0.7522996068000793),
#  ('cocoro-line-defender', 0.7522946000099182),
#  ('here-they-lie', 0.7522522211074829),
#  ('antichamber', 0.752250611782074),
#  ('world-championship-poker-2-featuring-howard-leder', 0.7522006034851074),
#  ('battleblock-theater', 0.7521942257881165),
#  ('yakuza-5-remastered', 0.7521386742591858),
#  ('mario-golf-advance-tour', 0.7521291971206665),
#  ('planet-puzzle-league', 0.7521170973777771),
#  ('swat-4', 0.7520930171012878),
#  ('gravity-games-bike-street-vert-dirt', 0.7520729899406433),
#  ('beam-breakers', 0.752016007900238),
#  ('xcom-enemy-unknown', 0.7520107626914978),
#  ('ncaa-march-madness-2004', 0.7519988417625427),
#  ('clive-barkers-undying', 0.7519623637199402),
#  ('lost-in-harmony', 0.7519410848617554),
#  ('nier-automata-the-end-of-yorha-edition', 0.7519016265869141),
#  ('bridge-constructor-portal', 0.7518911957740784),
#  ('mtv-sports-skateboarding-featuring-andy-macdonald', 0.7517648935317993),
#  ('mighty-switch-force-2', 0.751693069934845),
#  ('asgards-wrath', 0.7516514658927917),
#  ('infamous-second-son', 0.7516087889671326),
#  ('motorsport-manager', 0.7515736222267151),
#  ('fantasian-neo-dimension', 0.7515658736228943),
#  ('europa-universalis-iv', 0.7515506148338318),
#  ('sonic-and-knuckles', 0.7515261769294739),
#  ('janes-attack-squadron', 0.7515236139297485),
#  ('snoopy-flying-ace', 0.7515197396278381),
#  ('command-and-conquer-3-kanes-wrath', 0.7515048980712891),
#  ('crisis-core-final-fantasy-vii-reunion', 0.7514834403991699),
#  ('life-is-strange-episode-1', 0.751472532749176),
#  ('hauntii', 0.7514073252677917),
#  ('dual-blades', 0.7513700723648071),
#  ('technobabylon', 0.7513338923454285),
#  ('the-munchables', 0.7513330578804016),
#  ('blast-off', 0.751302182674408),
#  ('crash-bandicoot-4-its-about-time', 0.7512982487678528),
#  ('baldurs-gate', 0.7512968182563782),
#  ('neighbors-from-hell', 0.7512708902359009),
#  ('hex-shards-of-fate', 0.7512573599815369),
#  ('atelier-ryza-ever-darkness-and-the-secret-hideout', 0.7512511610984802),
#  ('maize-2016', 0.7512254118919373),
#  ('steel-seed', 0.7511796355247498),
#  ('microbot', 0.7511394619941711),
#  ('world-series-of-poker-2008-battle-for-the-bracele', 0.7511367797851562),
#  ('for-the-king', 0.7511137127876282),
#  ('paradigm-paradox', 0.7510901093482971),
#  ('tom-clancys-rainbow-six-vegas', 0.7510645985603333),
#  ('star-wars-galaxies-an-empire-divided', 0.7510219216346741),
#  ('chaos-field', 0.751004159450531),
#  ('rugby-2005', 0.7509932518005371),
#  ('a-memoir-blue', 0.7509523034095764),
#  ('onslaught-2009', 0.7509405016899109),
#  ('drakensang-the-dark-eye', 0.7508963346481323),
#  ('touchmaster', 0.750874400138855),
#  ('giga-wing-2', 0.7508242726325989),
#  ('brunswick-pro-bowling-2007', 0.7508134245872498),
#  ('shadows-over-loathing', 0.7507720589637756),
#  ('destiny-2', 0.7507448792457581),
#  ('destiny-2-warmind', 0.7507345080375671),
#  ('emergency-2012', 0.75072181224823),
#  ('spyro-season-of-ice', 0.7506760954856873),
#  ('shadow-of-the-tomb-raider', 0.7506702542304993),
#  ('reus', 0.7506676316261292),
#  ('legion-arena', 0.7506633996963501),
#  ('nelly-cootalot-the-fowl-fleet', 0.7506497502326965),
#  ('astral-chain', 0.7505989670753479),
#  ('papers-please', 0.7505974769592285),
#  ('viva-pinata', 0.7505751252174377),
#  ('arcana-heart-3', 0.7505605816841125),
#  ('dead-rising-4', 0.7505213022232056),
#  ('syberia-the-world-before', 0.7504274249076843),
#  ('bayonetta-plus-bayonetta-2', 0.7504248023033142),
#  ('unicorn-overlord', 0.7504238486289978),
#  ('another-code-r-a-journey-into-lost-memories', 0.7503154873847961),
#  ('f-zero-gx', 0.750244677066803),
#  ('sheltered', 0.7502118349075317),
#  ('portal-companion-collection', 0.7501880526542664),
#  ('karaoke-revolution-volume-3', 0.7501810789108276),
#  ...]
